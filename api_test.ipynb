# %% [markdown]
# ## 基础配置

# %%
# 从.env读取API Token，获取思源笔记的笔记本列表
import requests
import json
from pathlib import Path
from dotenv import load_dotenv
import os

# 加载.env文件中的环境变量
load_dotenv()

# 思源笔记API配置
SIYUAN_API_URL = os.getenv("SIYUAN_API_URL", "http://127.0.0.1:6806")  # 从.env读取，默认值为本地地址
SIYUAN_API_TOKEN = os.getenv("SIYUAN_API_TOKEN")

# API请求头
headers = {
    "Authorization": f"Token {SIYUAN_API_TOKEN}",
    "Content-Type": "application/json"
}

def call_siyuan_api(api_path, payload=None):
    """
    调用思源笔记API的通用函数

    :param api_path: API路径
    :param payload: 请求体数据(可选)
    :return: API响应的data部分
    """
    try:
        if payload is None:
            payload = {}

        response = requests.post(
            f"{SIYUAN_API_URL}{api_path}",
            headers=headers,
            json=payload,
            timeout=30
        )
        response.raise_for_status()

        json_response = response.json()
        if json_response.get("code") != 0:
            print(f"API调用错误: {json_response.get('msg')}")
            return None

        return json_response.get("data")

    except requests.exceptions.RequestException as e:
        print(f"请求失败: {e}")
        return None
    except Exception as e:
        print(f"未知错误: {e}")
        return None

# %% [markdown]
# ## 获取笔记本列表

# %%
def get_notebooks():
    """获取所有笔记本列表"""
    print("正在获取笔记本列表...")

    # 检查API配置是否存在
    if not SIYUAN_API_TOKEN:
        print("错误: 未找到SIYUAN_API_TOKEN，请检查.env文件")
        return None

    print(f"API地址: {SIYUAN_API_URL}")
    print(f"API Token: {SIYUAN_API_TOKEN[:10]}...{SIYUAN_API_TOKEN[-4:] if len(SIYUAN_API_TOKEN) > 14 else SIYUAN_API_TOKEN}")
    print()

    data = call_siyuan_api("/api/notebook/lsNotebooks")

    if data and "notebooks" in data:
        notebooks = data["notebooks"]
        print(f"成功获取到 {len(notebooks)} 个笔记本:")
        print("-" * 60)

        for notebook in notebooks:
            status = "已关闭" if notebook.get("closed", False) else "已打开"
            icon = notebook.get("icon", "📁")
            print(f"📖 {notebook['name']}")
            print(f"   ID: {notebook['id']}")
            print(f"   状态: {status}")
            print(f"   排序: {notebook.get('sort', 0)}")
            print("-" * 60)

        return notebooks
    else:
        print("获取笔记本列表失败")
        return None

# 执行获取笔记本列表
notebooks = get_notebooks()
# Out:
# 正在获取笔记本列表...
# API地址: http://127.0.0.1:6806
# API Token: 6bc792eg8b...x1p3
#
# 成功获取到 2 个笔记本:
# ------------------------------------------------------------
# 📖 QuincyZou
#    ID: 20250614224007-27h8mrb
#    状态: 已打开
#    排序: 0
# ------------------------------------------------------------
# 📖 剪藏笔记本
#    ID: 20250618232716-bvztpaf
#    状态: 已打开
#    排序: 0
# ------------------------------------------------------------

# %% [markdown]
# ## 获取笔记本包含的文档列表

# %%
# 获取一个笔记本下的文档列表
first_notebook = notebooks[1]

# 配置参数：设置获取文档的最大层级深度（-1表示无限制）
MAX_DEPTH = 3  # 可以修改这个值来控制层级深度，设为-1表示获取所有层级

print(f"正在获取笔记本 '{first_notebook['name']}' 下的文档列表...")
print(f"笔记本ID: {first_notebook['id']}")
print(f"最大层级深度: {'无限制' if MAX_DEPTH == -1 else MAX_DEPTH}")
print("-" * 60)

# 使用API获取文档树结构
doc_tree_data = call_siyuan_api("/api/filetree/listDocTree", {
    "notebook": first_notebook['id'],
    "path": "/"
})

if doc_tree_data and "tree" in doc_tree_data:
    tree = doc_tree_data["tree"]
    print(f"找到 {len(tree)} 个根文档/文件夹:")
    print()

    # 用于记录所有文档信息的列表
    all_docs_info = []

    # 首先收集指定深度内的所有文档ID
    def collect_doc_ids_with_depth(nodes, current_depth=0):
        """递归收集指定深度内的所有文档ID"""
        doc_ids = []
        for node in nodes:
            doc_id = node.get("id", "")
            if doc_id:
                doc_ids.append(doc_id)

            # 检查是否需要继续递归（根据深度限制）
            if "children" in node and (MAX_DEPTH == -1 or current_depth < MAX_DEPTH):
                doc_ids.extend(collect_doc_ids_with_depth(node["children"], current_depth + 1))
        return doc_ids

    print("正在收集指定深度内的文档ID...")
    all_doc_ids = collect_doc_ids_with_depth(tree)
    print(f"收集到 {len(all_doc_ids)} 个文档ID")

    # 批量获取所有文档的路径
    print("正在批量获取文档路径...")
    doc_paths = {}

    for doc_id in all_doc_ids:
        result = call_siyuan_api("/api/filetree/getHPathByID", {"id": doc_id})
        if result:
            doc_paths[doc_id] = result
        else:
            doc_paths[doc_id] = "未知路径"

    print(f"成功获取 {len(doc_paths)} 个文档的路径")

    def parse_doc_name_from_path(hpath):
        """从人类可读路径中解析文档名称"""
        if not hpath or hpath == "未知路径":
            return "未知文档"

        # 从路径中提取最后一部分作为文档名称
        parts = hpath.strip('/').split('/')
        if parts and parts[-1]:
            return parts[-1]
        return "未知文档"

    def get_doc_info(doc_id):
        """获取文档的名称和路径信息"""
        hpath = doc_paths.get(doc_id, "未知路径")
        doc_name = parse_doc_name_from_path(hpath)
        return doc_name, hpath

    def print_doc_tree(nodes, level=0):
        """递归打印文档树结构"""
        # 检查是否超过最大深度限制
        if MAX_DEPTH != -1 and level > MAX_DEPTH:
            return

        for node in nodes:
            doc_id = node.get("id", "")

            # 从路径解析获取文档信息
            doc_title, doc_hpath = get_doc_info(doc_id)

            # 检查是否有子文档
            has_children = "children" in node and len(node["children"]) > 0
            folder_icon = "📁" if has_children else "📄"

            # 创建可视化的层级缩进
            if level == 0:
                indent = ""
                tree_symbol = ""
            else:
                # 使用树状符号来表示层级关系
                indent = "│   " * (level - 1)
                tree_symbol = "├── "

            # 打印文档信息（增强的可视化层级）
            print(f"{indent}{tree_symbol}{folder_icon} {doc_title}")
            print(f"{indent}{'    ' if level > 0 else ''}   📍 ID: {doc_id}")
            # print(f"{indent}{'    ' if level > 0 else ''}   📊 层级: {level}")
            print(f"{indent}{'    ' if level > 0 else ''}   📂 路径: {doc_hpath}")

            # 记录文档信息到列表中
            doc_info = {
                "id": doc_id,
                "name": doc_title,
                "level": level,
                "has_children": has_children,
                "hpath": doc_hpath,
                "parent_path": "/".join(doc_hpath.strip('/').split('/')[:-1]) if doc_hpath != "未知路径" else "root"
            }
            all_docs_info.append(doc_info)

            # 递归处理子文档（考虑深度限制）
            if has_children and (MAX_DEPTH == -1 or level < MAX_DEPTH):
                print_doc_tree(node["children"], level + 1)

            print()

    print_doc_tree(tree)

    # 统计文档数量
    def count_docs(nodes):
        count = 0
        for node in nodes:
            count += 1
            if "children" in node:
                count += count_docs(node["children"])
        return count

    total_docs = count_docs(tree)
    print(f"总计文档数量: {total_docs}")
    print(f"记录的文档信息数量: {len(all_docs_info)}")

    # 打印文档统计信息
    print("\n=== 文档统计信息 ===")
    level_counts = {}
    for doc in all_docs_info:
        level = doc['level']
        level_counts[level] = level_counts.get(level, 0) + 1

    for level in sorted(level_counts.keys()):
        print(f"第{level}层文档: {level_counts[level]}个")

    # 打印所有文档的name属性
    print("\n=== 所有文档名称列表 ===")
    for i, doc in enumerate(all_docs_info, 1):
        indent = "  " * doc['level']
        print(f"{i:3d}. {indent}{doc['name']}")

    # 保存文档树结构到JSON文件
    output_dir = Path("output")
    output_dir.mkdir(exist_ok=True)

    # 保存原始API数据
    output_file = output_dir / f"doc_tree_{first_notebook['name']}.json"
    with output_file.open('w', encoding='utf-8') as f:
        json.dump(doc_tree_data, f, ensure_ascii=False, indent=2)

    # 保存整理后的文档信息
    docs_info_file = output_dir / f"docs_info_{first_notebook['name']}.json"
    with docs_info_file.open('w', encoding='utf-8') as f:
        json.dump(all_docs_info, f, ensure_ascii=False, indent=2)

    # 保存可视化格式的文档树结构
    visual_file = output_dir / f"visual_tree_{first_notebook['name']}.txt"

    def save_visual_tree(nodes, f, level=0):
        """递归保存可视化的文档树结构到文件"""
        # 检查是否超过最大深度限制
        if MAX_DEPTH != -1 and level > MAX_DEPTH:
            return

        for node in nodes:
            doc_id = node.get("id", "")

            # 从路径解析获取文档信息
            doc_title, doc_hpath = get_doc_info(doc_id)

            # 检查是否有子文档
            has_children = "children" in node and len(node["children"]) > 0
            folder_icon = "📁" if has_children else "📄"

            # 创建可视化的层级缩进
            if level == 0:
                indent = ""
                tree_symbol = ""
            else:
                # 使用树状符号来表示层级关系
                indent = "│   " * (level - 1)
                tree_symbol = "├── "

            # 写入文档信息（增强的可视化层级）
            f.write(f"{indent}{tree_symbol}{folder_icon} {doc_title}\n")
            f.write(f"{indent}{'    ' if level > 0 else ''}   📍 ID: {doc_id}\n")
            # f.write(f"{indent}{'    ' if level > 0 else ''}   📊 层级: {level}\n")
            f.write(f"{indent}{'    ' if level > 0 else ''}   📂 路径: {doc_hpath}\n")

            # 递归处理子文档（考虑深度限制）
            if has_children and (MAX_DEPTH == -1 or level < MAX_DEPTH):
                save_visual_tree(node["children"], f, level + 1)

            f.write("\n")

    with visual_file.open('w', encoding='utf-8') as f:
        f.write(f"笔记本: {first_notebook['name']}\n")
        f.write(f"笔记本ID: {first_notebook['id']}\n")
        f.write(f"最大层级深度: {'无限制' if MAX_DEPTH == -1 else MAX_DEPTH}\n")
        f.write(f"总文档数: {len(all_docs_info)}\n")
        f.write(f"成功获取路径数: {len(doc_paths)}\n")
        f.write("=" * 60 + "\n\n")

        # 保存可视化树结构
        save_visual_tree(tree, f)

    # 保存路径解析结果（文档ID和路径的映射）
    paths_file = output_dir / f"doc_paths_{first_notebook['name']}.json"
    with paths_file.open('w', encoding='utf-8') as f:
        json.dump(doc_paths, f, ensure_ascii=False, indent=2)

            # 打印路径解析统计信息
    print(f"\n=== 路径解析统计 ===")
    print(f"总文档数: {len(all_doc_ids)}")
    print(f"成功获取路径的文档数: {len(doc_paths)}")
    print(f"未获取到路径的文档数: {len(all_doc_ids) - len(doc_paths)}")

    # 统计路径深度分布
    depth_distribution = {}
    for doc in all_docs_info:
        depth = doc['level']
        depth_distribution[depth] = depth_distribution.get(depth, 0) + 1

    print(f"\n=== 层级深度分布 ===")
    for depth in sorted(depth_distribution.keys()):
        print(f"第{depth}层: {depth_distribution[depth]}个文档")

    print(f"\n文档树结构已保存到: {output_file}")
    print(f"文档信息已保存到: {docs_info_file}")
    print(f"可视化文档树已保存到: {visual_file}")
    print(f"文档名称列表已保存到: {names_file}")
    print(f"路径解析结果已保存到: {paths_file}")

else:
    print("获取文档树失败，尝试使用SQL查询...")

    # 备用方案：使用SQL查询获取文档列表
    sql_query = f"SELECT id, content, hpath FROM blocks WHERE box = '{first_notebook['id']}' AND type = 'd' ORDER BY created"

    sql_result = call_siyuan_api("/api/query/sql", {"stmt": sql_query})

    if sql_result:
        print(f"通过SQL查询找到 {len(sql_result)} 个文档:")
        print("-" * 60)

        for doc in sql_result:
            print(f"📄 {doc.get('content', '无标题')}")
            print(f"   ID: {doc.get('id', '')}")
            print(f"   路径: {doc.get('hpath', '')}")
            print("-" * 40)

        # 保存SQL查询结果
        output_dir = Path("output")
        output_dir.mkdir(exist_ok=True)
        sql_output_file = output_dir / f"docs_sql_{first_notebook['name']}.json"
        with sql_output_file.open('w', encoding='utf-8') as f:
            json.dump(sql_result, f, ensure_ascii=False, indent=2)

        print(f"SQL查询结果已保存到: {sql_output_file}")
    else:
        print("SQL查询也失败了")
# Out:
# 正在获取笔记本 '剪藏笔记本' 下的文档列表...
# 笔记本ID: 20250618232716-bvztpaf
# 最大层级深度: 3
# ------------------------------------------------------------
# 找到 3 个根文档/文件夹:
#
# 正在收集指定深度内的文档ID...
# 收集到 6945 个文档ID
# 正在批量获取文档路径...
# 成功获取 6945 个文档的路径
# 📁 Web收集箱
#    📍 ID: 20250614230655-rw72vei
#    📂 路径: /Web收集箱
# ├── 📄 PromptPilot：提示词优化工程终结者？
#        📍 ID: 20250615144650-fneylg8
#        📂 路径: /Web收集箱/PromptPilot：提示词优化工程终结者？
#
# ├── 📁 思源笔记使用技巧
#        📍 ID: 20250621071829-zjnz7iu
#        📂 路径: /Web收集箱/思源笔记使用技巧
# │   ├── 📄 想省大钱？思源笔记第三方同步 S3 手把手教程（使用七牛云对象存储 Kodo）（2024.4.25）
# │          📍 ID: 20250615083750-vl9nn96
# │          📂 路径: /Web收集箱/思源笔记使用技巧/想省大钱？思源笔记第三方同步 S3 手把手教程（使用七牛云对象存储 Kodo）（2024.4.25）
#
# │   ├── 📄 SQL 小助手
# │          📍 ID: 20250615093833-odybz7u
# │          📂 路径: /Web收集箱/思源笔记使用技巧/SQL 小助手
#
# │   ├── 📄 阶梯式动态数据库：SuperRef 与动态数据库应用初探
# │          📍 ID: 20250615094744-4laa9uh
# │          📂 路径: /Web收集箱/思源笔记使用技巧/阶梯式动态数据库：SuperRef 与动态数据库应用初探
#
# │   ├── 📄 插件开发 Quick Start
# │          📍 ID: 20250615094808-r6lumo0
# │          📂 路径: /Web收集箱/思源笔记使用技巧/插件开发 Quick Start
#
# │   ├── 📄 双链工作流个人使用经验
# │          📍 ID: 20250615094848-48y9qob
# │          📂 路径: /Web收集箱/思源笔记使用技巧/双链工作流个人使用经验
#
# │   ├── 📄 思源模板功能新人指南：模板语法 + 函数 + md 块语法
# │          📍 ID: 20250615095056-r5qkumk
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源模板功能新人指南：模板语法 + 函数 + md 块语法
#
# │   ├── 📄 思源笔记数据库使用新思路：谈自上而下管理与自下而上积累
# │          📍 ID: 20250615095225-qldhxa9
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源笔记数据库使用新思路：谈自上而下管理与自下而上积累
#
# │   ├── 📄 第二次漫游：双链、xanadu 与渐进学习
# │          📍 ID: 20250615095304-b7icfhs
# │          📂 路径: /Web收集箱/思源笔记使用技巧/第二次漫游：双链、xanadu 与渐进学习
#
# │   ├── 📄 手机伺服经验帖汇总（持续更新）
# │          📍 ID: 20250615095350-3x0dafe
# │          📂 路径: /Web收集箱/思源笔记使用技巧/手机伺服经验帖汇总（持续更新）
#
# │   ├── 📄 基于思源笔记的数据库使用分享 (附模板)
# │          📍 ID: 20250615095443-fldjrhe
# │          📂 路径: /Web收集箱/思源笔记使用技巧/基于思源笔记的数据库使用分享 (附模板)
#
# │   ├── 📄 Notion 的本地平替！思源笔记 v3.0 发布!
# │          📍 ID: 20250615095639-1er7psz
# │          📂 路径: /Web收集箱/思源笔记使用技巧/Notion 的本地平替！思源笔记 v3.0 发布!
#
# │   ├── 📄 数据库功能简介
# │          📍 ID: 20250615095711-j7uhpaj
# │          📂 路径: /Web收集箱/思源笔记使用技巧/数据库功能简介
#
# │   ├── 📄 基于思源笔记的写作、管理和分发流程
# │          📍 ID: 20250615095824-037we84
# │          📂 路径: /Web收集箱/思源笔记使用技巧/基于思源笔记的写作、管理和分发流程
#
# │   ├── 📄 (硬核向) 自制思源笔记微信收集箱搭建教程
# │          📍 ID: 20250615100436-wfn97qh
# │          📂 路径: /Web收集箱/思源笔记使用技巧/(硬核向) 自制思源笔记微信收集箱搭建教程
#
# │   ├── 📄 思源笔记用户常见问题（25 年 5 月 21 日更新 Mac 获取内核问题）
# │          📍 ID: 20250615100613-tcd0eo5
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源笔记用户常见问题（25 年 5 月 21 日更新 Mac 获取内核问题）
#
# │   ├── 📄 分享常用的思源笔记插件
# │          📍 ID: 20250615100811-pw6f9ms
# │          📂 路径: /Web收集箱/思源笔记使用技巧/分享常用的思源笔记插件
#
# │   ├── 📄 转移引用功能使用详解
# │          📍 ID: 20250615100935-wawm0gl
# │          📂 路径: /Web收集箱/思源笔记使用技巧/转移引用功能使用详解
#
# │   ├── 📄 思源 SQL 新人指南：SQL 语法 + Query + 模板
# │          📍 ID: 20250615100952-0z23t27
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源 SQL 新人指南：SQL 语法 + Query + 模板
#
# │   ├── 📄 思源笔记快乐手册 3.0 （新手指南）
# │          📍 ID: 20250615101729-5lgp8da
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源笔记快乐手册 3.0 （新手指南）
#
# │   ├── 📄 思源 CSS 主题修改常见问题与教程
# │          📍 ID: 20250615102022-xbug89v
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源 CSS 主题修改常见问题与教程
#
# │   ├── 📄 [js] 简单 AI 翻译，思源也有沉浸式翻译了
# │          📍 ID: 20250615102137-stln9sa
# │          📂 路径: /Web收集箱/思源笔记使用技巧/[js] 简单 AI 翻译，思源也有沉浸式翻译了
#
# │   ├── 📄 思源笔记同步指南
# │          📍 ID: 20250615102835-pt5ghay
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源笔记同步指南
#
# │   ├── 📄 性能优化 (Duplicated 2025-06-17 22:27:13)
# │          📍 ID: 20250617222713-h8myqdp
# │          📂 路径: /Web收集箱/思源笔记使用技巧/性能优化 (Duplicated 2025-06-17 22:27:13)
#
# │   ├── 📄 思源笔记同步指南
# │          📍 ID: 20250620235552-ye8as7h
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源笔记同步指南
#
# │   ├── 📄 思源API
# │          📍 ID: 20250621080513-0ydpceq
# │          📂 路径: /Web收集箱/思源笔记使用技巧/思源API
#
#
#
# 📁 兴趣爱好
#    📍 ID: 20250618232801-v1mh3n0
#    📂 路径: /兴趣爱好
# ├── 📁 AIGC
#        📍 ID: 20250618232802-7oa0kgz
#        📂 路径: /兴趣爱好/AIGC
# │   ├── 📄 11 个最热门的 MCP 资源平台，收藏备用！.md
# │          📍 ID: 20250618232803-0rve7kw
# │          📂 路径: /兴趣爱好/AIGC/11 个最热门的 MCP 资源平台，收藏备用！.md
#
# │   ├── 📄 02.10
# │          📍 ID: 20250618232803-1gjrh54
# │          📂 路径: /兴趣爱好/AIGC/02.10
#
# │   ├── 📄 1亿美元收入却只有11个员工！Midjourney是怎样炼成的？
# │          📍 ID: 20250618232803-1w89gzl
# │          📂 路径: /兴趣爱好/AIGC/1亿美元收入却只有11个员工！Midjourney是怎样炼成的？
#
# │   ├── 📄 1分钟搞定！Python超速工具uv换国内镜像，下载速度飙升10倍.md
# │          📍 ID: 20250618232803-2gvo2gj
# │          📂 路径: /兴趣爱好/AIGC/1分钟搞定！Python超速工具uv换国内镜像，下载速度飙升10倍.md
#
# │   ├── 📄 10月AI 新产品盘点，大家都做的太酷辣！
# │          📍 ID: 20250618232803-3inp25a
# │          📂 路径: /兴趣爱好/AIGC/10月AI 新产品盘点，大家都做的太酷辣！
#
# │   ├── 📄 03.10.25_ 被 AI 折叠的组织
# │          📍 ID: 20250618232803-5plcnnc
# │          📂 路径: /兴趣爱好/AIGC/03.10.25_ 被 AI 折叠的组织
#
# │   ├── 📄 100个思维模型提示词（1-50）
# │          📍 ID: 20250618232803-5v1e3jp
# │          📂 路径: /兴趣爱好/AIGC/100个思维模型提示词（1-50）
#
# │   ├── 📄 1个人60小时做1款游戏，AI游戏的新时代要来了！
# │          📍 ID: 20250618232803-6h364mb
# │          📂 路径: /兴趣爱好/AIGC/1个人60小时做1款游戏，AI游戏的新时代要来了！
#
# │   ├── 📄 05.05
# │          📍 ID: 20250618232803-aaf26ab
# │          📂 路径: /兴趣爱好/AIGC/05.05
#
# │   ├── 📄 17岁高中生写了个神级Prompt，直接把Claude强化成了满血o1。
# │          📍 ID: 20250618232803-bk7jbbh
# │          📂 路径: /兴趣爱好/AIGC/17岁高中生写了个神级Prompt，直接把Claude强化成了满血o1。
#
# │   ├── 📄 (万字)手搓智能体的这一年—AI应用经验分享
# │          📍 ID: 20250618232803-bs0yczh
# │          📂 路径: /兴趣爱好/AIGC/(万字)手搓智能体的这一年—AI应用经验分享
#
# │   ├── 📄 (6) SDXL Various Styles keywords
# │          📍 ID: 20250618232803-cpeti5v
# │          📂 路径: /兴趣爱好/AIGC/(6) SDXL Various Styles keywords
#
# │   ├── 📄 10 天硅谷行，我看到了这些趋势
# │          📍 ID: 20250618232803-d6ryirb
# │          📂 路径: /兴趣爱好/AIGC/10 天硅谷行，我看到了这些趋势
#
# │   ├── 📄 10个重要理念详解LLM大语言模型工作原理.md
# │          📍 ID: 20250618232803-dwkqrrt
# │          📂 路径: /兴趣爱好/AIGC/10个重要理念详解LLM大语言模型工作原理.md
#
# │   ├── 📄 1.6万字Rankify完全指南：三行代码搞定RAG，24种重排序方法任你选 | 全网最详细。
# │          📍 ID: 20250618232803-e5f67y0
# │          📂 路径: /兴趣爱好/AIGC/1.6万字Rankify完全指南：三行代码搞定RAG，24种重排序方法任你选 | 全网最详细。
#
# │   ├── 📄 13.7K star！免费接口合集，API 的搬运工，太香了！.md
# │          📍 ID: 20250618232803-js0qvxg
# │          📂 路径: /兴趣爱好/AIGC/13.7K star！免费接口合集，API 的搬运工，太香了！.md
#
# │   ├── 📄 10w人打出9.2高分！几乎每个人都哭着推荐的小说！
# │          📍 ID: 20250618232803-kk58pom
# │          📂 路径: /兴趣爱好/AIGC/10w人打出9.2高分！几乎每个人都哭着推荐的小说！
#
# │   ├── 📄 10条提示词包你测出「文生视频」成色；2024欧洲杯AI预测网站(还挺准；AI搜索版「苦涩的教训」 | ShowMeAI日报
# │          📍 ID: 20250618232803-mkkc7wc
# │          📂 路径: /兴趣爱好/AIGC/10条提示词包你测出「文生视频」成色；2024欧洲杯AI预测网站(还挺准；AI搜索版「苦涩的教训」 | ShowMeAI日报
#
# │   ├── 📄 1分钟学会制作“冰淇淋甜品地标图”, 5分钟学会制作流程.
# │          📍 ID: 20250618232803-qapfri8
# │          📂 路径: /兴趣爱好/AIGC/1分钟学会制作“冰淇淋甜品地标图”, 5分钟学会制作流程.
#
# │   ├── 📄 10大AI工具，助你成为超级个体.md
# │          📍 ID: 20250618232803-s7hb3pe
# │          📂 路径: /兴趣爱好/AIGC/10大AI工具，助你成为超级个体.md
#
# │   ├── 📄 1个小时、2条指令，我用ChatGPT画了一本24页的绘本！多图预警.md
# │          📍 ID: 20250618232803-sux7gy1
# │          📂 路径: /兴趣爱好/AIGC/1个小时、2条指令，我用ChatGPT画了一本24页的绘本！多图预警.md
#
# │   ├── 📄 100页深度：游戏厂商拥抱AIGC打法迥异，降本是果不是因.md
# │          📍 ID: 20250618232803-trpp6u2
# │          📂 路径: /兴趣爱好/AIGC/100页深度：游戏厂商拥抱AIGC打法迥异，降本是果不是因.md
#
# │   ├── 📄 10个最强大的游戏生成式AI工具.md
# │          📍 ID: 20250618232803-u28vzxb
# │          📂 路径: /兴趣爱好/AIGC/10个最强大的游戏生成式AI工具.md
#
# │   ├── 📄 10分钟！搭建一个本地MCP
# │          📍 ID: 20250618232803-uwnmme2
# │          📂 路径: /兴趣爱好/AIGC/10分钟！搭建一个本地MCP
#
# │   ├── 📄 02.10.25_ 超越“套壳”
# │          📍 ID: 20250618232803-vmh400f
# │          📂 路径: /兴趣爱好/AIGC/02.10.25_ 超越“套壳”
#
# │   ├── 📄 03.10
# │          📍 ID: 20250618232803-zd37iln
# │          📂 路径: /兴趣爱好/AIGC/03.10
#
# │   ├── 📄 1小时，用Windsurf，0代码基础完成flomo插件开发！全公开
# │          📍 ID: 20250618232803-zh5wt9r
# │          📂 路径: /兴趣爱好/AIGC/1小时，用Windsurf，0代码基础完成flomo插件开发！全公开
#
# │   ├── 📄 0基础用AI写APP，却拿下App Store付费榜第一，这是今年最有启发的AI故事
# │          📍 ID: 20250618232803-zl5hjn6
# │          📂 路径: /兴趣爱好/AIGC/0基础用AI写APP，却拿下App Store付费榜第一，这是今年最有启发的AI故事
#
# │   ├── 📄 05.05.25_ AI，从读心到织网
# │          📍 ID: 20250618232803-zqyynbw
# │          📂 路径: /兴趣爱好/AIGC/05.05.25_ AI，从读心到织网
#
# │   ├── 📄 2024年Product Hunt产品榜：Cursor年度最佳，众多AI产品上榜
# │          📍 ID: 20250618232804-0u3ubzv
# │          📂 路径: /兴趣爱好/AIGC/2024年Product Hunt产品榜：Cursor年度最佳，众多AI产品上榜
#
# │   ├── 📄 2024年了，造『论文解读』公众号，买个agent就够了……
# │          📍 ID: 20250618232804-14oqabk
# │          📂 路径: /兴趣爱好/AIGC/2024年了，造『论文解读』公众号，买个agent就够了……
#
# │   ├── 📄 1次搭建完胜1亿次编码，MCP硅谷疯传！Anthropic协议解锁智能体
# │          📍 ID: 20250618232804-3nkh2f5
# │          📂 路径: /兴趣爱好/AIGC/1次搭建完胜1亿次编码，MCP硅谷疯传！Anthropic协议解锁智能体
#
# │   ├── 📄 2024 年最完整的 AI Agents 清单来了，涉及 13 个领域，上百个 Agents！
# │          📍 ID: 20250618232804-6b4v5eh
# │          📂 路径: /兴趣爱好/AIGC/2024 年最完整的 AI Agents 清单来了，涉及 13 个领域，上百个 Agents！
#
# │   ├── 📄 2023年AIGC行业研究报告整理，一共110份，欢迎收藏
# │          📍 ID: 20250618232804-8oznnyn
# │          📂 路径: /兴趣爱好/AIGC/2023年AIGC行业研究报告整理，一共110份，欢迎收藏
#
# │   ├── 📄 1年赚1亿！YC CEO亲揭AI致富密码，10人也能做大生意
# │          📍 ID: 20250618232804-a1q8azs
# │          📂 路径: /兴趣爱好/AIGC/1年赚1亿！YC CEO亲揭AI致富密码，10人也能做大生意
#
# │   ├── 📄 2023年度AI设计实践报告发布！
# │          📍 ID: 20250618232804-bbpkp5h
# │          📂 路径: /兴趣爱好/AIGC/2023年度AI设计实践报告发布！
#
# │   ├── 📄 2023年最新GPT Plus和API开通攻略 .md
# │          📍 ID: 20250618232804-cf7vk2k
# │          📂 路径: /兴趣爱好/AIGC/2023年最新GPT Plus和API开通攻略 .md
#
# │   ├── 📄 2023年SaaS行业研究报告整理，一共92份，欢迎收藏！
# │          📍 ID: 20250618232804-d483tq3
# │          📂 路径: /兴趣爱好/AIGC/2023年SaaS行业研究报告整理，一共92份，欢迎收藏！
#
# │   ├── 📄 2024 年10个最佳 Midjourney 替代方案（免费和付费）-今日头条
# │          📍 ID: 20250618232804-f1471r4
# │          📂 路径: /兴趣爱好/AIGC/2024 年10个最佳 Midjourney 替代方案（免费和付费）-今日头条
#
# │   ├── 📄 2024年人工智能行业研究报告整理，一共43份，欢迎收藏！（持续更新）
# │          📍 ID: 20250618232804-otb82ys
# │          📂 路径: /兴趣爱好/AIGC/2024年人工智能行业研究报告整理，一共43份，欢迎收藏！（持续更新）
#
# │   ├── 📄 2024 万字回顾：SaaS 不会被 AI 颠覆，而是加速鞭策
# │          📍 ID: 20250618232804-p4do35z
# │          📂 路径: /兴趣爱好/AIGC/2024 万字回顾：SaaS 不会被 AI 颠覆，而是加速鞭策
#
# │   ├── 📄 2023年中国AI大模型市场研究报告（迈向通用人工智能）.md
# │          📍 ID: 20250618232804-pxod051
# │          📂 路径: /兴趣爱好/AIGC/2023年中国AI大模型市场研究报告（迈向通用人工智能）.md
#
# │   ├── 📄 2.5次元篇）-今日头条
# │          📍 ID: 20250618232804-spr8vc1
# │          📂 路径: /兴趣爱好/AIGC/Stable Diffusion 爆款人气模型评测（2/2.5次元篇）-今日头条
#
# │   ├── 📄 2024年国内最好用的免费AI软件.md
# │          📍 ID: 20250618232804-wri0zv1
# │          📂 路径: /兴趣爱好/AIGC/2024年国内最好用的免费AI软件.md
#
# │   ├── 📄 2024，我追过的 AI 风口
# │          📍 ID: 20250618232805-1e64rsi
# │          📂 路径: /兴趣爱好/AIGC/2024，我追过的 AI 风口
#
# │   ├── 📄 20亿美金的AI招聘独角兽Mercor：月增速50%、净留存100%、41%代码来自AI
# │          📍 ID: 20250618232805-27srxw9
# │          📂 路径: /兴趣爱好/AIGC/20亿美金的AI招聘独角兽Mercor：月增速50%、净留存100%、41%代码来自AI
#
# │   ├── 📄 2024打工人现状：四面AI歌；世界冠军独特的提示词技巧；我和AI谈恋爱了；谁能救救我的AI产品留存率 | ShowMeAI日报
# │          📍 ID: 20250618232805-3ft4h77
# │          📂 路径: /兴趣爱好/AIGC/2024打工人现状：四面AI歌；世界冠军独特的提示词技巧；我和AI谈恋爱了；谁能救救我的AI产品留存率 | ShowMeAI日报
#
# │   ├── 📄 20个中国大模型盘点：多个开源项目，允许商业化
# │          📍 ID: 20250618232805-7du9281
# │          📂 路径: /兴趣爱好/AIGC/20个中国大模型盘点：多个开源项目，允许商业化
#
# │   ├── 📄 2025 最新 AI Voice Agent 研究与图谱
# │          📍 ID: 20250618232805-7khkojx
# │          📂 路径: /兴趣爱好/AIGC/2025 最新 AI Voice Agent 研究与图谱
#
# │   ├── 📄 2024年度AI搜索产品对比解析：找到最适合你的搜索工具 - 飞书云文档
# │          📍 ID: 20250618232805-9nvodrc
# │          📂 路径: /兴趣爱好/AIGC/2024年度AI搜索产品对比解析：找到最适合你的搜索工具 - 飞书云文档
#
# │   ├── 📄 264页智能体综述来了！MetaGPT等20家顶尖机构、47位学者参与
# │          📍 ID: 20250618232805-9z8u6fl
# │          📂 路径: /兴趣爱好/AIGC/264页智能体综述来了！MetaGPT等20家顶尖机构、47位学者参与
#
# │   ├── 📄 2024年，出海做得好的AI产品有哪些共识与反共识？
# │          📍 ID: 20250618232805-a6gtxqs
# │          📂 路径: /兴趣爱好/AIGC/2024年，出海做得好的AI产品有哪些共识与反共识？
#
# │   ├── 📄 25个AI在一个小镇里过日子！斯坦福的实验价值可能超乎想象！
# │          📍 ID: 20250618232805-anpdd4q
# │          📂 路径: /兴趣爱好/AIGC/25个AI在一个小镇里过日子！斯坦福的实验价值可能超乎想象！
#
# │   ├── 📄 2024年度AI十大趋势报告：AI如何影响文化产业
# │          📍 ID: 20250618232805-b8uy4l6
# │          📂 路径: /兴趣爱好/AIGC/2024年度AI十大趋势报告：AI如何影响文化产业
#
# │   ├── 📄 264页 Agent 综述！MetaGPT、Mila、斯坦福、耶鲁、谷歌半年共同撰写
# │          📍 ID: 20250618232805-e1tsb92
# │          📂 路径: /兴趣爱好/AIGC/264页 Agent 综述！MetaGPT、Mila、斯坦福、耶鲁、谷歌半年共同撰写
#
# │   ├── 📄 23.10.12_马丁的Character.AI 赛道说明书
# │          📍 ID: 20250618232805-ginwil6
# │          📂 路径: /兴趣爱好/AIGC/23.10.12_马丁的Character.AI 赛道说明书
#
# │   ├── 📄 20组Prompt带你快速入门Midjourney-今日头条
# │          📍 ID: 20250618232805-i5ijbny
# │          📂 路径: /兴趣爱好/AIGC/20组Prompt带你快速入门Midjourney-今日头条
#
# │   ├── 📄 2024视觉模型鏖战：谁在吆喝？谁在赚钱？
# │          📍 ID: 20250618232805-jft6opc
# │          📂 路径: /兴趣爱好/AIGC/2024视觉模型鏖战：谁在吆喝？谁在赚钱？
#
# │   ├── 📄 2024诺奖颁奖现场，AI之父Hinton演讲：当AI已经开始理解人类的喜好和情绪（附视频）
# │          📍 ID: 20250618232805-krd5ssg
# │          📂 路径: /兴趣爱好/AIGC/2024诺奖颁奖现场，AI之父Hinton演讲：当AI已经开始理解人类的喜好和情绪（附视频）
#
# │   ├── 📄 23.10.12_马丁的Character.AI 赛道说明书
# │          📍 ID: 20250618232805-l3toy0p
# │          📂 路径: /兴趣爱好/AIGC/23.10.12_马丁的Character.AI 赛道说明书
#
# │   ├── 📄 2万字巨献 精华汇集｜Claude 3 官方提示词手册全解析.md
# │          📍 ID: 20250618232805-lvojzf6
# │          📂 路径: /兴趣爱好/AIGC/2万字巨献 精华汇集｜Claude 3 官方提示词手册全解析.md
#
# │   ├── 📄 20个群都来问我的AI早报，是这么做的。
# │          📍 ID: 20250618232805-mhsmwwy
# │          📂 路径: /兴趣爱好/AIGC/20个群都来问我的AI早报，是这么做的。
#
# │   ├── 📄 2024年消费电子行业研究报告整理，一共40份，欢迎收藏！（持续更新）
# │          📍 ID: 20250618232805-mlvxiso
# │          📂 路径: /兴趣爱好/AIGC/2024年消费电子行业研究报告整理，一共40份，欢迎收藏！（持续更新）
#
# │   ├── 📄 2万字长文，如何成为一个“懂”AI 的产品经理？
# │          📍 ID: 20250618232805-mxd4x9l
# │          📂 路径: /兴趣爱好/AIGC/2万字长文，如何成为一个“懂”AI 的产品经理？
#
# │   ├── 📄 27.4k star! TTS领域又一爆火的开源OpenVoice项目，文中实操效果炸裂，超逼真克隆！免费商用！！
# │          📍 ID: 20250618232805-n9dz3ap
# │          📂 路径: /兴趣爱好/AIGC/27.4k star! TTS领域又一爆火的开源OpenVoice项目，文中实操效果炸裂，超逼真克隆！免费商用！！
#
# │   ├── 📄 2个月涨粉10000+，多篇文章阅读过万！黄叔是如何在AI浪潮中找到清晰方向的？（内附“双杠杆”实践心得）
# │          📍 ID: 20250618232805-o7zdh32
# │          📂 路径: /兴趣爱好/AIGC/2个月涨粉10000+，多篇文章阅读过万！黄叔是如何在AI浪潮中找到清晰方向的？（内附“双杠杆”实践心得）
#
# │   ├── 📄 2025 年 AI 十大趋势：范式转移，变局正当时
# │          📍 ID: 20250618232805-ob4tel5
# │          📂 路径: /兴趣爱好/AIGC/2025 年 AI 十大趋势：范式转移，变局正当时
#
# │   ├── 📄 2024年新质生产力研究报告整理，一共43份，欢迎收藏！（持续更新）
# │          📍 ID: 20250618232805-ozke8hx
# │          📂 路径: /兴趣爱好/AIGC/2024年新质生产力研究报告整理，一共43份，欢迎收藏！（持续更新）
#
# │   ├── 📄 26个大模型prompt技巧.md
# │          📍 ID: 20250618232805-rbzgkz1
# │          📂 路径: /兴趣爱好/AIGC/26个大模型prompt技巧.md
#
# │   ├── 📄 23K Star开源生产力工具！从此告别图片模糊，马赛克.md
# │          📍 ID: 20250618232805-t8x13ya
# │          📂 路径: /兴趣爱好/AIGC/23K Star开源生产力工具！从此告别图片模糊，马赛克.md
#
# │   ├── 📄 2024年手游行业行业研究报告整理，一共31份，欢迎收藏！（持续更新）
# │          📍 ID: 20250618232805-x3ffivf
# │          📂 路径: /兴趣爱好/AIGC/2024年手游行业行业研究报告整理，一共31份，欢迎收藏！（持续更新）
#
# │   ├── 📄 4.1k star! FishSpeech1.2重磅开源,目前中文开源TTS效果最好！手把手带你进行部署推理复现官方demo！
# │          📍 ID: 20250618232806-0p0j3hv
# │          📂 路径: /兴趣爱好/AIGC/4.1k star! FishSpeech1.2重磅开源,目前中文开源TTS效果最好！手把手带你进行部署推理复现官方demo！
#
# │   ├── 📄 3000字干货！五个章节深入掌握 Stable Cascade（附模型下载）.md
# │          📍 ID: 20250618232806-31mak1y
# │          📂 路径: /兴趣爱好/AIGC/3000字干货！五个章节深入掌握 Stable Cascade（附模型下载）.md
#
# │   ├── 📄 6.5亿美元！AI智能体最大收购案产品之父Jake Keller采访：垂域Agent是成为10亿独角兽的新机会，决定仅用48小时
# │          📍 ID: 20250618232806-3cxkpoy
# │          📂 路径: /兴趣爱好/AIGC/6.5亿美元！AI智能体最大收购案产品之父Jake Keller采访：垂域Agent是成为10亿独角兽的新机会，决定仅用48小时
#
# │   ├── 📄 5070Ti&70&80&5090D AIGC速度测评
# │          📍 ID: 20250618232806-4hr4g3b
# │          📂 路径: /兴趣爱好/AIGC/5070Ti&70&80&5090D AIGC速度测评
#
# │   ├── 📄 70年, 800个, 全球AI模型数据可视化 | ShowMeAI日报.md
# │          📍 ID: 20250618232806-86zn07v
# │          📂 路径: /兴趣爱好/AIGC/70年, 800个, 全球AI模型数据可视化 | ShowMeAI日报.md
#
# │   ├── 📄 5500万份职业拆解，揭示AI对哪些职业有威胁｜前哨
# │          📍 ID: 20250618232806-9bg49rz
# │          📂 路径: /兴趣爱好/AIGC/5500万份职业拆解，揭示AI对哪些职业有威胁｜前哨
#
# │   ├── 📄 360问答,总有你的答案 年轻人iPhone6拍照_360问答搜索
# │          📍 ID: 20250618232806-b0p68ib
# │          📂 路径: /兴趣爱好/AIGC/360问答,总有你的答案 年轻人iPhone6拍照_360问答搜索
#
# │   ├── 📄 60天1000万流量，AI字幕工具如何年赚百万美金？
# │          📍 ID: 20250618232806-bji3plt
# │          📂 路径: /兴趣爱好/AIGC/60天1000万流量，AI字幕工具如何年赚百万美金？
#
# │   ├── 📄 6000字+6个案例：写给普通人的MCP入门指南
# │          📍 ID: 20250618232806-boa0va2
# │          📂 路径: /兴趣爱好/AIGC/6000字+6个案例：写给普通人的MCP入门指南
#
# │   ├── 📄 2小时思想碰撞，10000字深度思考：人类会被AI淘汰吗？丨AGI之路02期
# │          📍 ID: 20250618232806-dqvpkvk
# │          📂 路径: /兴趣爱好/AIGC/2小时思想碰撞，10000字深度思考：人类会被AI淘汰吗？丨AGI之路02期
#
# │   ├── 📄 3分钟，把ChatGPT训练成一个小红书爆款写手，秒出文！-今日头条
# │          📍 ID: 20250618232806-dz6k3bi
# │          📂 路径: /兴趣爱好/AIGC/3分钟，把ChatGPT训练成一个小红书爆款写手，秒出文！-今日头条
#
# │   ├── 📄 54个Case，54只猫咪！Flowith Neo 用实力证明：Stop Chatting, Start Creating.
# │          📍 ID: 20250618232806-e1fr6z1
# │          📂 路径: /兴趣爱好/AIGC/54个Case，54只猫咪！Flowith Neo 用实力证明：Stop Chatting, Start Creating.
#
# │   ├── 📄 70万人争先体验！视频生成新王者「可灵AI」又双叒升级了
# │          📍 ID: 20250618232806-efuen2k
# │          📂 路径: /兴趣爱好/AIGC/70万人争先体验！视频生成新王者「可灵AI」又双叒升级了
#
# │   ├── 📄 4K Star! 这款开源edge-tts效果超过ChatTTS，支持粤语方言、陕西方言、台湾方言等语音合成，关键是还免费~
# │          📍 ID: 20250618232806-ellyyh3
# │          📂 路径: /兴趣爱好/AIGC/4K Star! 这款开源edge-tts效果超过ChatTTS，支持粤语方言、陕西方言、台湾方言等语音合成，关键是还免费~
#
# │   ├── 📄 3分钟，生成一份科学的可视化个性化健康报告及行动方案！Claude 4效果惊艳【附完整提示词】
# │          📍 ID: 20250618232806-g3mjl51
# │          📂 路径: /兴趣爱好/AIGC/3分钟，生成一份科学的可视化个性化健康报告及行动方案！Claude 4效果惊艳【附完整提示词】
#
# │   ├── 📄 3个ChatGPT插件自动写书爆火，更多躺着赚钱玩法可以问AI自己！.md
# │          📍 ID: 20250618232806-hfzcv6m
# │          📂 路径: /兴趣爱好/AIGC/3个ChatGPT插件自动写书爆火，更多躺着赚钱玩法可以问AI自己！.md
#
# │   ├── 📄 4.1k star! FishSpeech1.2重磅开源,目前中文开源TTS效果最好！手把手带你进行部署推理复现官方demo！
# │          📍 ID: 20250618232806-k0ql6wu
# │          📂 路径: /兴趣爱好/AIGC/4.1k star! FishSpeech1.2重磅开源,目前中文开源TTS效果最好！手把手带你进行部署推理复现官方demo！
#
# │   ├── 📄 30人，25亿美元卖身！大模型淘汰赛加速
# │          📍 ID: 20250618232806-kq3awih
# │          📂 路径: /兴趣爱好/AIGC/30人，25亿美元卖身！大模型淘汰赛加速
#
# │   ├── 📄 6000字解读：当前大语言模型LLM研究的10大挑战.md
# │          📍 ID: 20250618232806-kwq1702
# │          📂 路径: /兴趣爱好/AIGC/6000字解读：当前大语言模型LLM研究的10大挑战.md
#
# │   ├── 📄 75岁Hinton中国大会最新演讲「通往智能的两种道路」，最后感慨：我已经老了，未来交给年轻人
# │          📍 ID: 20250618232806-lz9ozbl
# │          📂 路径: /兴趣爱好/AIGC/75岁Hinton中国大会最新演讲「通往智能的两种道路」，最后感慨：我已经老了，未来交给年轻人
#
# │   ├── 📄 4款插件2个API，我把Cursor“迭代”成了满血超频版程序员
# │          📍 ID: 20250618232806-merre0c
# │          📂 路径: /兴趣爱好/AIGC/4款插件2个API，我把Cursor“迭代”成了满血超频版程序员
#
# │   ├── 📄 30分钟完成50张插画，阮佳大大的Ai绘画挑战.md
# │          📍 ID: 20250618232806-ngqe31l
# │          📂 路径: /兴趣爱好/AIGC/30分钟完成50张插画，阮佳大大的Ai绘画挑战.md
#
# │   ├── 📄 5分钟用AI搞定小红书灵感选题
# │          📍 ID: 20250618232806-nnpjvvc
# │          📂 路径: /兴趣爱好/AIGC/5分钟用AI搞定小红书灵感选题
#
# │   ├── 📄 6000字超详细复盘！南京 AIGC 城市宣传 MV 全流程制作解析.md
# │          📍 ID: 20250618232806-obeif4k
# │          📂 路径: /兴趣爱好/AIGC/6000字超详细复盘！南京 AIGC 城市宣传 MV 全流程制作解析.md
#
# │   ├── 📄 3个火火火的AI项目，开源了！.md
# │          📍 ID: 20250618232806-ppwt1yf
# │          📂 路径: /兴趣爱好/AIGC/3个火火火的AI项目，开源了！.md
#
# │   ├── 📄 3Blue1Brown 科普动画 · 图文版 (中文)：GPT 原理.md
# │          📍 ID: 20250618232806-slydfre
# │          📂 路径: /兴趣爱好/AIGC/3Blue1Brown 科普动画 · 图文版 (中文)：GPT 原理.md
#
# │   ├── 📄 7 款让人“上头”的开源小游戏
# │          📍 ID: 20250618232806-tugboui
# │          📂 路径: /兴趣爱好/AIGC/7 款让人“上头”的开源小游戏
#
# │   ├── 📄 4.4万亿美元！AI未来每年创收顶得上整个英国？｜前哨
# │          📍 ID: 20250618232806-u8qe5zu
# │          📂 路径: /兴趣爱好/AIGC/4.4万亿美元！AI未来每年创收顶得上整个英国？｜前哨
#
# │   ├── 📄 2套权威的AI术语表，从此拿捏术语翻译：机器之心+ GPT Academic + ChatPaper & 清华大学
# │          📍 ID: 20250618232806-xh0dfr5
# │          📂 路径: /兴趣爱好/AIGC/2套权威的AI术语表，从此拿捏术语翻译：机器之心+ GPT Academic + ChatPaper & 清华大学
#
# │   ├── 📄 4.2K star！Reor：AI自动帮你发现知识之间的连接.md
# │          📍 ID: 20250618232806-yc9beyv
# │          📂 路径: /兴趣爱好/AIGC/4.2K star！Reor：AI自动帮你发现知识之间的连接.md
#
# │   ├── 📄 5亿个token之后，我们得出关于GPT的七条宝贵经验
# │          📍 ID: 20250618232806-yfhx1hq
# │          📂 路径: /兴趣爱好/AIGC/5亿个token之后，我们得出关于GPT的七条宝贵经验
#
# │   ├── 📄 AI 一年过山车：从狂想到放下幻想丨晚点回望 2024 ⑤
# │          📍 ID: 20250618232807-0u9e3ht
# │          📂 路径: /兴趣爱好/AIGC/AI 一年过山车：从狂想到放下幻想丨晚点回望 2024 ⑤
#
# │   ├── 📄 AI 大模型创业，悄悄盯上年轻人最爱的「谷子经济」
# │          📍 ID: 20250618232807-2myfy9w
# │          📂 路径: /兴趣爱好/AIGC/AI 大模型创业，悄悄盯上年轻人最爱的「谷子经济」
#
# │   ├── 📄 AI Coding能撑起一个多大的叙事？
# │          📍 ID: 20250618232807-39cfrey
# │          📂 路径: /兴趣爱好/AIGC/AI Coding能撑起一个多大的叙事？
#
# │   ├── 📄 8款 stable diffusion 动漫二次元大模型.md
# │          📍 ID: 20250618232807-3b9j8b5
# │          📂 路径: /兴趣爱好/AIGC/8款 stable diffusion 动漫二次元大模型.md
#
# │   ├── 📄 A Deep Dive Into MCP and the Future of AI Tooling | Andreessen Horowitz
# │          📍 ID: 20250618232807-4e8bgp9
# │          📂 路径: /兴趣爱好/AIGC/A Deep Dive Into MCP and the Future of AI Tooling | Andreessen Horowitz
#
# │   ├── 📄 9月 AI 产品&模型.md
# │          📍 ID: 20250618232807-4susxjz
# │          📂 路径: /兴趣爱好/AIGC/9月 AI 产品&模型.md
#
# │   ├── 📄 8000 字，一文讲透prompt变现和职业化.md
# │          📍 ID: 20250618232807-5tjbstr
# │          📂 路径: /兴趣爱好/AIGC/8000 字，一文讲透prompt变现和职业化.md
#
# │   ├── 📄 AGI前夜的思考：2025年将出现真正的AI智能体，年轻人需要快速适应
# │          📍 ID: 20250618232807-66vf236
# │          📂 路径: /兴趣爱好/AIGC/AGI前夜的思考：2025年将出现真正的AI智能体，年轻人需要快速适应
#
# │   ├── 📄 AI 大爆炸后，寻找Agent 的“水和空气”
# │          📍 ID: 20250618232807-7brhvio
# │          📂 路径: /兴趣爱好/AIGC/AI 大爆炸后，寻找Agent 的“水和空气”
#
# │   ├── 📄 A16Z发布最报告！中国AI全球崛起，你准备好了吗？
# │          📍 ID: 20250618232807-8hslpu7
# │          📂 路径: /兴趣爱好/AIGC/A16Z发布最报告！中国AI全球崛起，你准备好了吗？
#
# │   ├── 📄 AI Python for Beginners - DeepLearning.AI
# │          📍 ID: 20250618232807-9twydqr
# │          📂 路径: /兴趣爱好/AIGC/AI Python for Beginners - DeepLearning.AI
#
# │   ├── 📄 AGI离我们还有多远？大模型不是最终解，世界模型才是未来
# │          📍 ID: 20250618232807-aa7hvub
# │          📂 路径: /兴趣爱好/AIGC/AGI离我们还有多远？大模型不是最终解，世界模型才是未来
#
# │   ├── 📄 @samu 总结的常见知识管理工具清单
# │          📍 ID: 20250618232807-adnpw5u
# │          📂 路径: /兴趣爱好/AIGC/@samu 总结的常见知识管理工具清单
#
# │   ├── 📄 AI Agents大爆发：软件2.0雏形初现，OpenAI的下一步 - 智源社区 和另外 6 个页面 - 用户1 - Microsoft​ Edge
# │          📍 ID: 20250618232807-b6mwk7h
# │          📂 路径: /兴趣爱好/AIGC/AI Agents大爆发：软件2.0雏形初现，OpenAI的下一步 - 智源社区 和另外 6 个页面 - 用户1 - Microsoft​ Edge
#
# │   ├── 📄 AI Agents大爆发：软件2.0雏形初现，OpenAI的下一步 和另外 3 个页面 - 用户1 - Microsoft​ Edge
# │          📍 ID: 20250618232807-cjkh3ti
# │          📂 路径: /兴趣爱好/AIGC/AI Agents大爆发：软件2.0雏形初现，OpenAI的下一步 和另外 3 个页面 - 用户1 - Microsoft​ Edge
#
# │   ├── 📄 AI Agent产品经理血泪史：一年来我摸过的那些石头【Tools篇】
# │          📍 ID: 20250618232807-g9sjq6y
# │          📂 路径: /兴趣爱好/AIGC/AI Agent产品经理血泪史：一年来我摸过的那些石头【Tools篇】
#
# │   ├── 📄 95后创业AI游戏陪玩，留存付费双高！已适配《黑神话》，团队全员二次元
# │          📍 ID: 20250618232807-gu9pv6d
# │          📂 路径: /兴趣爱好/AIGC/95后创业AI游戏陪玩，留存付费双高！已适配《黑神话》，团队全员二次元
#
# │   ├── 📄 AI 工具.md
# │          📍 ID: 20250618232807-j8hgohs
# │          📂 路径: /兴趣爱好/AIGC/AI 工具.md
#
# │   ├── 📄 AI Agent漫游指南
# │          📍 ID: 20250618232807-k0oz0hx
# │          📂 路径: /兴趣爱好/AIGC/AI Agent漫游指南
#
# │   ├── 📄 AI 做海报都这么厉害了？设计师不容错过的 DALL·E 3 进阶玩法.md
# │          📍 ID: 20250618232807-ko9fwrc
# │          📂 路径: /兴趣爱好/AIGC/AI 做海报都这么厉害了？设计师不容错过的 DALL·E 3 进阶玩法.md
#
# │   ├── 📄 A16Z最新分析，AI抓住医疗降价的5个命门！｜前哨
# │          📍 ID: 20250618232807-kpnwb08
# │          📂 路径: /兴趣爱好/AIGC/A16Z最新分析，AI抓住医疗降价的5个命门！｜前哨
#
# │   ├── 📄 AI Agent技术的最新进展-Agent框架推荐.md
# │          📍 ID: 20250618232807-kzuod23
# │          📂 路径: /兴趣爱好/AIGC/AI Agent技术的最新进展-Agent框架推荐.md
#
# │   ├── 📄 8.3K Stars!《多模态大语言模型综述》重大升级.md
# │          📍 ID: 20250618232807-l5j0sk6
# │          📂 路径: /兴趣爱好/AIGC/8.3K Stars!《多模态大语言模型综述》重大升级.md
#
# │   ├── 📄 AI Agent调研-7种Agent框架对比！大家都在用Agent做什么？.md
# │          📍 ID: 20250618232807-lherog4
# │          📂 路径: /兴趣爱好/AIGC/AI Agent调研-7种Agent框架对比！大家都在用Agent做什么？.md
#
# │   ├── 📄 AI Engineer  | ShowMeAI日报.md
# │          📍 ID: 20250618232807-m3dm4dx
# │          📂 路径: /兴趣爱好/AIGC/AI Engineer  | ShowMeAI日报.md
#
# │   ├── 📄 AI 大神Karpathy再发LLM入门介绍视频，入门必看！
# │          📍 ID: 20250618232807-ng14lod
# │          📂 路径: /兴趣爱好/AIGC/AI 大神Karpathy再发LLM入门介绍视频，入门必看！
#
# │   ├── 📄 AGI万字长文(上) | 2023回顾与反思.md
# │          📍 ID: 20250618232807-o91nekg
# │          📂 路径: /兴趣爱好/AIGC/AGI万字长文(上) | 2023回顾与反思.md
#
# │   ├── 📄 9个AI绘画Prompt，让你轻松变身AI艺术家！.md
# │          📍 ID: 20250618232807-ppb23ys
# │          📂 路径: /兴趣爱好/AIGC/9个AI绘画Prompt，让你轻松变身AI艺术家！.md
#
# │   ├── 📄 AI 产品和服务推荐.md
# │          📍 ID: 20250618232807-rh7pl2o
# │          📂 路径: /兴趣爱好/AIGC/AI 产品和服务推荐.md
#
# │   ├── 📄 AI 应用的UX设计.md
# │          📍 ID: 20250618232807-u69p7yl
# │          📂 路径: /兴趣爱好/AIGC/AI 应用的UX设计.md
#
# │   ├── 📄 8月份AI应用月活盘点，离超级应用有多远？ChatGPT还有机会吗？
# │          📍 ID: 20250618232807-utqhj4j
# │          📂 路径: /兴趣爱好/AIGC/8月份AI应用月活盘点，离超级应用有多远？ChatGPT还有机会吗？
#
# │   ├── 📄 AI Agent 产品经理血泪史（二）-欲知方圆，则必规矩【Workflow篇】
# │          📍 ID: 20250618232807-v96cgam
# │          📂 路径: /兴趣爱好/AIGC/AI Agent 产品经理血泪史（二）-欲知方圆，则必规矩【Workflow篇】
#
# │   ├── 📄 ACL 2023｜如何智能生成吸引人又符合实际的标题？
# │          📍 ID: 20250618232807-vhrldic
# │          📂 路径: /兴趣爱好/AIGC/ACL 2023｜如何智能生成吸引人又符合实际的标题？
#
# │   ├── 📄 AI Agent综合指南「2024」.md
# │          📍 ID: 20250618232807-x62q87t
# │          📂 路径: /兴趣爱好/AIGC/AI Agent综合指南「2024」.md
#
# │   ├── 📄 AGI产品经理知识手册精选（一）：深入浅出deepseek原理及黑客酷玩！
# │          📍 ID: 20250618232807-yriphl5
# │          📂 路径: /兴趣爱好/AIGC/AGI产品经理知识手册精选（一）：深入浅出deepseek原理及黑客酷玩！
#
# │   ├── 📄 A 3-step AI coding workflow for solo founders | Ryan Carson (5x founder)
# │          📍 ID: 20250618232807-zf7cn98
# │          📂 路径: /兴趣爱好/AIGC/A 3-step AI coding workflow for solo founders | Ryan Carson (5x founder)
#
# │   ├── 📄 AI Agent 将重塑游戏行业？.md
# │          📍 ID: 20250618232807-zm0hwkq
# │          📂 路径: /兴趣爱好/AIGC/AI Agent 将重塑游戏行业？.md
#
# │   ├── 📄 AI 系列(二)：大模型的应用需求，是解痛点还是蹭热点？
# │          📍 ID: 20250618232808-22yapvg
# │          📂 路径: /兴趣爱好/AIGC/AI 系列(二)：大模型的应用需求，是解痛点还是蹭热点？
#
# │   ├── 📄 AI 编程蓝皮书.md
# │          📍 ID: 20250618232808-2sqwwaq
# │          📂 路径: /兴趣爱好/AIGC/AI 编程蓝皮书.md
#
# │   ├── 📄 AI-Generated Art Won a Prize. Artists Aren’t Happy..md
# │          📍 ID: 20250618232808-35qsp17
# │          📂 路径: /兴趣爱好/AIGC/AI-Generated Art Won a Prize. Artists Aren’t Happy..md
#
# │   ├── 📄 AI 编程的能与不能
# │          📍 ID: 20250618232808-crfmdsj
# │          📂 路径: /兴趣爱好/AIGC/AI 编程的能与不能
#
# │   ├── 📄 AI-native 应用长什么样？
# │          📍 ID: 20250618232808-e0a6o20
# │          📂 路径: /兴趣爱好/AIGC/AI-native 应用长什么样？
#
# │   ├── 📄 AI 影响最大的行业？LLM 如何让教育产品化
# │          📍 ID: 20250618232808-f8lgwlw
# │          📂 路径: /兴趣爱好/AIGC/AI 影响最大的行业？LLM 如何让教育产品化
#
# │   ├── 📄 AI 虚拟陪伴一年谈
# │          📍 ID: 20250618232808-fry3341
# │          📂 路径: /兴趣爱好/AIGC/AI 虚拟陪伴一年谈
#
# │   ├── 📄 AIGC Weekly
# │          📍 ID: 20250618232808-g2ggk5l
# │          📂 路径: /兴趣爱好/AIGC/AIGC Weekly
#
# │   ├── 📄 AIGC Weekly
# │          📍 ID: 20250618232808-hcogqlt
# │          📂 路径: /兴趣爱好/AIGC/AIGC Weekly
#
# │   ├── 📄 AIGC之AI绘画行业发展研究报告（2023）.md
# │          📍 ID: 20250618232808-hogiq7l
# │          📂 路径: /兴趣爱好/AIGC/AIGC之AI绘画行业发展研究报告（2023）.md
#
# │   ├── 📄 AI 绘图：用Stable Difussion还原金庸小说场景.md
# │          📍 ID: 20250618232808-ihwr8ge
# │          📂 路径: /兴趣爱好/AIGC/AI 绘图：用Stable Difussion还原金庸小说场景.md
#
# │   ├── 📄 AI 无法替代的工作们｜见知录 Vol.003 - 飞书云文档
# │          📍 ID: 20250618232808-p908fby
# │          📂 路径: /兴趣爱好/AIGC/AI 无法替代的工作们｜见知录 Vol.003 - 飞书云文档
#
# │   ├── 📄 AI 编程+：bolt.new.md
# │          📍 ID: 20250618232808-pgtqh1d
# │          📂 路径: /兴趣爱好/AIGC/AI 编程+：bolt.new.md
#
# │   ├── 📄 AIGC 汇总贴
# │          📍 ID: 20250618232808-sss9t1n
# │          📂 路径: /兴趣爱好/AIGC/AIGC 汇总贴
#
# │   ├── 📄 AI 系列(一)：一文说透AI产品经理的底牌和命门
# │          📍 ID: 20250618232808-y6m738m
# │          📂 路径: /兴趣爱好/AIGC/AI 系列(一)：一文说透AI产品经理的底牌和命门
#
# │   ├── 📄 AIGC视频生成趋势报告（上篇）：行业概况与国际产品评析
# │          📍 ID: 20250618232808-yfimjp7
# │          📂 路径: /兴趣爱好/AIGC/AIGC视频生成趋势报告（上篇）：行业概况与国际产品评析
#
# │   ├── 📄 AI将玩转3A大作，OpenAI将被调查？2023 AI全景报告给出十大预测
# │          📍 ID: 20250618232809-0ns7bk1
# │          📂 路径: /兴趣爱好/AIGC/AI将玩转3A大作，OpenAI将被调查？2023 AI全景报告给出十大预测
#
# │   ├── 📄 AI将如何改变我们的生活？这5本书帮你率先洞悉未来！
# │          📍 ID: 20250618232809-2k7596n
# │          📂 路径: /兴趣爱好/AIGC/AI将如何改变我们的生活？这5本书帮你率先洞悉未来！
#
# │   ├── 📄 AI变革的未来不是大模型，而是...｜万字精读
# │          📍 ID: 20250618232809-37carlp
# │          📂 路径: /兴趣爱好/AIGC/AI变革的未来不是大模型，而是...｜万字精读
#
# │   ├── 📄 AI产品商业模式 | ShowMeAI日报.md
# │          📍 ID: 20250618232809-3rx6nhn
# │          📂 路径: /兴趣爱好/AIGC/AI产品商业模式 | ShowMeAI日报.md
#
# │   ├── 📄 AI「视觉图灵」时代来了！字节OmniHuman，一张图配上音频，就能直接生成视频
# │          📍 ID: 20250618232809-5e6zd48
# │          📂 路径: /兴趣爱好/AIGC/AI「视觉图灵」时代来了！字节OmniHuman，一张图配上音频，就能直接生成视频
#
# │   ├── 📄 AI工程师的必背经典：The Bitter Lesson（苦涩的教训）
# │          📍 ID: 20250618232809-5rmyf4e
# │          📂 路径: /兴趣爱好/AIGC/AI工程师的必背经典：The Bitter Lesson（苦涩的教训）
#
# │   ├── 📄 AI应用路线图：可控性是最强路标.md
# │          📍 ID: 20250618232809-64foind
# │          📂 路径: /兴趣爱好/AIGC/AI应用路线图：可控性是最强路标.md
#
# │   ├── 📄 AI工具实践 | 拥抱AI，零基础开发小程序：我的职业边界突破
# │          📍 ID: 20250618232809-7nz2pmi
# │          📂 路径: /兴趣爱好/AIGC/AI工具实践 | 拥抱AI，零基础开发小程序：我的职业边界突破
#
# │   ├── 📄 AI如何重塑游戏与创作？我们和十几位行业创业者聊了聊｜五源小酒馆Vol.26
# │          📍 ID: 20250618232809-9p54zf9
# │          📂 路径: /兴趣爱好/AIGC/AI如何重塑游戏与创作？我们和十几位行业创业者聊了聊｜五源小酒馆Vol.26
#
# │   ├── 📄 AI开发实践，小白如何用5k行代码打造个人项目？（完整经验复盘 + Cursor 提效攻略）
# │          📍 ID: 20250618232809-cnxj8x1
# │          📂 路径: /兴趣爱好/AIGC/AI开发实践，小白如何用5k行代码打造个人项目？（完整经验复盘 + Cursor 提效攻略）
#
# │   ├── 📄 AI一键就能画漫画了？AI又换了个领域大杀特杀！.md
# │          📍 ID: 20250618232809-crwo6k6
# │          📂 路径: /兴趣爱好/AIGC/AI一键就能画漫画了？AI又换了个领域大杀特杀！.md
#
# │   ├── 📄 AIGC视频生成趋势报告（下篇）：国内产品评析与总结
# │          📍 ID: 20250618232809-dw6zllo
# │          📂 路径: /兴趣爱好/AIGC/AIGC视频生成趋势报告（下篇）：国内产品评析与总结
#
# │   ├── 📄 AI图片橡皮擦来了，清华&阿里合作推出「概念半透膜」模型，还能改头换面
# │          📍 ID: 20250618232809-e6eswki
# │          📂 路径: /兴趣爱好/AIGC/AI图片橡皮擦来了，清华&阿里合作推出「概念半透膜」模型，还能改头换面
#
# │   ├── 📄 AI在玩一种很新的艺术，700万网友在线围观，太酷炫了！
# │          📍 ID: 20250618232809-f1kzq6p
# │          📂 路径: /兴趣爱好/AIGC/AI在玩一种很新的艺术，700万网友在线围观，太酷炫了！
#
# │   ├── 📄 AI变革来了，颠覆和被颠覆，你选哪边儿？
# │          📍 ID: 20250618232809-fuzx37i
# │          📂 路径: /兴趣爱好/AIGC/AI变革来了，颠覆和被颠覆，你选哪边儿？
#
# │   ├── 📄 AI原生游戏：1001 Nights 和 Oasis，两个极端，哪种才是真正的 Native 方向？.md
# │          📍 ID: 20250618232809-grvobvz
# │          📂 路径: /兴趣爱好/AIGC/AI原生游戏：1001 Nights 和 Oasis，两个极端，哪种才是真正的 Native 方向？.md
#
# │   ├── 📄 AI创业全球化：开源、机遇和挑战｜五源小酒馆Vol.23【播客】
# │          📍 ID: 20250618232809-hvtpzjq
# │          📂 路径: /兴趣爱好/AIGC/AI创业全球化：开源、机遇和挑战｜五源小酒馆Vol.23【播客】
#
# │   ├── 📄 AI与教育，毁灭与新生（暨10.25上海高金AI碰撞局小记）
# │          📍 ID: 20250618232809-k35bu6a
# │          📂 路径: /兴趣爱好/AIGC/AI与教育，毁灭与新生（暨10.25上海高金AI碰撞局小记）
#
# │   ├── 📄 AI世界的魔法棒：扩散模型（Diffusion Models）究竟“神”在哪？
# │          📍 ID: 20250618232809-k3hax79
# │          📂 路径: /兴趣爱好/AIGC/AI世界的魔法棒：扩散模型（Diffusion Models）究竟“神”在哪？
#
# │   ├── 📄 AI下半场，聊一聊 Agent 本质与变革 | 大白话技术科普系列@Jomy
# │          📍 ID: 20250618232809-k4x467m
# │          📂 路径: /兴趣爱好/AIGC/AI下半场，聊一聊 Agent 本质与变革 | 大白话技术科普系列@Jomy
#
# │   ├── 📄 AI图角色一致不再是梦：Midjourney新功能详解与实操指南.md
# │          📍 ID: 20250618232809-l0pzcyb
# │          📂 路径: /兴趣爱好/AIGC/AI图角色一致不再是梦：Midjourney新功能详解与实操指南.md
#
# │   ├── 📄 AI实操课 | 创作小白如何使用AI工具链从0到1制作影视MV的工作流（保姆级）
# │          📍 ID: 20250618232809-l68dqew
# │          📂 路径: /兴趣爱好/AIGC/AI实操课 | 创作小白如何使用AI工具链从0到1制作影视MV的工作流（保姆级）
#
# │   ├── 📄 AI圈深夜王炸！OpenAI发最强GPT！但最重要的不是性能！
# │          📍 ID: 20250618232809-p1rd7yt
# │          📂 路径: /兴趣爱好/AIGC/AI圈深夜王炸！OpenAI发最强GPT！但最重要的不是性能！
#
# │   ├── 📄 AI原生应用：个人创意和生产力的新纪元
# │          📍 ID: 20250618232809-p6ttwku
# │          📂 路径: /兴趣爱好/AIGC/AI原生应用：个人创意和生产力的新纪元
#
# │   ├── 📄 AI应用爆款背后的真相：从Cursor到Arc，PMF决定生死的关键洞察 和另外 15 个页面 - 用户1 - Microsoft​ Edge
# │          📍 ID: 20250618232809-poba87o
# │          📂 路径: /兴趣爱好/AIGC/AI应用爆款背后的真相：从Cursor到Arc，PMF决定生死的关键洞察 和另外 15 个页面 - 用户1 - Microsoft​ Edge
#
# │   ├── 📄 AI变革的未来不是大模型，而是...｜万字精读
# │          📍 ID: 20250618232809-sxx0yxs
# │          📂 路径: /兴趣爱好/AIGC/AI变革的未来不是大模型，而是...｜万字精读
#
# │   ├── 📄 AI大模型时代，我们还要学习编程吗？
# │          📍 ID: 20250618232809-unymut0
# │          📂 路径: /兴趣爱好/AIGC/AI大模型时代，我们还要学习编程吗？
#
# │   ├── 📄 AI之外，互联网还在发生哪些变化?
# │          📍 ID: 20250618232809-wb3ly6m
# │          📂 路径: /兴趣爱好/AIGC/AI之外，互联网还在发生哪些变化?
#
# │   ├── 📄 AI工具，让8小时分析工作缩至5分钟：红杉资本采访OpenAI 的DeepResearch团队（附视频）
# │          📍 ID: 20250618232809-yv7w1lc
# │          📂 路径: /兴趣爱好/AIGC/AI工具，让8小时分析工作缩至5分钟：红杉资本采访OpenAI 的DeepResearch团队（附视频）
#
# │   ├── 📄 AI爆发年：从旧金山湾区 看创业者们如何搞钱、搞增长
# │          📍 ID: 20250618232810-8g1ytnu
# │          📂 路径: /兴趣爱好/AIGC/AI爆发年：从旧金山湾区 看创业者们如何搞钱、搞增长
#
# │   ├── 📄 AI最强图像分割工具来了：HQ-SAM，分离对象就这么简单！.md
# │          📍 ID: 20250618232810-8i0yqu3
# │          📂 路径: /兴趣爱好/AIGC/AI最强图像分割工具来了：HQ-SAM，分离对象就这么简单！.md
#
# │   ├── 📄 AI怎么让脸部更细致? 3个技巧告诉你.md
# │          📍 ID: 20250618232810-9luj3so
# │          📂 路径: /兴趣爱好/AIGC/AI怎么让脸部更细致? 3个技巧告诉你.md
#
# │   ├── 📄 AI独角兽抢着上岸大厂了？Transfomer作者创办的Character.AI 正式被谷歌收编！
# │          📍 ID: 20250618232810-a11e48v
# │          📂 路径: /兴趣爱好/AIGC/AI独角兽抢着上岸大厂了？Transfomer作者创办的Character.AI 正式被谷歌收编！
#
# │   ├── 📄 AI异类的信息源｜6个极为精准的海外信息渠道
# │          📍 ID: 20250618232810-aguhwd1
# │          📂 路径: /兴趣爱好/AIGC/AI异类的信息源｜6个极为精准的海外信息渠道
#
# │   ├── 📄 AI教育行业全景图最新版；可汗学院新书发布 | ShowMeAI日报.md
# │          📍 ID: 20250618232810-akyqop5
# │          📂 路径: /兴趣爱好/AIGC/AI教育行业全景图最新版；可汗学院新书发布 | ShowMeAI日报.md
#
# │   ├── 📄 AI战友来袭：《永劫无间》中的“最强辅助“与未来游戏革命
# │          📍 ID: 20250618232810-bc744hb
# │          📂 路径: /兴趣爱好/AIGC/AI战友来袭：《永劫无间》中的“最强辅助“与未来游戏革命
#
# │   ├── 📄 AI现场发了2万红包，打开了大模型Act时代
# │          📍 ID: 20250618232810-ei32m1i
# │          📂 路径: /兴趣爱好/AIGC/AI现场发了2万红包，打开了大模型Act时代
#
# │   ├── 📄 AI爆程序员失业潮！小扎正开发编程智能体，「中级程序员」剩最后一年？
# │          📍 ID: 20250618232810-euq81jq
# │          📂 路径: /兴趣爱好/AIGC/AI爆程序员失业潮！小扎正开发编程智能体，「中级程序员」剩最后一年？
#
# │   ├── 📄 AI持久战，怎么打？
# │          📍 ID: 20250618232810-h4a0ezx
# │          📂 路径: /兴趣爱好/AIGC/AI持久战，怎么打？
#
# │   ├── 📄 AI改造游戏业.md
# │          📍 ID: 20250618232810-i4k00wq
# │          📂 路径: /兴趣爱好/AIGC/AI改造游戏业.md
#
# │   ├── 📄 AI批量生成“书单号”视频：用AI读电子书+剪映，日更50条.md
# │          📍 ID: 20250618232810-k4okgyr
# │          📂 路径: /兴趣爱好/AIGC/AI批量生成“书单号”视频：用AI读电子书+剪映，日更50条.md
#
# │   ├── 📄 AI智库｜月度榜单🏆 （9 月） - 飞书云文档
# │          📍 ID: 20250618232810-kc6nonm
# │          📂 路径: /兴趣爱好/AIGC/AI智库｜月度榜单🏆 （9 月） - 飞书云文档
#
# │   ├── 📄 AI数据训AI，引发模型大崩溃！牛津剑桥最新研究，登上Nature发警告.md
# │          📍 ID: 20250618232810-mel6pf8
# │          📂 路径: /兴趣爱好/AIGC/AI数据训AI，引发模型大崩溃！牛津剑桥最新研究，登上Nature发警告.md
#
# │   ├── 📄 AI开源项目推荐.md
# │          📍 ID: 20250618232810-nuk8s6e
# │          📂 路径: /兴趣爱好/AIGC/AI开源项目推荐.md
#
# │   ├── 📄 AI杀疯了 | AI绘画发展历史全梳理
# │          📍 ID: 20250618232810-oll0s01
# │          📂 路径: /兴趣爱好/AIGC/AI杀疯了 | AI绘画发展历史全梳理
#
# │   ├── 📄 AI深度运用：一大波详情页设计.md
# │          📍 ID: 20250618232810-prjqo25
# │          📂 路径: /兴趣爱好/AIGC/AI深度运用：一大波详情页设计.md
#
# │   ├── 📄 AI正在让很多行业的红利消失.md
# │          📍 ID: 20250618232810-rz814cq
# │          📂 路径: /兴趣爱好/AIGC/AI正在让很多行业的红利消失.md
#
# │   ├── 📄 AI泡沫破裂，英伟达市值暴跌2万亿？ 英伟达不服输.md
# │          📍 ID: 20250618232810-s4g53za
# │          📂 路径: /兴趣爱好/AIGC/AI泡沫破裂，英伟达市值暴跌2万亿？ 英伟达不服输.md
#
# │   ├── 📄 AI智能体产品案例深度思考和分享（全球顶级公司实践细节，做AI智能体必读）
# │          📍 ID: 20250618232810-uki2iau
# │          📂 路径: /兴趣爱好/AIGC/AI智能体产品案例深度思考和分享（全球顶级公司实践细节，做AI智能体必读）
#
# │   ├── 📄 AI教父Hinton演讲视频：AI已具备主观体验，深入解析超越人类智能的关键路径
# │          📍 ID: 20250618232810-vnpl1uv
# │          📂 路径: /兴趣爱好/AIGC/AI教父Hinton演讲视频：AI已具备主观体验，深入解析超越人类智能的关键路径
#
# │   ├── 📄 AI文生图第一案！500块钱的官司！为啥引发外媒关注？
# │          📍 ID: 20250618232810-vtvujlj
# │          📂 路径: /兴趣爱好/AIGC/AI文生图第一案！500块钱的官司！为啥引发外媒关注？
#
# │   ├── 📄 AI智能体与人类的未来协作方式、合作组织与生产空间（万字长文）.md
# │          📍 ID: 20250618232810-wberpjp
# │          📂 路径: /兴趣爱好/AIGC/AI智能体与人类的未来协作方式、合作组织与生产空间（万字长文）.md
#
# │   ├── 📄 AI海洋中的海妖之歌：腾讯AI Lab大模型幻觉问题综述
# │          📍 ID: 20250618232810-xijfbhp
# │          📂 路径: /兴趣爱好/AIGC/AI海洋中的海妖之歌：腾讯AI Lab大模型幻觉问题综述
#
# │   ├── 📄 AI是不是搞错了方向？
# │          📍 ID: 20250618232810-zoiaj2w
# │          📂 路径: /兴趣爱好/AIGC/AI是不是搞错了方向？
#
# │   ├── 📄 AI硬件.md
# │          📍 ID: 20250618232811-03akrca
# │          📂 路径: /兴趣爱好/AIGC/AI硬件.md
#
# │   ├── 📄 AI绘图-Stable Diffusion进阶- Inpaint+ControlNet手部修复实战.md
# │          📍 ID: 20250618232811-29gqekn
# │          📂 路径: /兴趣爱好/AIGC/AI绘图-Stable Diffusion进阶- Inpaint+ControlNet手部修复实战.md
#
# │   ├── 📄 AI绘图之Midjourney手把手教程-完全入门指南-.md
# │          📍 ID: 20250618232811-6tyql7t
# │          📂 路径: /兴趣爱好/AIGC/AI绘图之Midjourney手把手教程-完全入门指南-.md
#
# │   ├── 📄 AI眼镜爆火！中国六大门派围攻Meta，真正大BOSS还未进场
# │          📍 ID: 20250618232811-ge55nhv
# │          📂 路径: /兴趣爱好/AIGC/AI眼镜爆火！中国六大门派围攻Meta，真正大BOSS还未进场
#
# │   ├── 📄 AI的尽头是美女，一句话生成你的专属“新垣结衣”，“我被美女包围”变为现实啦
# │          📍 ID: 20250618232811-h3zggqk
# │          📂 路径: /兴趣爱好/AIGC/AI的尽头是美女，一句话生成你的专属“新垣结衣”，“我被美女包围”变为现实啦
#
# │   ├── 📄 AI绘图-Vlad(Stable Diffusion)训练自己的LoRA模型实战（五）.md
# │          📍 ID: 20250618232811-htryd4t
# │          📂 路径: /兴趣爱好/AIGC/AI绘图-Vlad(Stable Diffusion)训练自己的LoRA模型实战（五）.md
#
# │   ├── 📄 AI生产实践 | 从梦境到游戏：Oasis的探索与未来潜力
# │          📍 ID: 20250618232811-lm2sofy
# │          📂 路径: /兴趣爱好/AIGC/AI生产实践 | 从梦境到游戏：Oasis的探索与未来潜力
#
# │   ├── 📄 AI研究的主要推动力会是什么？ChatGPT团队研究科学家：算力成本下降
# │          📍 ID: 20250618232811-paafci9
# │          📂 路径: /兴趣爱好/AIGC/AI研究的主要推动力会是什么？ChatGPT团队研究科学家：算力成本下降
#
# │   ├── 📄 AI画图如何保持风格一致？ - DALL·E 3绘图&风格一致性画图完整教学.md
# │          📍 ID: 20250618232811-pw377in
# │          📂 路径: /兴趣爱好/AIGC/AI画图如何保持风格一致？ - DALL·E 3绘图&风格一致性画图完整教学.md
#
# │   ├── 📄 AI生成图片版权首获司法认定，对大模型行业是利好吗？.md
# │          📍 ID: 20250618232811-q97e7t5
# │          📂 路径: /兴趣爱好/AIGC/AI生成图片版权首获司法认定，对大模型行业是利好吗？.md
#
# │   ├── 📄 AI眼镜众筹纪录，CES上爆火的Halliday做对了什么？
# │          📍 ID: 20250618232811-ufzv3zv
# │          📂 路径: /兴趣爱好/AIGC/刷新AR/AI眼镜众筹纪录，CES上爆火的Halliday做对了什么？
#
# │   ├── 📄 AI算力(上)|成本腰斩-英伟达-个人算力
# │          📍 ID: 20250618232811-ujb69cb
# │          📂 路径: /兴趣爱好/AIGC/AI算力(上)|成本腰斩-英伟达-个人算力
#
# │   ├── 📄 AI生图、扩图、去水印……全免费！「Sora 平替」Viva 玩了把大的.md
# │          📍 ID: 20250618232811-vzpxr16
# │          📂 路径: /兴趣爱好/AIGC/AI生图、扩图、去水印……全免费！「Sora 平替」Viva 玩了把大的.md
#
# │   ├── 📄 AI绘图-Stable Diffusion进阶- 光影控制实战.md
# │          📍 ID: 20250618232811-y2kpol4
# │          📂 路径: /兴趣爱好/AIGC/AI绘图-Stable Diffusion进阶- 光影控制实战.md
#
# │   ├── 📄 AI绘画-ComfyUI进阶-如何使用Lora、Embeddings增强控制.md
# │          📍 ID: 20250618232812-1uinumv
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-ComfyUI进阶-如何使用Lora、Embeddings增强控制.md
#
# │   ├── 📄 AI绘画中，Transformer的“自注意力机制”有什么作用？.md
# │          📍 ID: 20250618232812-6go523y
# │          📂 路径: /兴趣爱好/AIGC/AI绘画中，Transformer的“自注意力机制”有什么作用？.md
#
# │   ├── 📄 AI绘画.md
# │          📍 ID: 20250618232812-9bb047t
# │          📂 路径: /兴趣爱好/AIGC/30款好用AI工具合集！AI对话/AI写作/AI办公演示/AI绘画.md
#
# │   ├── 📄 AI绘画-Stable Diffusion进阶- ControlNet+Loopback手部修复.md
# │          📍 ID: 20250618232812-aoc34rx
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-Stable Diffusion进阶- ControlNet+Loopback手部修复.md
#
# │   ├── 📄 AI编码新神登基，藏师傅一手Claude 4实测
# │          📍 ID: 20250618232812-by3h0h3
# │          📂 路径: /兴趣爱好/AIGC/AI编码新神登基，藏师傅一手Claude 4实测
#
# │   ├── 📄 AI绘画-Stable Diffusion进阶- 循环输入（Loopback）实战换装.md
# │          📍 ID: 20250618232812-c6nqgfo
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-Stable Diffusion进阶- 循环输入（Loopback）实战换装.md
#
# │   ├── 📄 AI绘画神器 Fooocus 2.0 来啦！出图质量升级+新增4大实用功能！.md
# │          📍 ID: 20250618232812-h4jtz7r
# │          📂 路径: /兴趣爱好/AIGC/AI绘画神器 Fooocus 2.0 来啦！出图质量升级+新增4大实用功能！.md
#
# │   ├── 📄 AI绘画提示词技巧（2）：反向提词进阶.md
# │          📍 ID: 20250618232812-hrwz6fm
# │          📂 路径: /兴趣爱好/AIGC/AI绘画提示词技巧（2）：反向提词进阶.md
#
# │   ├── 📄 AI绘画-Stable Diffusion 进阶-常用的光影效果提示词.md
# │          📍 ID: 20250618232812-kyafg01
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-Stable Diffusion 进阶-常用的光影效果提示词.md
#
# │   ├── 📄 AI绘画神器 Controlnet 组合技-今日头条
# │          📍 ID: 20250618232812-l3ikiv6
# │          📂 路径: /兴趣爱好/AIGC/AI绘画神器 Controlnet 组合技-今日头条
#
# │   ├── 📄 AI绘画可控性研究与应用
# │          📍 ID: 20250618232812-ng2mgoz
# │          📂 路径: /兴趣爱好/AIGC/AI绘画可控性研究与应用
#
# │   ├── 📄 AI绘画-Stable Diffusion进阶- ControlNet向外扩展（Outpaint）.md
# │          📍 ID: 20250618232812-pjxti6f
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-Stable Diffusion进阶- ControlNet向外扩展（Outpaint）.md
#
# │   ├── 📄 AI绘画何以突飞猛进? 从历史到技术突破, 一文读懂火爆的AI绘画发展史.md
# │          📍 ID: 20250618232812-q4yk5eu
# │          📂 路径: /兴趣爱好/AIGC/AI绘画何以突飞猛进? 从历史到技术突破, 一文读懂火爆的AI绘画发展史.md
#
# │   ├── 📄 AI绘画教程：如何用Stable Diffusion始终画同一个人？.md
# │          📍 ID: 20250618232812-rsp97dp
# │          📂 路径: /兴趣爱好/AIGC/AI绘画教程：如何用Stable Diffusion始终画同一个人？.md
#
# │   ├── 📄 AI绘画神器Midjourney进阶手册：如何让生成的图片更加可控？.md
# │          📍 ID: 20250618232812-tu302qm
# │          📂 路径: /兴趣爱好/AIGC/AI绘画神器Midjourney进阶手册：如何让生成的图片更加可控？.md
#
# │   ├── 📄 AI绘图颠覆游戏业：你的648氪金，可能买了5分钟的AI作品？ .md
# │          📍 ID: 20250618232812-ud8bcnm
# │          📂 路径: /兴趣爱好/AIGC/AI绘图颠覆游戏业：你的648氪金，可能买了5分钟的AI作品？ .md
#
# │   ├── 📄 AI绘画-Stable Diffusion进阶- 实战photo bashing手法换装.md
# │          📍 ID: 20250618232812-wleg4ci
# │          📂 路径: /兴趣爱好/AIGC/AI绘画-Stable Diffusion进阶- 实战photo bashing手法换装.md
#
# │   ├── 📄 AI绘图最常用的十一个领域都在这篇了！.md
# │          📍 ID: 20250618232812-xetlh6v
# │          📂 路径: /兴趣爱好/AIGC/AI绘图最常用的十一个领域都在这篇了！.md
#
# │   ├── 📄 AI绘画Midjourney提示词prompt「每日分享」未来主义色彩（多图）-今日头条
# │          📍 ID: 20250618232812-yjr6hbh
# │          📂 路径: /兴趣爱好/AIGC/AI绘画Midjourney提示词prompt「每日分享」未来主义色彩（多图）-今日头条
#
# │   ├── 📄 AI绘画 - 因为新的control net插件，我放弃了另一个Ai绘画软件.md
# │          📍 ID: 20250618232812-zsyzouh
# │          📂 路径: /兴趣爱好/AIGC/AI绘画 - 因为新的control net插件，我放弃了另一个Ai绘画软件.md
#
# │   ├── 📄 AI自主智能体大盘点，构建、应用、评估全覆盖，人大高瓴文继荣等32页综述
# │          📍 ID: 20250618232813-0upyauv
# │          📂 路径: /兴趣爱好/AIGC/AI自主智能体大盘点，构建、应用、评估全覆盖，人大高瓴文继荣等32页综述
#
# │   ├── 📄 AI视频爆发式更新｜近半年值得关注的13个闭源产品动向
# │          📍 ID: 20250618232813-3gqidn1
# │          📂 路径: /兴趣爱好/AIGC/AI视频爆发式更新｜近半年值得关注的13个闭源产品动向
#
# │   ├── 📄 AI这样把NB写在脸上，它在玩一种很新的艺术.md
# │          📍 ID: 20250618232813-3tz3znf
# │          📂 路径: /兴趣爱好/AIGC/AI这样把NB写在脸上，它在玩一种很新的艺术.md
#
# │   ├── 📄 AI音乐生成工作流 - 飞书云文档.md
# │          📍 ID: 20250618232813-4bp56s4
# │          📂 路径: /兴趣爱好/AIGC/AI音乐生成工作流 - 飞书云文档.md
#
# │   ├── 📄 AI群星闪耀时 | 听说这轮人工智能又要凉凉？盘点八十年AI发展史高光时刻；2030年会是下一个人类发展奇点吗@ShowMeAI
# │          📍 ID: 20250618232813-9qk9gij
# │          📂 路径: /兴趣爱好/AIGC/AI群星闪耀时 | 听说这轮人工智能又要凉凉？盘点八十年AI发展史高光时刻；2030年会是下一个人类发展奇点吗@ShowMeAI
#
# │   ├── 📄 AI陪伴复盘：亚洲市场跑出营收黑马，分三大方向探索未来可能
# │          📍 ID: 20250618232813-b8qh93j
# │          📂 路径: /兴趣爱好/AIGC/AI陪伴复盘：亚洲市场跑出营收黑马，分三大方向探索未来可能
#
# │   ├── 📄 AI视频不再“默片”！谷歌Veo 3炸裂登场（附超全案例及提示词）🎬 🤫 - 飞书云文档
# │          📍 ID: 20250618232813-cdwyqqh
# │          📂 路径: /兴趣爱好/AIGC/AI视频不再“默片”！谷歌Veo 3炸裂登场（附超全案例及提示词）🎬 🤫 - 飞书云文档
#
# │   ├── 📄 AbletonMCP：实现Claude和Ableton交互制作音乐 - 飞书云文档
# │          📍 ID: 20250618232813-cwvco98
# │          📂 路径: /兴趣爱好/AIGC/AbletonMCP：实现Claude和Ableton交互制作音乐 - 飞书云文档
#
# │   ├── 📄 AI输出游戏角色设定方法
# │          📍 ID: 20250618232813-f4gtdya
# │          📂 路径: /兴趣爱好/AIGC/AI输出游戏角色设定方法
#
# │   ├── 📄 AI视频可控性里程碑更新：Runway上线多重运动笔刷
# │          📍 ID: 20250618232813-fdtaxdm
# │          📂 路径: /兴趣爱好/AIGC/AI视频可控性里程碑更新：Runway上线多重运动笔刷
#
# │   ├── 📄 AI角色扮演再进化，清华提出CharacterGLM，支持AI角色高度定制化
# │          📍 ID: 20250618232813-gpvu1w8
# │          📂 路径: /兴趣爱好/AIGC/AI角色扮演再进化，清华提出CharacterGLM，支持AI角色高度定制化
#
# │   ├── 📄 AI陪伴：EVE创始人 VS C.AI工程师，到底谁才是真正的AI陪伴？
# │          📍 ID: 20250618232813-kbwyr3d
# │          📂 路径: /兴趣爱好/AIGC/AI陪伴：EVE创始人 VS C.AI工程师，到底谁才是真正的AI陪伴？
#
# │   ├── 📄 AI视频制作工作流全解析 - 飞书云文档
# │          📍 ID: 20250618232813-n79m67a
# │          📂 路径: /兴趣爱好/AIGC/AI视频制作工作流全解析 - 飞书云文档
#
# │   ├── 📄 AI视频生成的Vidu样本：攻坚视频生成核心难题，引领内容生产力变革
# │          📍 ID: 20250618232813-uqidm2s
# │          📂 路径: /兴趣爱好/AIGC/AI视频生成的Vidu样本：攻坚视频生成核心难题，引领内容生产力变革
#
# │   ├── 📄 AI视频创作教程：如何用AI让古画动起来。_ai如何让国画动起来-CSDN博客
# │          📍 ID: 20250618232813-v0kbzz8
# │          📂 路径: /兴趣爱好/AIGC/AI视频创作教程：如何用AI让古画动起来。_ai如何让国画动起来-CSDN博客
#
# │   ├── 📄 AI视频创作教程：如何用AI让古画动起来。-CSDN博客
# │          📍 ID: 20250618232813-v9d508i
# │          📂 路径: /兴趣爱好/AIGC/AI视频创作教程：如何用AI让古画动起来。-CSDN博客
#
# │   ├── 📄 A_designer’s_guide_to_AI:_Building_in_Cursor_(instead_of_Figma)_lets_you_prototype_10x_faster,_simplifies_collabor…
# │          📍 ID: 20250618232813-vqcmund
# │          📂 路径: /兴趣爱好/AIGC/A_designer’s_guide_to_AI:_Building_in_Cursor_(instead_of_Figma)_lets_you_prototype_10x_faster,_simplifies_collabor…
#
# │   ├── 📄 APPLovin暴涨7倍真是靠AI吗？
# │          📍 ID: 20250618232813-wxwplfi
# │          📂 路径: /兴趣爱好/AIGC/APPLovin暴涨7倍真是靠AI吗？
#
# │   ├── 📄 AI音乐半年观(上) | 音乐生成有哪些实用场景和代表产品?
# │          📍 ID: 20250618232813-wxzscxw
# │          📂 路径: /兴趣爱好/AIGC/AI音乐半年观(上) | 音乐生成有哪些实用场景和代表产品?
#
# │   ├── 📄 AI编程：江山代有AI出，各领风骚数十天 (bolt.new、Windsurf)，以及 AI Coding 赛道洞察
# │          📍 ID: 20250618232813-yzh0thw
# │          📂 路径: /兴趣爱好/AIGC/AI编程：江山代有AI出，各领风骚数十天 (bolt.new、Windsurf)，以及 AI Coding 赛道洞察
#
# │   ├── 📄 AiCC第十九期Lora：梦幻蓝紫色手绘风格 油画棒风格
# │          📍 ID: 20250618232814-09dsip4
# │          📂 路径: /兴趣爱好/AIGC/AiCC第十九期Lora：梦幻蓝紫色手绘风格 油画棒风格
#
# │   ├── 📄 Atom Capital：中美AI最前沿 —— 创投新趋势、中美竞争与初创企业出海战略
# │          📍 ID: 20250618232814-10yltby
# │          📂 路径: /兴趣爱好/AIGC/Atom Capital：中美AI最前沿 —— 创投新趋势、中美竞争与初创企业出海战略
#
# │   ├── 📄 Andrej Karpathy 推荐的书.md
# │          📍 ID: 20250618232814-40nmxrp
# │          📂 路径: /兴趣爱好/AIGC/Andrej Karpathy 推荐的书.md
#
# │   ├── 📄 Anthropic官方 深入探讨prompt工程 | 全文脱水中文版
# │          📍 ID: 20250618232814-43y9e68
# │          📂 路径: /兴趣爱好/AIGC/Anthropic官方 深入探讨prompt工程 | 全文脱水中文版
#
# │   ├── 📄 Atom Capital：OpenAI o1的阳谋和其开启的新世界
# │          📍 ID: 20250618232814-4rswokt
# │          📂 路径: /兴趣爱好/AIGC/Atom Capital：OpenAI o1的阳谋和其开启的新世界
#
# │   ├── 📄 AutoGLM - 2025年Agent领域的发展预测 - 飞书云文档
# │          📍 ID: 20250618232814-7l4sswh
# │          📂 路径: /兴趣爱好/AIGC/AutoGLM - 2025年Agent领域的发展预测 - 飞书云文档
#
# │   ├── 📄 Atom Capital：AI搜索的未来
# │          📍 ID: 20250618232814-7ynib4q
# │          📂 路径: /兴趣爱好/AIGC/Atom Capital：AI搜索的未来
#
# │   ├── 📄 AiCC第十四期Lora：黑白线条
# │          📍 ID: 20250618232814-9ljpp0t
# │          📂 路径: /兴趣爱好/AIGC/AiCC第十四期Lora：黑白线条
#
# │   ├── 📄 AiCC第八期Lora：【折纸】动物折纸 奇妙世界
# │          📍 ID: 20250618232814-a1g68gz
# │          📂 路径: /兴趣爱好/AIGC/AiCC第八期Lora：【折纸】动物折纸 奇妙世界
#
# │   ├── 📄 Agent 如何在企业里落地？我们和火山引擎聊了聊
# │          📍 ID: 20250618232814-a1gimkp
# │          📂 路径: /兴趣爱好/AIGC/Agent 如何在企业里落地？我们和火山引擎聊了聊
#
# │   ├── 📄 Agent调研-19类Agent框架对比-今日头条 和另外 13 个页面 - 用户1 - Microsoft​ Edge
# │          📍 ID: 20250618232814-bv8uu4g
# │          📂 路径: /兴趣爱好/AIGC/Agent调研-19类Agent框架对比-今日头条 和另外 13 个页面 - 用户1 - Microsoft​ Edge
#
# │   ├── 📄 Anthropic新控制台：Claude一键搞定提示词管理全流程，太强了！
# │          📍 ID: 20250618232814-dtdsjta
# │          📂 路径: /兴趣爱好/AIGC/Anthropic新控制台：Claude一键搞定提示词管理全流程，太强了！
#
# │   ├── 📄 Anthropic：Agents 的设计之道与年度总结
# │          📍 ID: 20250618232814-e3p2m4g
# │          📂 路径: /兴趣爱好/AIGC/Anthropic：Agents 的设计之道与年度总结
#
# │   ├── 📄 Agent Neo全面开放！无需邀请码 - 飞书云文档
# │          📍 ID: 20250618232814-f4fpozf
# │          📂 路径: /兴趣爱好/AIGC/Agent Neo全面开放！无需邀请码 - 飞书云文档
#
# │   ├── 📄 Apple Intelligence 里面各种智能应用的提示词已经被曝光了 - 飞书云文档
# │          📍 ID: 20250618232814-f56zlmb
# │          📂 路径: /兴趣爱好/AIGC/Apple Intelligence 里面各种智能应用的提示词已经被曝光了 - 飞书云文档
#
# │   ├── 📄 Anthropic首发AI经济影响报告：36%职业已渗透，仅4%被深度改造
# │          📍 ID: 20250618232814-g9p12sq
# │          📂 路径: /兴趣爱好/AIGC/Anthropic首发AI经济影响报告：36%职业已渗透，仅4%被深度改造
#
# │   ├── 📄 Anthropic总结智能体年度经验：最成功的≠最复杂的
# │          📍 ID: 20250618232814-gl2zwd4
# │          📂 路径: /兴趣爱好/AIGC/Anthropic总结智能体年度经验：最成功的≠最复杂的
#
# │   ├── 📄 Ai自动制作3分钟时长的短视频，人人都能制作专业级视频！-今日头条 和另外 4 个页面 - 用户1 - Microsoft​ Edge
# │          📍 ID: 20250618232814-h6poj1h
# │          📂 路径: /兴趣爱好/AIGC/Ai自动制作3分钟时长的短视频，人人都能制作专业级视频！-今日头条 和另外 4 个页面 - 用户1 - Microsoft​ Edge
#
# │   ├── 📄 Anthropic's CPO on what comes next | Mike Krieger (co-founder of Instagram)
# │          📍 ID: 20250618232814-hjsaktk
# │          📂 路径: /兴趣爱好/AIGC/Anthropic's CPO on what comes next | Mike Krieger (co-founder of Instagram)
#
# │   ├── 📄 AutoGPT star量破10万，这是首篇系统介绍自主智能体的文章
# │          📍 ID: 20250618232814-jn7m63m
# │          📂 路径: /兴趣爱好/AIGC/AutoGPT star量破10万，这是首篇系统介绍自主智能体的文章
#
# │   ├── 📄 Artwork generated using AI software Midjourney won a state competition - The Verge.md
# │          📍 ID: 20250618232814-k62swe0
# │          📂 路径: /兴趣爱好/AIGC/Artwork generated using AI software Midjourney won a state competition - The Verge.md
#
# │   ├── 📄 Atom Capital：中美AI最前沿——创投新趋势、中美竞争与初创企业出海战略
# │          📍 ID: 20250618232814-mjfkaah
# │          📂 路径: /兴趣爱好/AIGC/Atom Capital：中美AI最前沿——创投新趋势、中美竞争与初创企业出海战略
#
# │   ├── 📄 AiCC第九期Lora：【科技风图例】发光插图 人&动物&物体
# │          📍 ID: 20250618232814-nr5kqr4
# │          📂 路径: /兴趣爱好/AIGC/AiCC第九期Lora：【科技风图例】发光插图 人&动物&物体
#
# │   ├── 📄 AiCC首发Lora：C站新人榜榜首卷儿老师领衔炼制
# │          📍 ID: 20250618232814-o9fbq7l
# │          📂 路径: /兴趣爱好/AIGC/AiCC首发Lora：C站新人榜榜首卷儿老师领衔炼制
#
# │   ├── 📄 AiCC第三期Lora：工笔画
# │          📍 ID: 20250618232814-onxw8f8
# │          📂 路径: /兴趣爱好/AIGC/AiCC第三期Lora：工笔画
#
# │   ├── 📄 AiCC第二期Lora：C站新人榜榜首卷儿老师、咖菲猫咪老师炼制
# │          📍 ID: 20250618232814-oo8rn56
# │          📂 路径: /兴趣爱好/AIGC/AiCC第二期Lora：C站新人榜榜首卷儿老师、咖菲猫咪老师炼制
#
# │   ├── 📄 Agentic Workflow：AI重塑了我的工作流.md
# │          📍 ID: 20250618232814-otghu50
# │          📂 路径: /兴趣爱好/AIGC/Agentic Workflow：AI重塑了我的工作流.md
#
# │   ├── 📄 AiCC第四期Lora：【卡通背景】动物拟人举牌
# │          📍 ID: 20250618232814-ron6jg2
# │          📂 路径: /兴趣爱好/AIGC/AiCC第四期Lora：【卡通背景】动物拟人举牌
#
# │   ├── 📄 AiCC第五期Lora：【国画山水】只此青绿，禅意山水
# │          📍 ID: 20250618232814-s91k8j5
# │          📂 路径: /兴趣爱好/AIGC/AiCC第五期Lora：【国画山水】只此青绿，禅意山水
#
# │   ├── 📄 Agent 最全 Playbook：场景、记忆和交互创新
# │          📍 ID: 20250618232814-sfa60p5
# │          📂 路径: /兴趣爱好/AIGC/Agent 最全 Playbook：场景、记忆和交互创新
#
# │   ├── 📄 Artifacts：与AI交互的 (新) 形式，正在被开发者们玩出新花样
# │          📍 ID: 20250618232814-t04lnkq
# │          📂 路径: /兴趣爱好/AIGC/Artifacts：与AI交互的 (新) 形式，正在被开发者们玩出新花样
#
# │   ├── 📄 AiCC第十六期Lora：水彩插画
# │          📍 ID: 20250618232814-ujgl9jx
# │          📂 路径: /兴趣爱好/AIGC/AiCC第十六期Lora：水彩插画
#
# │   ├── 📄 AiCC第十一期Lora：国风磨砂玻璃瓶
# │          📍 ID: 20250618232814-vh7yfz5
# │          📂 路径: /兴趣爱好/AIGC/AiCC第十一期Lora：国风磨砂玻璃瓶
#
# │   ├── 📄 Anthropic亲自公开Claude脑回路！
# │          📍 ID: 20250618232814-vjfoup5
# │          📂 路径: /兴趣爱好/AIGC/Anthropic亲自公开Claude脑回路！
#
# │   ├── 📄 Anthropic发布报告：龙虾、孕妇与禁售芯片
# │          📍 ID: 20250618232814-x7v1rr0
# │          📂 路径: /兴趣爱好/AIGC/Anthropic发布报告：龙虾、孕妇与禁售芯片
#
# │   ├── 📄 CES 2025回顾：DIVE IN to the Future | 红杉爱科学
# │          📍 ID: 20250618232815-17pr8q4
# │          📂 路径: /兴趣爱好/AIGC/CES 2025回顾：DIVE IN to the Future | 红杉爱科学
#
# │   ├── 📄 CES 2025：井喷的AI陪伴与AI眼镜
# │          📍 ID: 20250618232815-1ou8uws
# │          📂 路径: /兴趣爱好/AIGC/CES 2025：井喷的AI陪伴与AI眼镜
#
# │   ├── 📄 ChatGPT+Jupyter Notebook？
# │          📍 ID: 20250618232815-3y9cu1h
# │          📂 路径: /兴趣爱好/AIGC/ChatGPT+Jupyter Notebook？
#
# │   ├── 📄 CES 2025灵魂三问：这是什么？能买吗？对我有什么用？｜甲子光年
# │          📍 ID: 20250618232815-7f2jnox
# │          📂 路径: /兴趣爱好/AIGC/CES 2025灵魂三问：这是什么？能买吗？对我有什么用？｜甲子光年
#
# │   ├── 📄 ChatGPT大更新！API新增杀手级能力还降价，新模型、4倍上下文都来
# │          📍 ID: 20250618232815-8n0gn4k
# │          📂 路径: /兴趣爱好/AIGC/ChatGPT大更新！API新增杀手级能力还降价，新模型、4倍上下文都来
#
# │   ├── 📄 AutoGen：通过多agent对话支持下一代LLM 应用
# │          📍 ID: 20250618232815-93pqaug
# │          📂 路径: /兴趣爱好/AIGC/AutoGen：通过多agent对话支持下一代LLM 应用
#
# │   ├── 📄 ChatGPT与DALL·E 3之间的行业「黑话」被人发现了
# │          📍 ID: 20250618232815-9b40mpi
# │          📂 路径: /兴趣爱好/AIGC/ChatGPT与DALL·E 3之间的行业「黑话」被人发现了
#
# │   ├── 📄 ChatGPT CoT 的系统提示词.md
# │          📍 ID: 20250618232815-alxj32h
# │          📂 路径: /兴趣爱好/AIGC/ChatGPT CoT 的系统提示词.md
#
# ...
# 6461.   深度分析Iot的七大通信协议
# 6462.   深度好文：去投资，而不是在股海中沉浮丨观点聚焦
# 6463.   清朝诗人张灿有一首短诗：“书画琴棋诗酒花
# 6464.   特斯拉员工自述：马斯克激进冰冷，特斯拉犹如邪教
# 6465.   玛雅文明怎么看都有点“中二”
# 6466.   每天做180秒平板支撑，坚持1个月会发生什么？
# 6467.   深度解读《原则》： 掌握更高次的思考方式
# 6468.   理解死亡，这十本书可以读
# 6469.   漫话：全球 IPv4 地址正式耗尽？是时候说说到底什么是IPv4和IPv6了！
# 6470.   爱情里必须了解的 1 个问题和 2 个策略，看完就能马上用
# 6471.   生命最有意思的十件事儿
# 6472.   结婚纪念日，聊聊如何和亲密的人好好说话
# 6473.   硅谷“PayPal黑帮”迷恋区块链的3个原因-网易云阅读
# 6474.   相片尺寸规格
# 6475.   罗胖60秒：为什么要让孩子学钢琴
# 6476.   百度云-OCR调用
# 6477.   知乎点赞最高的60个金句，每一句都很喜欢！
# 6478.   知乎高赞：你在哪一刻体验到了真正的贫富差距
# 6479.   用这三个方法成为“更聪明”的学习者
# 6480.   罗胖60秒：为什么狗比猫更亲近人？
# 6481.   电脑手机快速互传文件7个免费工具软件 - Google Chrome
# 6482.   罗胖发明的这个概念，可以解释整个互联网的下半场了
# 6483.   稻盛和夫：打造激情四射团队的16个关键
# 6484.   知乎13万赞：你有什么道理后悔没有早点知道？
# 6485.   精选PPT | 平台革命：改变世界的商业模式
# 6486.   科学结论：早教对孩子不仅没用，反而有害
# 6487.   精选50篇文章 +  40张笔记思维导图 + 各行业研究报告 + 小程序白皮书等资料包
# 6488.   罗辑思维
# 6489.   目前看到的关于房价暴涨和中美贸易战最好的文章，没有之一——2018中国房价暴涨和中美贸易战的深层关系
# 6490.   职场修炼
# 6491.     11个案例，11种态度
# 6492.     2017年《财富》世界500强发布
# 6493.     10 advantages of mind mapping software vs. hand-drawn maps
# 6494.     10分钟让你的阅读速度提高两倍
# 6495.     2023年巨量引擎研究报告整理，一共24份，欢迎收藏！
# 6496.     2023年TikTok研究报告整理，一共27份，欢迎收藏！（持续更新）
# 6497.     1966年7月，《中国画报》有王铁人头戴瓜皮帽的照片，日本人就推断出此地为零下30度的东北地区；又根据运原油的列车上灰层的厚度，测出油田与北京的距离，认定油田应
# 6498.     110数字动作编码配人物颜色物件
# 6499.     1000幅图训练方法
# 6500.     1860年，美国大富翁道格拉斯作为民主党总统候选人，公开羞辱共和党总统候选人林肯：“我要让林肯这个乡巴佬闻闻我们贵族的气味!”后来，林肯这个没有专车，自己拉票时
# 6501.     一张图读懂运营商五年兴衰：土豪还是土豪 电联还需努力
# 6502.     一文讲懂什么是vlan、三层交换机、网关、DNS、子网掩码、MAC地址
# 6503.     元宇宙
# 6504.       360推出社交产品“N世界”，模仿discord能做成元宇宙吗？-今日头条
# 6505.       75页游戏引擎研报：3A较难推动国产inhouse引擎，东西方路径差异明显
# 6506.       我在赛博世界里女装、蹦迪、耍钱、18禁、不系绳子蹦极
# 6507.       元宇宙系列之初探商业模式 和另外 2 个页面 - 用户配置 1 - Microsoft​ Edge
# 6508.       《雪崩》原作者笔下的元宇宙长什么样？-虎嗅网 和另外 1 个页面 - 用户配置 1 - Microsoft​ Edge
# 6509.       Epic CTO：实现元宇宙的真正技术难题是什么？
# 6510.       Metaverse，元宇宙 - 用户配置 1 - Microsoft​ Edge
# 6511.       元宇宙清单：awesome-metaverse
# 6512.       Web3.0，「激发创造」的时代
# 6513.       如何让一幅画的价格翻上四倍？答：把它烧掉后做成电子版
# 6514.       别听那些报告忽悠，元宇宙研究看这一篇就够了 和另外 2 个页面 - 用户配置 1 - Microsoft​ Edge
# 6515.       清华大学：2021 元宇宙研究报告！
# 6516.       报告揭秘扎克伯格的元宇宙野心，布局八大场景，软硬件全都要 | 智东西内参 和另外 3 个页面 - 用户配置 1 - Microsoft​ Edge
# 6517.       玩家真的需要「随时随地畅玩游戏大作」吗？
# 6518.       虚拟财产将会比实物更有价值吗，元宇宙重新定义未来 和另外 1 个页面 - 用户配置 1 - Microsoft​ Edge
# 6519.       百度“希壤”恶评如潮？但我看到了元宇宙商业的四大模式-今日头条
# 6520.       这届游戏公司还能指望元宇宙吗？
# 6521.       许怡然发文：我怎么看元宇宙和游戏行业的未来
# 6522.       硬核科普：什么是元宇宙？
# 6523.       炒房炒到元宇宙，虚拟地产单个交易新纪录：1500万元，一平米2.7万
# 6524.     作为一个经理意味着什么 神话与现实
# 6525.     5 Steps to Exceed Customer Expectations
# 6526.     •麦肯锡的商业模式分类能够较好的反映商业模式的大类特征，即鲸鱼、布谷鸟和益生菌三大类。
# 6527.     [原创]如何进行人生规划（含MindManager模板）
# 6528.     Toyata Principles 丰田原则
# 6529.     人生有七次机会
# 6530.     一条龙服务，我来手把手带你玩转云服务器~
# 6531.     一张图看懂华为2015年年报
# 6532.     从优秀员工到黯然离职——给还在华为的兄弟一点生存智慧
# 6533.     任正非曾经对土狼时代的华为精神作过经典概括。他说：“发展中的企业犹如一只狼。狼有三大特性：一是敏锐的嗅觉，二是不屈不挠、奋不顾身的进攻精神，三是群体奋斗的意识。
# 6534.     ○细节可见风节
# 6535.     企业管理者的表扬与批评艺术
# 6536.     How To Meet Women
# 6537.     [转帖]龙应台：一张考卷做做看[栖息谷·管理人网络社区]
# 6538.     【漫画】https 加密那点事
# 6539.     丰田精细化管理
# 6540.     《水平思考》每周学习摘要（每周学习一点点）
# 6541.     The Toyota Way
# 6542.     How Duolingo reignited user growth Duolingo如何重新点燃用户增长.md
# 6543.     从PowerPoint中导出图片文件和声音文件
# 6544.     [原创]外语学习听觉系统之多米尼克语言岛策略汉化版——一个具体可操作的方案
# 6545.     乔哈瑞窗口（Johari windows）
# 6546.     一个月2分钟内记住一副扑克（体会分享）！（续）（秘技部分，附图）
# 6547.     一、时间管理——从执行者的角度看执行力
# 6548.     从1G到3G的相关技术简介
# 6549.     CEO应该如何写作：贝佐斯把写作变成了亚马逊的竞争优势
# 6550.     [原创]创造力思维的技巧和运用
# 6551.     《基业长青》的杰里·波拉斯与他的助手，花几年时间与全球200多位成功人士访谈，最后成书《成功长青》。在这本2007年新出版的巨著中，波拉斯公布了一条坏消息：“不
# 6552.     TC基本功－定位与选择
# 6553.     企业应积极重视知识型员工的个体化差异
# 6554.     一个月2分钟内记住一副扑克（体会分享）
# 6555.     以交通为例，行人的个体行为数据被采集，汇集起来成|方片
# 6556.     [推荐]集结号_一次失败的项目管理
# 6557.     Thread_ [分享]浅谈Marketing的质量工作 （From 马啸）
# 6558.     [原创] 英文单词记忆-字母组合的图像编码及其应用
# 6559.     以岗定级、以级定薪、人岗匹配、易岗易薪
# 6560.     什么是盖洛普Q12
# 6561.     互动媒体
# 6562.     DATEDIF
# 6563.     从单一工作走向斜杠人生，这是你的必经之路
# 6564.     丰田公司对浪费作了严格区分，将浪费现象分为以下七种：
# 6565.     【NLP基础教程】NLP十四项心理定律
# 6566.     保障客户网络的稳定运行，是技术服务部员工的基本职责。从历次网上重大事故案例中，我们都可以学到很多共同的经验教训：
# 6567.     [置顶]xbeta精心荐精品之免费软件列表
# 6568.     [转帖]12年面试2万余人之后的一点感悟[栖息谷·管理人网络社区]
# 6569.     [转帖]三个愚昧的老汉引发的管理思考
# 6570.     “不到位”的背后是低效与浪费
# 6571.     Shit, I'm A Manager - The Talk
# 6572.     [转帖]经高人点拨，终于明白了两件大事 !!!
# 6573.     Exceed Expectations...
# 6574.     A Million Dollar Lesson
# 6575.     [原创]学习力的革命6
# 6576.     total commander
# 6577.     [讨论]一道测试题，终生受用！
# 6578.     中国记忆力训练网精品训练教程之一：如何在3分钟内记住一副扑克牌
# 6579.     PPS文件怎么样转回.PPT文件
# 6580.     从“智猪博弈”看团队建设
# 6581.     什么是HMS？带你了解华为HMS移动生态系统所有信息
# 6582.     30原则” (3517个读者)
# 6583.     习惯人生
# 6584.     “千言万语不及一张图” ! ! !
# 6585.     [Q & A]什么叫软文？
# 6586.     一文读懂云计算：发展历程、概念技术与现状分析
# 6587.     n 三流企业卖力气
# 6588.     [吐血推荐]七种思考武器之二：一塔惊四座
# 6589.     中国记忆力训练网精品训练教程之三：如何在3分钟内记住100位数字
# 6590.     AIoT
# 6591.     为什么你的PPT做起来那么慢？原因可能是你没有用这个辅助神器！
# 6592.     促销的4要点——人员推广、广告、公共关系、促销活动，也不知其实。至于促销活动常见的16种——打折、送赠品、退费优待、凭证优惠、抽奖、集点换物、联合促销、免费试用
# 6593.     PDCA
# 6594.     ®“世界上本没有垃圾，只是因为放错了地方。”
# 6595.     mindmap的使用入门
# 6596.     B测试科学决策？
# 6597.     亚当斯密
# 6598.     Thread_ [Discussing]关于MKTG的困惑和思考
# 6599.     Office常用快捷键
# 6600.     Excel Study_
# 6601.     [心灵驿站]_溝通六原則
# 6602.     一张图看懂华为2016年年报
# 6603.     为什么要这样面试，这是我看过最好的答案
# 6604.     2023年罗兰贝格研究报告，一共39份，欢迎收藏！
# 6605.     七种思考武器之超级思考帽
# 6606.     体检过程的思维博弈
# 6607.     Thread_ 惊人相似：广告的经典与盗版
# 6608.     为那些Image Streaming时无法“获得影像”的人准备的特别技巧
# 6609.     v一个孩子四岁才会说话，七岁才会写字，老师给他的评语是“反应迟钝，思维不合逻辑”。一个孩子考了三次艺术院校都未能考上，父亲抱怨他是“白痴”，其叔叔说他是“孺子不
# 6610.     业界最受关注话题：“神舟电脑，是如何赚钱的？”董事长自爆谜底！
# 6611.     中国记忆力训练网精品训练教程之二：如何快速记忆人名与头像
# 6612.     _古巴导弹危机_曝内幕：一个_不_字拯救世界
# 6613.     Ø蛙跳战术
# 6614.     三段式命名：TC下最实用的文件（夹）命名规则 (2)
# 6615.     任正非接受BBC采访全文：美国这么一个大国家和我们这个小公司打架，说明这个小公司东西还真好
# 6616.     产品和数据应该懂得的AARRR
# 6617.     45岁退休，华为员工何去何从？股票又如何保留？.md
# 6618.     “一滴水怎样才能不干涸？”弟子们面面相觑，无法回答。释迦牟尼说：“把它放到大海里去。”
# 6619.     中国记忆力训练网精品训练教程之四：如何记忆二进制数字
# 6620.     习惯与自然
# 6621.     “长尾营销”颠覆了“二八定律”？
# 6622.     一个谎言的四十年……
# 6623.     【牛头NLP笔记－概述01】什么是NLP[修订版]
# 6624.     关于细节
# 6625.     关于近期易岗易薪REVIEW及2008年人岗匹配工作安排的情况通告
# 6626.     养牛之道
# 6627.     八种创业赢利模式2
# 6628.     出租司机给我上的MBA课
# 6629.     功能展示不彻底
# 6630.     华为总裁任正非管理幽默语录
# 6631.     华为游戏中心花瓣游戏开发者服务持续升级，赋能高效研运
# 6632.     别让沟通能力，成为你最大的短板
# 6633.     华为40岁中年员工分享求职经历：温水煮青蛙一朝警醒，总算不太晚
# 6634.     判断一个人能否胜任团队leader，就看这一点
# 6635.     华为应用商城搜不到拼多多？关键词是“夕夕” - 用户配置 1 - Microsoft​ Edge
# 6636.     努力决定生存
# 6637.     兵随将转，无不可用之才。作为一个管理者，你可以不知道下属的短处，却不能不知道下属的长处。
# 6638.     动画_ 一个浏览器是如何工作的？
# 6639.     关于对人民币升值有很好理解的思维导图
# 6640.     北京大爷
# 6641.     华为溪流背坡村规划
# 6642.     公司宣传口径一纸禅
# 6643.     十大自我修炼工具
# 6644.     关于记忆文章和专业课的方法
# 6645.     华为人“江湖黑话”_菊花_飞机_公司 和另外 7 个页面 - 用户配置 1 - Microsoft​ Edge
# 6646.     十九世纪中叶，维也纳的医师约瑟夫．布鲁尔（Josef Breuer）治疗过一个罹患恐水症的女病人，她的症状是无法喝水，虽然她可以把杯子端到嘴巴旁边，却怎么样也无
# 6647.     关于PPT的绝对技巧
# 6648.     华为、中兴、爱立信、诺基亚、阿朗 五大设备商2015财报大对比
# 6649.     几个有趣的提问，你能回答几个？[栖息谷·管理人网络社区]
# 6650.     十分钟经济学，让你看懂中国经济--各位达人如何看
# 6651.     华为首席管理科学家黄卫伟：我来回答你什么是“中国式管理”
# 6652.     八种创业赢利模式1
# 6653.     有人的地方就有江湖
# 6654.     图像记忆的四大步骤：图像转化、图像联结、图像定桩、图像整理
# 6655.     沟通小故事
# 6656.     沃尔玛服务三条基本信条（ThreeBasicBeliefs）：
# 6657.     好消息往往不是好新闻
# 6658.     欧洲战神”拿破仑的话：一只狮子率领一群绵羊的队伍，可以打败由一只绵羊带领一群狮子的部队。这句格言说明两层意思，一是只要有一个优秀指挥官，他可以将一平庸的队伍调教
# 6659.     我的100个数字人物码.
# 6660.     心理游戏——五个简单的问题
# 6661.     有一种说法这样讲：
# 6662.     教授的测试题
# 6663.     查找函数之Vlookup
# 6664.     将产品开发管理的方法应用到一般工作中
# 6665.     如何穿西装打领带配衬衫
# 6666.     有效授权——从执行过程的角度看执行力1
# 6667.     搜索运营有哪些玩法，你知道吗？
# 6668.     扁鹊三兄弟
# 6669.     清除泄露上网行踪的“index.dat”文件
# 6670.     平衡计分卡的原理方法
# 6671.     平衡记分卡（Balanced Scorecard）的优势
# 6672.     海尔管理藏经阁
# 6673.     搞笑有套路，段子有公式
# 6674.     女人与时尚
# 6675.     有没有什么好的思维导图分享网站？ - 知乎 - 傲游云浏览器 4.4.0.3000
# 6676.     当事人揭秘4G核心专利：高通没那么多，中国没那么少！
# 6677.     外企趣味智力面试题
# 6678.     欠 着
# 6679.     并不是你想象中那样
# 6680.     有没有什么好的思维导图分享网站？ - 知乎 - 傲游云浏览器 4.4.0.3000
# 6681.     往返都能让客人看见富士山
# 6682.     当老虎来临时
# 6683.     德鲁克论管理人员及其工作
# 6684.     吴春波：知识员工的管理与激励
# 6685.     有效授权——从执行过程的角度看执行力3
# 6686.     当人们在团队里面，他们的工作不能被明显地区别开来，并且不容易评价，他们就会倾向于少花点力气。
# 6687.     当ABCD（人工智能AI、区块链Blockcha|方片
# 6688.     常见姓氏编码表（按拼音排列）
# 6689.     古怪小孩的古怪想法
# 6690.     性格即命运
# 6691.     当艾森豪威尔当选总统时，他的前任哈里·s·杜鲁门曾说道：“可怜的艾克，他在当将军时，一道命令下去，贯彻起来畅行无阻。现在他得坐在那间大办公室里了，他若再发布命令
# 6692.     批评的艺术
# 6693.     消费者心理洞察（二）
# 6694.     思维导图真的有效吗？ - 知乎
# 6695.     富有哲理的小故事
# 6696.     极为经典的故事：第四个把梳子卖给和尚的人
# 6697.     图解Total Commander 7.0之22项更新与改进（推荐）
# 6698.     四大设备商2015年成绩单：华为一枝独秀 利润超三家总和
# 6699.     游戏中心年中会议手写笔记20220722
# 6700.     小事成就大事，细节成就完美
# 6701.     最基本的快速记忆方法：联想法
# 6702.     桩子大世界
# 6703.     必不可少的说服艺术
# 6704.     如何解读Excel公式
# 6705.     折磨顾客 －－因为他们喜欢
# 6706.     思维导图 | ​​​​​吴晓波万字演讲：2020，如何求生？
# 6707.     博士
# 6708.     微利时代，企业如何应对？
# 6709.     如何使用六项思考帽
# 6710.     形象记忆法训练（西维累尔摆动实验）
# 6711.     商业头条No.2 - 拯救华为汽车业务.md
# 6712.     如何牢记别人的姓名（一）
# 6713.     帕金森定理
# 6714.     案例评审模块Appraising parts
# 6715.     平衡计分卡的不足
# 6716.     如何对一本书做思维导图
# 6717.     当初中国从日本进口缝衣针的时候，好多人都感惊诧：一个针还要买日本人的？看到了日本针才发现，我们常用的针是圆孔，而日本的针是长条孔，这是为照顾老人们眼花而设计的。
# 6718.     思维导图最大缺点是什么？ - 知乎
# 6719.     原创]择业，别做正常的傻瓜
# 6720.     华为：17 万大军，孤独行走在世界上
# 6721.     江泽民答CBS记者问 (转载)
# 6722.     图解 | 通用搜索引擎背后的技术点
# 6723.     数组公式
# 6724.     消费互联网的发展已经逼近顶点。以中国为例，CNN|方片
# 6725.     杨钢谈质量
# 6726.     志愿
# 6727.     国外这个爆火的PPT动画太炸了！脑洞和实用并存，绝了 - Google Chrome
# 6728.     快一步是先烈，快半步是先进
# 6729.     博弈论精要 （童话版）
# 6730.     古巴导弹危机
# 6731.     如何啃企业业务的鸡肋？
# 6732.     很残酷但很现实，看再多的书也无法改变命运.md
# 6733.     斗地主：如何记住对方出的牌
# 6734.     游戏引擎产业研究：元宇宙筑梦师 和另外 2 个页面 - 用户配置 1 - Microsoft​ Edge
# 6735.     只需一个底层逻辑，搞定所有问题
# 6736.     消费购买心理洞察与应用
# 6737.     打破速读神话!!!
# 6738.     我是陈阿土
# 6739.     曲突徒薪
# 6740.     在我们的实际项目中我们往往忽略了客户这个最重要的博奕对手，把客户当成“朋友”。在项目操作中对友商竞争想尽办法，而对客户是 一味妥协、缺乏策略。
# 6741.     原来如此
# 6742.     思维导图网站大全
# 6743.     工业发展四个等级
# 6744.     思维导图的应用
# 6745.     在这时代，必须把自己变成「碰不得的人」 ，下列四类就是碰不得的工作者：
# 6746.     没有永远的敌人，只有永远的利益。
# 6747.     有效授权——从执行过程的角度看执行力2
# 6748.     教你看财务报表的方法
# 6749.     岂能尽如人意，但求无愧我心
# 6750.     定义名称的妙处
# 6751.     我们从《封杀王老吉》事件学什么？
# 6752.     技术开源
# 6753.     工程师如何从技术转型做管理？
# 6754.     员工的个体差异
# 6755.     如何利用备注详解——演示者可看观众不可看
# 6756.     思维的基本方法
# 6757.     显而易见，以一当十并不难，我们太强调英雄，总在强调“以一当十”，但是，难的是以十当一。因为“以一当十”只要最大程度地发挥一个人的潜力就行了。而以十当一则不同，它
# 6758.     同事常说的堡垒机是什么？
# 6759.     思维导图 | ​​​​​​​​​比天赋更重要的，是正确的学习方法
# 6760.     游戏行业
# 6761.       《万国觉醒》获赔1000万，这回法院定义了什么叫“换皮抄袭”
# 6762.       【十一充电】游戏制作的核心竞争力：立项定输赢
# 6763.       中小团队游戏立项，如何才能提高成功率？
# 6764.       2023会是游戏行业的春天吗？6位游戏人坐下来聊了聊
# 6765.       【策划干货】从9人团队到年度爆款，制作人亲述《阴阳师》是如何立项的？
# 6766.       《潮爆三国》制作人大宝：立项决定生死，美术创新最具性价比丨课堂笔记
# 6767.       从休闲巨头Voodoo、 Ketchapp看爆款小游戏立项的三种方法
# 6768.       “中国已成为世界最大的移动游戏生产国”
# 6769.       全球竞争力报告：全球移动市场规模缩减10.3%，中国游戏市场占有率稳步提升
# 6770.       聊聊这两年游戏行业最大的认知陷阱
# 6771.       游戏立项期的收入预测（一）
# 6772.       游戏立项报告框架
# 6773.       创业首秀七天流水破5000万，公司CEO：都是米哈游逼的
# 6774.       畅销榜拔升100多名，DAU破千万，网易又赌对了一个爆款？
# 6775.     搞笑有套路，段子有公式​
# 6776.     如何有效的学习培训课程（经典）
# 6777.     物联网IoT
# 6778.       绝密计划：我在阿里打黑工
# 6779.       关于对物联网理解的十大误区，你有踩过吗？
# 6780.       “四把刷子”就能横行物联网？它做到了
# 6781.       “不做SaaS，被集成”阿里云新战略背后的商业逻辑
# 6782.       【やじうまPC Watch】Huawei、新型コロナウイルス対策用に「ボタンに触らずに乗れるエレベータ」を開発 ～6月末までソリューションを無償提供 - PC Watch
# 6783.       安筱鹏一语道破：为什么数字化转型常常陷入误区与困境？【物女心经】
# 6784.       对话行癫：解密阿里云顶层设计和底层逻辑
# 6785.       最新！49页PPT读懂物联网市场走向！
# 6786.       干货 | 边缘计算在能源物联网中的应用场景（附PPT全文）
# 6787.       「开源资讯」MQTT X - 优雅的跨平台 MQTT 5.0 桌面客户端
# 6788.       思维导图 | To B姗姗来迟，来势汹汹
# 6789.       解读阿里云生态新战略
# 6790.     牛头记忆系列4【牛头也谈谈初学者如何学习记忆术】
# 6791.     演示制胜——文稿演示检查表
# 6792.     激励、培训、规划，一个都不能少
# 6793.     通信设备商的海外趣事：要不干脆帮你建个水泥厂吧！
# 6794.     跟踪监控－－提高管理执行力的诀窍之一
# 6795.     金字塔原理：思考、写作和解决问题的逻辑
# 6796.     管好关键员工：三大原则
# 6797.     鲨鱼与鱼(转载)
# 6798.     理性思维的8大元素 &快速记忆的方法
# 6799.     网络经典命令行
# 6800.     请问，为什么管ZTE叫26呢？
# 6801.     高筑墙,广积粮,缓称王
# 6802.     男性西装的正确穿法是什么？
# 6803.     秀才赶考
# 6804.     王者荣耀的技术美术
# 6805.     解读博弈论大师-纳什
# 6806.     经理人最有用的100个管理站点(最新整理)
# 6807.     用右脑背单词-原创，举例 （1） aug 7 我相信大部分想学习快速记忆或超级记忆的人，最主要的目的就是如何更快更有效的记住英文单词。用传统的方式记单词，通过大
# 6808.     神奇记忆术揭秘全集
# 6809.     知识型员工流失风险管理
# 6810.     英语美文:【Three Days to See】
# 6811.     通读美国实体清单1340条全记录：中国第一，华为第一
# 6812.     领导艺术－八项管理定律
# 6813.     这套方法，让74%的人一年成为核心人员
# 6814.     行为的触发
# 6815.     轮值CEO郭平：5G到来之前，我们可以做这三件事
# 6816.     经济学妙语和笑话
# 6817.     试论人际关系与人际传播
# 6818.     番茄工作法
# 6819.     王永庆开米店
# 6820.     看了华为近20年分红数据，有点夸张，有点嫉妒-今日头条
# 6821.     突围职场十年之痒
# 6822.     钥 匙
# 6823.     知识型员工为何难沟通 关键是心态
# 6824.     简单却容易被忽略的四条管理定律
# 6825.     青朴山：过去三年中国最牛逼的商业创新模式——摩拜单车，还能走多远？
# 6826.     管理人员注意到每一家店的相同性，观察出每一家店的差异性，一个小细节的成功导致整个公司巨大的销售成功。
# 6827.     破解加密excel
# 6828.     美国议事规则
# 6829.     领带打法图解
# 6830.     营销写作借鉴——转载：24种诗文风格，哪种你最心仪
# 6831.     老子曰：“天下大事必作于细，天下难事必成于易。”
# 6832.     诺贝尔经济学奖
# 6833.     ，一个新的赛道诞生时会出现一个 590 现象，也|方片
# 6834.     铂程斋--任总接受美联社采访纪要
# 6835.     记忆力改变了我的一生
# 6836.     目前考核结果过于滞后，比如3季度的考核沟通在11月下旬才能进行，包括这个3季度调查本身都是在12月份才开始。绩效考核如果不注重时效性，对员工的意义就弱化了。
# 6837.     达成一万小时后的脱口透演员所给出的80个增加幽默感的谈话建议
# 6838.     高效经理的五个常用工具
# 6839.     都2021年了，再不做私域就晚了
# 6840.     物联网元年、爆发性增长，据物联网研究机构IoT |方片
# 6841.     职场启示录：高薪难以解决35岁之后人生的根本问题
# 6842.     看莫斯科保卫战有感
# 6843.     长尾理论出现，和二八定律产生直接冲突。所谓长尾理论（The Long Tail），从统计学中一个形状类似“恐龙长尾”的分布特征的口语化表述演化而来。查阅维基百科
# 6844.     看完这篇招聘方法论，90�O会心痛.md
# 6845.     看法
# 6846.     经营VS管理
# 6847.     编码图象与地点联结规律探讨
# 6848.     突然不喜欢余（世维）博士的讲座了？
# 6849.     针对不同需求的客户，如何做好英文胶片宣讲
# 6850.     记忆体操之六：牢记《八荣八耻》
# 6851.     黄粱一梦
# 6852.     男女博弈
# 6853.     重新定义系统集成
# 6854.     近二十年来诺贝尔经济学奖得主及贡献
# 6855.     电信运营商观念改变：网络所有权不再是盈利必要条件
# 6856.     通用电气（General Electric）
# 6857.     袋鼠与笼子
# 6858.     真假江泽民的一场网上戏
# 6859.     物联网三大挑战
# 6860.     领导力基线素质：
# 6861.     著名咨询公司笔记法，提高效率
# 6862.     虽然微软在阐述Freemium模式时提及了苹果和谷歌的商业模式
# 6863.     迈克尔·波特解析差异化战略
# 6864.     龙应台：啊，上海男人！
# 6865.     领导力：称赞与批评2∶1最合适
# 6866.     魔鬼经济学
# 6867.   看完这篇还不了解Nginx，那我就哭了！
# 6868.   纸张尺寸_百度百科
# 6869.   缺钱的时候怎么办？这部剧震碎了我的三观……
# 6870.   知识礼物 | 关于亲密关系，最值得收藏的十本著作
# 6871.   美团王兴的10年
# 6872.   让我受用终身的12种底层思维方法
# 6873.   许小年：未来五年在中国最赚钱的不是股市、房地产，而是…
# 6874.   腾讯、米哈游、沐瞳……这件特别的利器，过半出海厂商都在用 和另外 3 个页面 - 用户配置 1 - Microsoft​ Edge
# 6875.   芒格震撼演讲：看不清这个趋势，会错过一大波机会
# 6876.   蒋方舟：作为一个独身且并不清贫的女学生，爱情并不是必需品
# 6877.   让身体和大脑彻底放松的七个方法
# 6878.   花了十二年，他在地中海边的悬崖上造出了世界上风景最美的独立书店
# 6879.   让容器的世界变得更美好
# 6880.   芒格在Daily Journal 年会上的演讲
# 6881.   蔻蔻梁：谁的相亲路上没遇到过几个奇葩
# 6882.   薛兆丰：这三个故事，让你重新认识商业
# 6883.   设置网页正文提取规则 - Wiz 为知个人知识管理 - 傲游云浏览器 4.4.1.2000
# 6884.   褚时健：活着是为了什么？
# 6885.   莫言说他是偶像，王朔说他已成精，时隔17年，终于等到他的全集了
# 6886.   让你不用翻墙，只需3个步骤，就能下载到Google Play外国区的APP_sonyl36h吧_百度贴吧 - 傲游云浏览器 4.4.3.4000
# 6887.   蒋方舟：我不再怕别人说我名不副实
# 6888.   萧红曾说“只恨自己不是男人”
# 6889.   要么进化，要么去死 | 傅盛解读《原则》及书摘
# 6890.   让你不用翻墙，只需3个步骤，就能下载到Google Play外国区的APP_sonyl36h吧_百度贴吧 - 傲游云浏览器 4.4.3.4000
# 6891.   自动档汽车档位介绍和驾驶知识与技巧
# 6892.   讲好故事是个很重要的技能，推荐几本书籍
# 6893.   这个曾被冯小刚“赶出”影视圈的男人，用一张卡刷爆了朋友圈，也刷爆了全世界的酒店
# 6894.   赠书丨每当我找到生命的意义，它就又变了
# 6895.   豆瓣9.1！如果你在人群中感到格格不入，一定要读它
# 6896.   这9个发现，藏着中国商业世界未来的机会
# 6897.   设置网页正文提取规则 - Wiz 为知个人知识管理 - 傲游云浏览器 4.4.1.2000
# 6898.   这5本成人绘本，治愈程度10颗星！
# 6899.   这套思维让你的选择更具科学性 | 3个小故事
# 6900.   这才是真正的十八禁，因为它说：单身久了，原来真的会变成狗！在一起，也好不到哪去！
# 6901.   这种感觉
# 6902.   诺兰星际穿越后不可不看四部伟大科幻小说
# 6903.   超刺激！破4项世界纪录的玻璃大峡谷，两天后开放！
# 6904.   跟父母在一起没话说，试试聊聊这8个问题
# 6905.   读书是性价比最高的投资 | 笔记书堂12本好书推荐
# 6906.   这七本书告诉你，人生没有一种不孤独
# 6907.   这个真实案件，居然比好莱坞大片还刺激
# 6908.   谈文章出轨：谁是爱的标榜
# 6909.   追剧追到死的假期，我只选这七部美剧
# 6910.   谷歌搜索高级语法技巧大全_百度经验 - 傲游云浏览器 4.4.1.5000
# 6911.   赢在BP：商业计划书的必备内容
# 6912.   轰动世界200年的至高文学经典，让无数自卑者找到真实的自己
# 6913.   选择一个合适的数据图表？
# 6914.   赠书结果 | 张爱玲那些让人心痛的句子
# 6915.   豆瓣9.1，我终于能看到这本神书的正版了！
# 6916.   这样玩电子游戏对才有孩子帮助
# 6917.   速写东京人的美好时光
# 6918.   连清川：电子阅读可以取代传统阅读吗
# 6919.   较真 | 美国人耗费巨资研发太空笔，苏联人用铅笔解决问题？没这回事
# 6920.   这样的读书方法，让你的阅读质量提升300%
# 6921.   通往财富自由，比成功更重要的事是什么
# 6922.   谈谈录音、视听证据的法律效力
# 6923.   速写，每一根线条都要迷死个人！
# 6924.   这项研究只能证明相关
# 6925.   谷歌搜索高级语法技巧大全_百度经验 - 傲游云浏览器 4.4.1.5000
# 6926.   阿里云为什么要进军 IoT？
# 6927.   阿里巴巴为什么能抗住90秒100亿？看完这篇你就明白了！
# 6928.   首先，墙真是个好东西，就像生物一样，隔离是物种多样性的一个重要条件，不隔离的话，弱势物种就会被优势物种排挤掉，中学生物的大小草履虫共处一瓶试验就说明了这个问题。
# 6929.   鸦片战争原来是这个样子
# 6930.   那些轻松搞定沟通的高手，只比你多做了一件事
# 6931.   饿了么成为外卖第一后，你所不知道的美团惊天逆袭真相
# 6932.   那个写从前慢的木心，究竟是个什么样的人？
# 6933.   阿里巴巴架构师：十问业务中台和我的答案
# 6934.   青春，总让人意犹未尽
# 6935.   重磅|吕廷杰：废除网络中立，数字经济生态重构的开端
# 6936.   题目二、外星人都做不出来的题
# 6937.   随着上周后半段降低印花税等利好出现，股市反弹强劲，市场乐观估计基金赎回潮将不会大规模发生。然而，笔者的判断恰恰相反，基金的赎回潮可能还没有到来，随着反弹进入末端
# 6938.   靠谱的人：凡事有交代，件件有着落，事事有回音
# 6939.   颜值在爱情里有多重要？让数学家来告诉你
# 6940.   首发 | 时间的朋友·2017罗振宇跨年演讲（精华版）
# 6941.   重磅发布！股神巴菲特2019年致股东公开信(全译文)_手机新浪网
# 6942.   年金是指收入或者支付间隔期相同\金额相等的款项.
# 6943.   高效工作的信息搜集及整理术
# 6944.   陈黎读诗：侵爱的，我对你的爱永远不便｜诗人读诗
# 6945.   阿里、京东、腾讯的新零售战略解析
#
# === 路径解析统计 ===
# 总文档数: 6945
# 成功获取路径的文档数: 6945
# 未获取到路径的文档数: 0
#
# === 层级深度分布 ===
# 第0层: 3个文档
# 第1层: 444个文档
# 第2层: 3308个文档
# 第3层: 3190个文档
#
# 文档树结构已保存到: output\doc_tree_剪藏笔记本.json
# 文档信息已保存到: output\docs_info_剪藏笔记本.json
# 可视化文档树已保存到: output\visual_tree_剪藏笔记本.txt
# 文档名称列表已保存到: output\doc_names_QuincyZou.txt
# 路径解析结果已保存到: output\doc_paths_剪藏笔记本.json

# %% [markdown]
# ## 获取文档的属性以及包含的块及内容

# %%
# 获取文档的属性以及包含的块及内容

def get_document_blocks(doc_id):
    """
    获取指定文档的所有块内容

    :param doc_id: 文档ID
    :return: 块列表
    """
    print(f"正在获取文档 {doc_id} 的所有块...")

    # 使用SQL查询获取文档的所有子块
    sql_query = f"""
    SELECT id, type, subtype, content, markdown, parent_id, sort, created, updated
    FROM blocks
    WHERE root_id = '{doc_id}'
    ORDER BY sort
    """

    data = call_siyuan_api("/api/query/sql", {"stmt": sql_query})

    if data and len(data) > 0:
        print(f"找到 {len(data)} 个块")
        return data
    else:
        print("未找到任何块")
        return []

def display_blocks(blocks):
    """
    格式化显示块内容

    :param blocks: 块列表
    """
    if not blocks:
        print("没有块可显示")
        return

    print("=" * 80)
    print(f"文档块结构 (共 {len(blocks)} 个块)")
    print("=" * 80)

    for i, block in enumerate(blocks, 1):
        block_type = block.get('type', 'unknown')
        subtype = block.get('subtype', '')
        content = block.get('content', '').strip()
        markdown = block.get('markdown', '').strip()
        parent_id = block.get('parent_id', '')
        block_id = block.get('id', '')
        created = block.get('created', '')
        updated = block.get('updated', '')

        # 根据块类型显示不同的图标
        type_icons = {
            'd': '📄',  # 文档
            'p': '📝',  # 段落
            'h': '📑',  # 标题
            'l': '📋',  # 列表
            'i': '🖼️',  # 列表项
            'b': '📦',  # 引用块
            'c': '💾',  # 代码块
            's': '🔄',  # 超级块
            't': '📊',  # 表格
            'm': '🔢',  # 数学公式
            'html': '🌐',  # HTML块
            'widget': '🔧',  # 挂件
            'iframe': '🖼️',  # iframe
            'video': '🎥',  # 视频
            'audio': '🔊',  # 音频
        }

        icon = type_icons.get(block_type, '📄')
        type_desc = f"{block_type}" + (f"/{subtype}" if subtype else "")

        print(f"\n{i:3d}. {icon} 块类型: {type_desc}")
        print(f"     📍 ID: {block_id}")
        print(f"     👆 父块: {parent_id}")
        print(f"     📅 创建: {created}")
        print(f"     🔄 更新: {updated}")

        if content:
            # 限制显示长度，避免输出过长
            display_content = content if len(content) <= 200 else content[:200] + "..."
            print(f"     💬 内容: {display_content}")

        if markdown and markdown != content:
            display_markdown = markdown if len(markdown) <= 200 else markdown[:200] + "..."
            print(f"     📝 Markdown: {display_markdown}")

        print("-" * 60)

def get_block_attributes(block_id):
    """
    获取指定块的属性

    :param block_id: 块 ID
    :return: 属性字典
    """
    payload = {"id": block_id}
    return call_siyuan_api("/api/attr/getBlockAttrs", payload)

def save_blocks_to_file(blocks, doc_id, output_dir="output"):
    """
    保存块信息到文件

    :param blocks: 块列表
    :param doc_id: 文档ID
    :param output_dir: 输出目录
    """
    output_path = Path(output_dir)
    output_path.mkdir(exist_ok=True)

    # 保存完整的块信息到JSON文件
    json_file = output_path / f"blocks_{doc_id}.json"
    with json_file.open('w', encoding='utf-8') as f:
        json.dump(blocks, f, ensure_ascii=False, indent=2)

    # 保存可读格式到文本文件
    txt_file = output_path / f"blocks_{doc_id}.txt"
    with txt_file.open('w', encoding='utf-8') as f:
        f.write(f"文档 {doc_id} 的块结构\n")
        f.write("=" * 60 + "\n\n")

        for i, block in enumerate(blocks, 1):
            f.write(f"{i:3d}. 块类型: {block.get('type', 'unknown')}\n")
            f.write(f"     ID: {block.get('id', '')}\n")
            f.write(f"     父块: {block.get('parent_id', '')}\n")
            f.write(f"     内容: {block.get('content', '').strip()}\n")
            if block.get('markdown'):
                f.write(f"     Markdown: {block.get('markdown', '').strip()}\n")
            f.write("-" * 40 + "\n")

    print(f"\n文件已保存:")
    print(f"  JSON格式: {json_file}")
    print(f"  文本格式: {txt_file}")

# 示例：指定要获取的文档ID
# 您可以修改这个ID为您想要查看的文档ID
DOC_ID = "20250618232924-ed8wf0w"  # 示例文档ID，请根据需要修改

print(f"开始获取文档 {DOC_ID} 的所有块内容...")
print()

# 获取块内容
blocks = get_document_blocks(DOC_ID)

if blocks:
    # 显示块内容
    display_blocks(blocks)

    attributes = get_block_attributes(DOC_ID)
    print(attributes)
    # 保存到文件
    save_blocks_to_file(blocks, DOC_ID)

    # 统计信息
    type_counts = {}
    for block in blocks:
        block_type = block.get('type', 'unknown')
        type_counts[block_type] = type_counts.get(block_type, 0) + 1

    print(f"\n📊 块类型统计:")
    for block_type, count in sorted(type_counts.items()):
        print(f"  {block_type}: {count} 个")
else:
    print("未能获取到块内容")
# Out:
# 开始获取文档 20250618232924-ed8wf0w 的所有块内容...
#
# 正在获取文档 20250618232924-ed8wf0w 的所有块...
# 找到 45 个块
# ================================================================================
# 文档块结构 (共 45 个块)
# ================================================================================
#
#   1. 📄 块类型: d
#      📍 ID: 20250618232924-ed8wf0w
#      👆 父块:
#      📅 创建: 20250618232924
#      🔄 更新: 20250618232924
#      💬 内容: 这个大模型，真的治好了我的论文阅读障碍
# ------------------------------------------------------------
#
#   2. 🌐 块类型: html
#      📍 ID: 20250618232925-ksxmn77
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# <!DOCTYPE html>
# </div>
# ------------------------------------------------------------
#
#   3. 🌐 块类型: html
#      📍 ID: 20250618232925-lcpavs3
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>这个大模型，真的治好了我的论文阅读障碍</title>
# </head>
# <body>
# <!doctype html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <head></head>
#   </head>
#   <body>
#    ...
# ------------------------------------------------------------
#
#   4. 📝 块类型: p
#      📍 ID: 20250618232925-qyikp5f
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 在腾讯「元宝」的最近一次更新中，我们看到了这些问题的解决方案。他们新推出的「深度阅读模式」支持长文精读，能够输出模块化的、图文并茂的解析，非常适合用来读论文。
#      📝 Markdown: 在腾讯「**元宝**」的最近一次更新中，我们看到了这些问题的解决方案。他们新推出的「**深度阅读模式**」支持**长文精读**，**能够输出模块化的、图文并茂的解析**，非常适合用来读论文。
# ------------------------------------------------------------
#
#   5. 📝 块类型: p
#      📍 ID: 20250618232925-j0qgthv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 为了验证这一新功能的效果，机器之心进行了一手实测。
# ------------------------------------------------------------
#
#   6. 📝 块类型: p
#      📍 ID: 20250618232925-ndzts7w
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 论文「精读」，精在哪儿？
#      📝 Markdown: **论文「精读」，精在哪儿？**
# ------------------------------------------------------------
#
#   7. 📝 块类型: p
#      📍 ID: 20250618232925-9qbt9en
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 用 AI 读论文是一种怎样的体验？很多时候是：你丢给它一个 PDF，它返回一段总结 + 若干条概述（有时候可能高达 10 条）。这些信息确实有帮助，但有时候，你很难分清哪些是亮点，以及论文解决了什么、没解决什么，有哪些核心问题值得细看。
# ------------------------------------------------------------
#
#   8. 📝 块类型: p
#      📍 ID: 20250618232925-e5tqd5e
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 我们实测发现，「元宝」是通过提供一系列模块化、结构化信息来解决这些问题的。
# ------------------------------------------------------------
#
#   9. 📝 块类型: p
#      📍 ID: 20250618232925-lp4mnwq
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 以我们测试的一篇 SIGGRAPH 论文为例。如果你直接把论文丢进去，它返回的总结和其他 AI 区别不大。不过，只要你耐心往下拉，就会看到一个「深度阅读该文档」的按钮，这才是「一键直达」论文精读的开关。
# ------------------------------------------------------------
#
#  10. 📝 块类型: p
#      📍 ID: 20250618232925-mezbn47
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_2-20250618232924-g1t0tnn.png
#      📝 Markdown: ![image](assets/640_2-20250618232924-g1t0tnn.png)
# ------------------------------------------------------------
#
#  11. 📝 块类型: p
#      📍 ID: 20250618232925-la4rqmw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 与之前总结论文的界面不同，精读页面会把论文拆解得非常有层次，研究背景、研究方法、实验设计、结果分析、总体结论各自被组织成一个模块，很像机器之心平时介绍论文的布局。所有这些都可以通过左边的大纲迅速跳转。
#      📝 Markdown: 与之前总结论文的界面不同，**精读页面会把论文拆解得非常有层次**，研究背景、研究方法、实验设计、结果分析、总体结论各自被组织成一个模块，很像机器之心平时介绍论文的布局。所有这些都可以通过左边的大纲迅速跳转。
# ------------------------------------------------------------
#
#  12. 📝 块类型: p
#      📍 ID: 20250618232925-q2c08rv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_3-20250618232924-7uq17ds.png
#      📝 Markdown: ![image](assets/640_3-20250618232924-7uq17ds.png)
# ------------------------------------------------------------
#
#  13. 📝 块类型: p
#      📍 ID: 20250618232925-qwi6458
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 别看每个模块字不多，其实这些字是非常有信息量的。比如在研究背景这个模块，「研究难点」段落仅用三个短句就描述了四个难点，「相关工作」更是对第二章「related work」的高度浓缩，一段话就把该领域的主要技术路线介绍清楚了。所以，在读完这个模块之后，我们能基本搞清楚论文研究的是一个什么问题，面临的是怎样一个研究现状。
# ------------------------------------------------------------
#
#  14. 📝 块类型: p
#      📍 ID: 20250618232925-bg1c6fb
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了这些常规的结构化信息，元宝的精读还有一个令人眼前一亮的设计 —— 它会把论文的优点与不足列出来，方便研究者迅速了解自己能从这篇论文中学到什么，还有什么问题值得继续研究。
#      📝 Markdown: 除了这些常规的结构化信息，元宝的精读还有一个令人眼前一亮的设计 —— **它会把论文的优点与不足列出来**，方便研究者迅速了解自己能从这篇论文中学到什么，还有什么问题值得继续研究。
# ------------------------------------------------------------
#
#  15. 📝 块类型: p
#      📍 ID: 20250618232925-i5rojyg
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_4-20250618232924-7wcgqv5.png
#      📝 Markdown: ![image](assets/640_4-20250618232924-7wcgqv5.png)
# ------------------------------------------------------------
#
#  16. 📝 块类型: p
#      📍 ID: 20250618232925-x7ooiaw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_5-20250618232924-zm8iiwz.png
#      📝 Markdown: ![image](assets/640_5-20250618232924-zm8iiwz.png)
# ------------------------------------------------------------
#
#  17. 📝 块类型: p
#      📍 ID: 20250618232925-d8xh6s1
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 为什么这个功能如此重要？中国台湾清华大学教授彭明辉在关于论文阅读的一篇文章中曾经写道，论文和课本不同，课本会提供别人整理、组织好的系统性知识，而论文要求读者自己从无组织的知识中检索、筛选、组织知识。其中，分析既有研究优缺点的能力尤其重要，这是批判性思维的关键部分，也是学术研究中自我提升的重要途径。元宝通过快速分析和总结论文的优缺点，可以帮助研究者节省大量筛选和初步理解的时间，使他们能够更快地聚焦于...
#      📝 Markdown: 为什么这个功能如此重要？中国台湾清华大学教授彭明辉在关于论文阅读的一篇文章中曾经写道，论文和课本不同，课本会提供别人整理、组织好的系统性知识，而论文要求读者自己从无组织的知识中检索、筛选、组织知识。其中，**分析既有研究优缺点的能力尤其重要，这是批判性思维的关键部分，也是学术研究中自我提升的重要途径**。元宝通过快速分析和总结论文的优缺点，可以帮助研究者节省大量筛选和初步理解的时间，使他们能够更快...
# ------------------------------------------------------------
#
#  18. 📝 块类型: p
#      📍 ID: 20250618232925-udiynou
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 不过，如果你觉得前面这些信息太繁琐，你也可以直接跳转到最后的「关键问题与解答」模块。这里会列出几个最关键的问题，让你快速了解到论文的价值，进而判断是否值得花时间去读原文。当然，之前的很多 AI 助手也会在答案末尾呈现一些关键问题，点一下就能得到答案，但如果你是一名初学者或者跨学科背景的读者，你可能不太容易判断哪些问题比较关键。元宝这种直接呈现的方式感觉更加直观。
#      📝 Markdown: 不过，如果你觉得前面这些信息太繁琐，你也可以直接跳转到最后的 **「关键问题与解答」模块**。这里会列出几个最关键的问题，让你快速了解到论文的价值，进而判断是否值得花时间去读原文。当然，之前的很多 AI 助手也会在答案末尾呈现一些关键问题，点一下就能得到答案，但如果你是一名初学者或者跨学科背景的读者，你可能不太容易判断哪些问题比较关键。元宝这种直接呈现的方式感觉更加直观。
# ------------------------------------------------------------
#
#  19. 📝 块类型: p
#      📍 ID: 20250618232925-mwmhayr
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_6-20250618232924-0sgh1t9.png
#      📝 Markdown: ![image](assets/640_6-20250618232924-0sgh1t9.png)
# ------------------------------------------------------------
#
#  20. 📝 块类型: p
#      📍 ID: 20250618232925-h9srjs7
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 原图原数，谁说 AI 读论文不能配图？
#      📝 Markdown: **原图原数，谁说 AI 读论文不能配图？**
# ------------------------------------------------------------
#
#  21. 📝 块类型: p
#      📍 ID: 20250618232925-ki4dswk
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 在读论文时，很多人都有一个习惯，一边看图，一边看论文描述。这样理解起来更快、更容易。但是，现在市面上大部分 AI 应用返回的都是文字结果，想看图的话需要自己去原文里找。
# ------------------------------------------------------------
#
#  22. 📝 块类型: p
#      📍 ID: 20250618232925-xwgzq18
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 我们在测试中发现，元宝是为数不多的直接把论文图截出来并放到段落对应位置的 AI。比如，如果在某个模块讲架构，那它会把对应的架构图放上：
#      📝 Markdown: 我们在测试中发现，**元宝是为数不多的直接把论文图截出来并放到段落对应位置的 AI**。比如，如果在某个模块讲架构，那它会把对应的架构图放上：
# ------------------------------------------------------------
#
#  23. 📝 块类型: p
#      📍 ID: 20250618232925-0m3pxz4
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_7-20250618232924-9d0ho0e.png
#      📝 Markdown: ![image](assets/640_7-20250618232924-9d0ho0e.png)
# ------------------------------------------------------------
#
#  24. 📝 块类型: p
#      📍 ID: 20250618232925-tuzna5p
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_8-20250618232924-3ec9sxb.png
#      📝 Markdown: ![image](assets/640_8-20250618232924-3ec9sxb.png)
# ------------------------------------------------------------
#
#  25. 📝 块类型: p
#      📍 ID: 20250618232925-c8fb1fw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 如果在某个模块讲实验结果，那它会把对应的图表放上：
# ------------------------------------------------------------
#
#  26. 📝 块类型: p
#      📍 ID: 20250618232925-sld5b8i
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_9-20250618232924-8xtz03t.png
#      📝 Markdown: ![image](assets/640_9-20250618232924-8xtz03t.png)
# ------------------------------------------------------------
#
#  27. 📝 块类型: p
#      📍 ID: 20250618232925-wbcvbo7
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_10-20250618232924-hrqfbcx.png
#      📝 Markdown: ![image](assets/640_10-20250618232924-hrqfbcx.png)
# ------------------------------------------------------------
#
#  28. 📝 块类型: p
#      📍 ID: 20250618232925-a40iuay
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 众所周知，大模型的幻觉问题现在还没有办法完全解决。因此，这种原图原数的呈现其实是一种更加可靠的输出方式，方便读者随时验证模型的答案，在用作参考时更加保险。
# ------------------------------------------------------------
#
#  29. 📝 块类型: p
#      📍 ID: 20250618232925-8qe5pb3
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 此外，我们还发现，如果你有写博客等对外输出的需求，元宝还可以帮你绘制图表，而且你不需要告诉它数据去哪里找，它能自己定位到论文中的相关表格，并将数据提取出来进行绘制。这一功能可以通过精读页面右侧的「提问」按钮来唤起。
# ------------------------------------------------------------
#
#  30. 📝 块类型: p
#      📍 ID: 20250618232925-bdpd5im
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_11-20250618232924-lhj4egm.png
#      📝 Markdown: ![image](assets/640_11-20250618232924-lhj4egm.png)
# ------------------------------------------------------------
#
#  31. 📝 块类型: p
#      📍 ID: 20250618232925-9sigu5g
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 随时随地想读就读，谁说读论文障碍重重？
#      📝 Markdown: **随时随地想读就读，谁说读论文障碍重重？**
# ------------------------------------------------------------
#
#  32. 📝 块类型: p
#      📍 ID: 20250618232925-wh5fo5w
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了结构化的信息和图文并茂的输出，我们在测试中还发现，元宝其实有一些非常实用的小功能，能让读论文这件事变得更加方便。
# ------------------------------------------------------------
#
#  33. 📝 块类型: p
#      📍 ID: 20250618232925-qqdg1tt
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 首先是划词翻译和搜索，这是「原文」阅读界面的两个实用小功能。划词翻译可以帮助英语不好的读者随时随地扫清语言障碍，划词搜索则更进一步，像是把元宝的搜索功能做成了一个插件，可以随时搜相关信息。而且，元宝给出的解释不只是简短的总结，还有模块化的展开，真是把「结构化」、「有信息量」做到每一个细节里了。
#      📝 Markdown: 首先是**划词翻译和搜索**，这是「原文」阅读界面的两个实用小功能。划词翻译可以帮助英语不好的读者随时随地扫清语言障碍，划词搜索则更进一步，像是把元宝的搜索功能做成了一个插件，可以随时搜相关信息。而且，元宝给出的解释不只是简短的总结，还有模块化的展开，真是把「结构化」、「有信息量」做到每一个细节里了。
# ------------------------------------------------------------
#
#  34. 📝 块类型: p
#      📍 ID: 20250618232925-kwwat0a
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_12-20250618232924-9tq4oc6.gif
#      📝 Markdown: ![image](assets/640_12-20250618232924-9tq4oc6.gif)
# ------------------------------------------------------------
#
#  35. 📝 块类型: p
#      📍 ID: 20250618232925-ua7u619
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_13-20250618232925-712fycw.gif
#      📝 Markdown: ![image](assets/640_13-20250618232925-712fycw.gif)
# ------------------------------------------------------------
#
#  36. 📝 块类型: p
#      📍 ID: 20250618232925-xocemfy
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 其次是「离线阅读」。这个功能的实用之处在于：它可以让你在「飞行模式」下回看精读内容及原文，不浪费一点碎片时间。这让航空公司在与高铁的竞争中扳回一局。说不定，研究者们的下一个灵感就是在飞机上回看精读时产生的呢。
#      📝 Markdown: 其次是「**离线阅读**」。这个功能的实用之处在于：它可以让你在「飞行模式」下回看精读内容及原文，不浪费一点碎片时间。这让航空公司在与高铁的竞争中扳回一局。说不定，研究者们的下一个灵感就是在飞机上回看精读时产生的呢。
# ------------------------------------------------------------
#
#  37. 📝 块类型: p
#      📍 ID: 20250618232925-r9boa3s
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_14-20250618232925-3pps49b.jpg
#      📝 Markdown: ![image](assets/640_14-20250618232925-3pps49b.jpg)
# ------------------------------------------------------------
#
#  38. 📝 块类型: p
#      📍 ID: 20250618232925-9isicnb
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 最后一个小功能是「计算器」。前段时间，AI 因为分不清 9.9 和 9.11 哪个大而引发了很多讨论。在元宝中，我们发现它集成了计算器功能，能够确保根据准确的计算结果来生成答案。这种功能在我们阅读实验数据时非常有用。
#      📝 Markdown: 最后一个小功能是「**计算器**」。前段时间，AI 因为分不清 9.9 和 9.11 哪个大而引发了很多讨论。在元宝中，我们发现它集成了计算器功能，能够确保根据准确的计算结果来生成答案。这种功能在我们阅读实验数据时非常有用。
# ------------------------------------------------------------
#
#  39. 📝 块类型: p
#      📍 ID: 20250618232925-3e59xx9
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 长文精读的背后：原来有专家指导
#      📝 Markdown: **长文精读的背后：原来有专家指导**
# ------------------------------------------------------------
#
#  40. 📝 块类型: p
#      📍 ID: 20250618232925-04scg83
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 根据官方信息，腾讯元宝的这次升级主打「长文精读」，可原生支持最长近 50 万字的输入。我们在测试中用到的论文远远没有达到这个长度，日常所接触的论文大多也达不到。所以用元宝来精读论文，大部分情况下上下文窗口都是够用的。它的模块化、图文并茂输出以及划词搜索、翻译等小功能也让读论文这件事真正变得方便、高效，向着「实用性」又迈近了一步。
# ------------------------------------------------------------
#
#  41. 📝 块类型: p
#      📍 ID: 20250618232925-u1h5qrh
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 这种进化离不开其背后模型 —— 腾讯混元大模型的升级。据悉，为了在专业领域中提升模型的专业性和实用性，腾讯混元团队专门邀请领域专家概括各专业领域的核心技能，并制定了专业问题的回答标准，使得模型能够作为真正的领域专家来提供服务。所以我们用下来就感觉，元宝是知道论文读者需要什么信息以及信息应该如何呈现的。
#      📝 Markdown: 这种进化离不开其背后模型 —— 腾讯混元大模型的升级。据悉，为了在专业领域中提升模型的专业性和实用性，腾讯混元团队**专门邀请领域专家概括各专业领域的核心技能，并制定了专业问题的回答标准**，使得模型能够作为真正的领域专家来提供服务。所以我们用下来就感觉，元宝是知道论文读者需要什么信息以及信息应该如何呈现的。
# ------------------------------------------------------------
#
#  42. 📝 块类型: p
#      📍 ID: 20250618232925-zgmh29e
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了论文，这个新功能还可以用来精读财报、研报等长文本。在这些场景中，它可以从多个维度梳理信息，根据报告内容生成杜邦分析图等专业图表，让不懂这些文件的人也能看懂企业的财务状况等信息。
#      📝 Markdown: 除了论文，这个新功能还可以用来精读**财报、研报**等长文本。在这些场景中，它可以从多个维度梳理信息，根据报告内容生成杜邦分析图等专业图表，让不懂这些文件的人也能看懂企业的财务状况等信息。
# ------------------------------------------------------------
#
#  43. 📝 块类型: p
#      📍 ID: 20250618232925-onh1mn2
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_15-20250618232925-fa0beu6.gif
#      📝 Markdown: ![image](assets/640_15-20250618232925-fa0beu6.gif)
# ------------------------------------------------------------
#
#  44. 📝 块类型: p
#      📍 ID: 20250618232925-4hdadlv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 不过，就读论文这个场景来说，元宝依然存在一些改进空间，比如在阅读原文界面缺乏完整的原文 - 译文对照，对公式的识别有时不够准确等。我们也希望元宝能在未来的更新中改进这些问题。</pre>
# ------------------------------------------------------------
#
#  45. 🌐 块类型: html
#      📍 ID: 20250618232925-a0qnofv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# </body>
# </html>
# </body>
# </html>
# </div>
# ------------------------------------------------------------
# {'custom-abstract': '<nil>', 'custom-accessed': '2024-09-03 22:36:43 +0000 UTC', 'custom-attachmentCount': '0', 'custom-author': '<nil>', 'custom-category': '/兴趣爱好/AIGC/', 'custom-created': '2024-08-18 09:02:36 +0000 UTC', 'custom-docGuid': '7986491f-fba2-4d29-a20f-4c587692ad73', 'custom-keywords': '<nil>', 'custom-modified': '<nil>', 'custom-readCount': '0', 'custom-resources': '[]', 'custom-url': 'https://mp.weixin.qq.com/s/mC1N8qdHwli6bufPLX_LWg', 'custom-version': '153404', 'id': '20250618232924-ed8wf0w', 'tags': '已读', 'title': '这个大模型，真的治好了我的论文阅读障碍', 'type': 'doc', 'updated': '20250618232924'}
#
# 文件已保存:
#   JSON格式: output\blocks_20250618232924-ed8wf0w.json
#   文本格式: output\blocks_20250618232924-ed8wf0w.txt
#
# 📊 块类型统计:
#   d: 1 个
#   html: 3 个
#   p: 41 个

# %%
# 获取文档块的kramdown源码
doc_id = "20250621081403-hx0zl8u"
payload = {"id": doc_id}
data = call_siyuan_api("/api/block/getBlockKramdown", payload)

def print_dict_structure(data, indent=0):
    """递归打印字典结构，每一层都有适当的缩进"""
    if isinstance(data, dict):
        for key, value in data.items():
            print("  " * indent + f"{key}:")
            if isinstance(value, (dict, list)):
                print_dict_structure(value, indent + 1)
            else:
                print("  " * (indent + 1) + str(value))
    elif isinstance(data, list):
        for i, item in enumerate(data):
            print("  " * indent + f"[{i}]:")
            if isinstance(item, (dict, list)):
                print_dict_structure(item, indent + 1)
            else:
                print("  " * (indent + 1) + str(item))
    else:
        print("  " * indent + str(data))

print_dict_structure(data)
# Out:
# id:
#   20250621081403-hx0zl8u
# kramdown:
#   > 为知笔记迁移文档自定义属性：
# > abstract: <nil>
# > url: [https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848](https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848)
# > created: 2025-06-09 23:04:19 +0000 UTC
# > accessed: 2025-06-12 12:31:36 +0000 UTC
# > modified: <nil>
# > {: id="20250621135634-nggyytp" updated="20250621135634"}
# >
# {: id="20250621135634-nu0eacg" updated="20250621135634"}
#
# # 苹果重磅论文翻车！被指测试方法有大问题……网友：Cook 该裁员了！
# {: updated="20250621105403" id="20250621081403-clxqrix"}
#
# 2025-06-09 17:43·[人工智能学家](https://www.toutiao.com/c/user/token/MS4wLjABAAAAopm85qB5EHed92CocYuWSjILG4hacNLOMeKOxKXTHGk/?source=tuwen_detail)
# {: id="20250621081403-8gvt7q6" updated="20250615183338"}
#
# 来源：AGI Hunt
# {: id="20250621081403-tgzjxng" updated="20250615183338"}
#
# **苹果的AI 研究团队这次真的翻车了！**
# {: id="20250621081403-ghxk2dy" updated="20250615183338"}
#
# 他们最近发布的一篇论文引发了AI 圈的集体吐槽，原因竟然是**测试方法出了大问题**。
# {: id="20250621081403-gba3sqo" updated="20250615183338"}
#
# ![image](assets/5e3c075bb3b21ecc3bae51e4b8a175df-20250615183338-vocbet6.jpg)
# {: id="20250621081403-d3xebaz" updated="20250615183338"}
#
# 见前文：苹果宣判推理模型死刑！Google CEO：忘了AGI吧，先用好AJI
# {: id="20250621081403-xy9amr8" updated="20250615183338"}
#
# 研究者Lisan al Gaib在复现苹果论文中的汉诺塔（Tower of Hanoi）测试后发现了一个惊人的事实：**模型根本不是因为推理能力不行而失败，而是因为输出token限制！**
# {: id="20250621081403-7p1if9k" updated="20250615183338"}
#
# ![image](assets/60ef00128e5cf80619d90503519d1757-20250615183338-oktw4wi.jpg)
# {: id="20250621081403-cyyfl0e" updated="20250615183338"}
#
# 要知道，汉诺塔问题需要**至少2^N - 1步**才能解决，而输出格式需要每步10个token外加一些固定内容。
# {: updated="20250615183338" id="20250621081403-159tyw2"}
#
# 这意味着什么？
# {: id="20250621081403-utt76ju" updated="20250615183338"}
#
# {: custom-abstract="&lt;nil&gt;" custom-accessed="2025-06-12 12:31:36 +0000 UTC" custom-attachmentCount="0" custom-author="&lt;nil&gt;" custom-category="/My Emails/" custom-created="2025-06-09 23:04:19 +0000 UTC" custom-docGuid="38002001-6d85-41c2-a1ec-a75f9ed33571" custom-keywords="&lt;nil&gt;" custom-modified="&lt;nil&gt;" custom-readCount="0" custom-resources="[]" custom-url="https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848" custom-version="179271" id="20250621081403-hx0zl8u" title="自定义属性，含url" type="doc" updated="20250621135634"}
