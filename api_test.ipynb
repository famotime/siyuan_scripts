# %% [markdown]
# ## 基础配置

# %%
# 使用functions.py模块简化API操作
import json
from pathlib import Path
from functions import (
    create_siyuan_client, create_managers,
    FileManager, TreeProcessor
)

# 创建API客户端和管理器
print("正在初始化思源笔记API客户端...")
api_client = create_siyuan_client()
notebook_manager, document_manager, block_manager = create_managers(api_client)
print("✓ API客户端和管理器初始化完成")
# Out:
# 正在初始化思源笔记API客户端...
# ✓ API客户端和管理器初始化完成

# %% [markdown]
# ## 获取笔记本列表

# %%
def get_notebooks():
    """获取所有笔记本列表（使用functions.py模块）"""
    print("正在获取笔记本列表...")

    try:
        # 使用NotebookManager获取笔记本列表
        notebooks = notebook_manager.list_notebooks()

        if notebooks:
            print(f"成功获取到 {len(notebooks)} 个笔记本:")
            print("-" * 60)

            for notebook in notebooks:
                print(f"📖 {notebook['name']} ({notebook['id']}) 状态: {'关闭' if notebook['closed'] else '打开'}")
                print("-" * 60)

            return notebooks
        else:
            print("未获取到笔记本")
            return None

    except Exception as e:
        print(f"获取笔记本列表失败: {e}")
        return None

# 执行获取笔记本列表
notebooks = get_notebooks()
# Out:
# 2025-06-21 21:33:04,754 - INFO - 正在获取笔记本列表...
# 2025-06-21 21:33:04,761 - INFO - 找到 3 个笔记本
# 正在获取笔记本列表...
# 成功获取到 3 个笔记本:
# ------------------------------------------------------------
# 📖 思源笔记用户指南 (20210808180117-czj9bvb) 状态: 打开
# ------------------------------------------------------------
# 📖 QuincyZou (20250614224007-27h8mrb) 状态: 打开
# ------------------------------------------------------------
# 📖 剪藏笔记本 (20250618232716-bvztpaf) 状态: 打开
# ------------------------------------------------------------

# %% [markdown]
# ## 获取笔记本包含的文档列表

# %%
# 获取一个笔记本下的文档列表（使用functions.py模块）
notebook = notebooks[1]

# 配置参数：设置获取文档的最大层级深度（-1表示无限制）
MAX_DEPTH = 3  # 可以修改这个值来控制层级深度，设为-1表示获取所有层级

print(f"正在获取笔记本 '{notebook['name']}' 下的文档列表...")
print(f"笔记本ID: {notebook['id']}")
print(f"最大层级深度: {'无限制' if MAX_DEPTH == -1 else MAX_DEPTH}")
print("-" * 60)

# 使用DocumentManager获取文档树结构
tree_data = document_manager.get_doc_tree(notebook['id'], "/")

if tree_data:
    # 用于记录所有文档信息的列表
    all_docs_info = []

    # 首先收集指定深度内的所有文档ID
    def collect_doc_ids_with_depth(nodes, current_depth=0):
        """递归收集指定深度内的所有文档ID"""
        doc_ids = []
        for node in nodes:
            doc_id = node.get("id", "")
            if doc_id:
                doc_ids.append(doc_id)

            # 检查是否需要继续递归（根据深度限制）
            if "children" in node and (MAX_DEPTH == -1 or current_depth < MAX_DEPTH):
                doc_ids.extend(collect_doc_ids_with_depth(node["children"], current_depth + 1))
        return doc_ids

    print("正在收集指定深度内的文档ID...")
    all_doc_ids = collect_doc_ids_with_depth(tree_data)
    print(f"收集到 {len(all_doc_ids)} 个文档ID")

    # 批量获取所有文档的路径
    print("正在批量获取文档路径...")
    doc_paths = {}

    for doc_id in all_doc_ids:
        result = api_client.call_api("/api/filetree/getHPathByID", {"id": doc_id})
        if result:
            doc_paths[doc_id] = result
        else:
            doc_paths[doc_id] = "未知路径"

    print(f"成功获取 {len(doc_paths)} 个文档的路径")

    def parse_doc_name_from_path(hpath):
        """从人类可读路径中解析文档名称"""
        if not hpath or hpath == "未知路径":
            return "未知文档"

        # 从路径中提取最后一部分作为文档名称
        parts = hpath.strip('/').split('/')
        if parts and parts[-1]:
            return parts[-1]
        return "未知文档"

    def get_doc_info(doc_id):
        """获取文档的名称和路径信息"""
        hpath = doc_paths.get(doc_id, "未知路径")
        doc_name = parse_doc_name_from_path(hpath)
        return doc_name, hpath

    def print_doc_tree(nodes, level=0):
        """递归打印文档树结构"""
        # 检查是否超过最大深度限制
        if MAX_DEPTH != -1 and level > MAX_DEPTH:
            return

        for node in nodes:
            doc_id = node.get("id", "")

            # 从路径解析获取文档信息
            doc_title, doc_hpath = get_doc_info(doc_id)

            # 检查是否有子文档
            has_children = "children" in node and len(node["children"]) > 0
            folder_icon = "📁" if has_children else "📄"

            # 创建可视化的层级缩进
            if level == 0:
                indent = ""
                tree_symbol = ""
            else:
                # 使用树状符号来表示层级关系
                indent = "│   " * (level - 1)
                tree_symbol = "├── "

            # 打印文档信息（增强的可视化层级）
            print(f"{indent}{tree_symbol}{folder_icon} {doc_title}")
            print(f"{indent}{'    ' if level > 0 else ''}   📍 ID: {doc_id}")
            # print(f"{indent}{'    ' if level > 0 else ''}   📊 层级: {level}")
            print(f"{indent}{'    ' if level > 0 else ''}   📂 路径: {doc_hpath}")

            # 记录文档信息到列表中
            doc_info = {
                "id": doc_id,
                "name": doc_title,
                "level": level,
                "has_children": has_children,
                "hpath": doc_hpath,
                "parent_path": "/".join(doc_hpath.strip('/').split('/')[:-1]) if doc_hpath != "未知路径" else "root"
            }
            all_docs_info.append(doc_info)

            # 递归处理子文档（考虑深度限制）
            if has_children and (MAX_DEPTH == -1 or level < MAX_DEPTH):
                print_doc_tree(node["children"], level + 1)

            print()

    print_doc_tree(tree_data)

    # 统计文档数量
    def count_docs(nodes):
        count = 0
        for node in nodes:
            count += 1
            if "children" in node:
                count += count_docs(node["children"])
        return count

    total_docs = count_docs(tree_data)
    print(f"总计文档数量: {total_docs}")
    print(f"记录的文档信息数量: {len(all_docs_info)}")

    # 打印文档统计信息
    print("\n=== 文档统计信息 ===")
    level_counts = {}
    for doc in all_docs_info:
        level = doc['level']
        level_counts[level] = level_counts.get(level, 0) + 1

    for level in sorted(level_counts.keys()):
        print(f"第{level}层文档: {level_counts[level]}个")

    # 打印所有文档的name属性
    print("\n=== 所有文档名称列表 ===")
    for i, doc in enumerate(all_docs_info, 1):
        indent = "  " * doc['level']
        print(f"{i:3d}. {indent}{doc['name']}")

    # 保存文档树结构到JSON文件
    output_dir = Path("output")
    output_dir.mkdir(exist_ok=True)

    # 保存原始API数据（使用FileManager）
    output_file = output_dir / f"doc_tree_{notebook['name']}.json"
    FileManager.save_json_file(tree_data, str(output_file))

    # 保存整理后的文档信息（使用FileManager）
    docs_info_file = output_dir / f"docs_info_{notebook['name']}.json"
    FileManager.save_json_file(all_docs_info, str(docs_info_file))

    # 保存可视化格式的文档树结构
    visual_file = output_dir / f"visual_tree_{notebook['name']}.txt"

    def save_visual_tree(nodes, f, level=0):
        """递归保存可视化的文档树结构到文件"""
        # 检查是否超过最大深度限制
        if MAX_DEPTH != -1 and level > MAX_DEPTH:
            return

        for node in nodes:
            doc_id = node.get("id", "")

            # 从路径解析获取文档信息
            doc_title, doc_hpath = get_doc_info(doc_id)

            # 检查是否有子文档
            has_children = "children" in node and len(node["children"]) > 0
            folder_icon = "📁" if has_children else "📄"

            # 创建可视化的层级缩进
            if level == 0:
                indent = ""
                tree_symbol = ""
            else:
                # 使用树状符号来表示层级关系
                indent = "│   " * (level - 1)
                tree_symbol = "├── "

            # 写入文档信息（增强的可视化层级）
            f.write(f"{indent}{tree_symbol}{folder_icon} {doc_title}\n")
            f.write(f"{indent}{'    ' if level > 0 else ''}   📍 ID: {doc_id}\n")
            # f.write(f"{indent}{'    ' if level > 0 else ''}   📊 层级: {level}\n")
            f.write(f"{indent}{'    ' if level > 0 else ''}   📂 路径: {doc_hpath}\n")

            # 递归处理子文档（考虑深度限制）
            if has_children and (MAX_DEPTH == -1 or level < MAX_DEPTH):
                save_visual_tree(node["children"], f, level + 1)

            f.write("\n")

    with visual_file.open('w', encoding='utf-8') as f:
        f.write(f"笔记本: {notebook['name']}\n")
        f.write(f"笔记本ID: {notebook['id']}\n")
        f.write(f"最大层级深度: {'无限制' if MAX_DEPTH == -1 else MAX_DEPTH}\n")
        f.write(f"总文档数: {len(all_docs_info)}\n")
        f.write(f"成功获取路径数: {len(doc_paths)}\n")
        f.write("=" * 60 + "\n\n")

        # 保存可视化树结构
        save_visual_tree(tree_data, f)

    # 保存路径解析结果（文档ID和路径的映射，使用FileManager）
    paths_file = output_dir / f"doc_paths_{notebook['name']}.json"
    FileManager.save_json_file(doc_paths, str(paths_file))

    # 打印路径解析统计信息
    print(f"\n=== 路径解析统计 ===")
    print(f"总文档数: {len(all_doc_ids)}")
    print(f"成功获取路径的文档数: {len(doc_paths)}")
    print(f"未获取到路径的文档数: {len(all_doc_ids) - len(doc_paths)}")

    # 统计路径深度分布
    depth_distribution = {}
    for doc in all_docs_info:
        depth = doc['level']
        depth_distribution[depth] = depth_distribution.get(depth, 0) + 1

    print(f"\n=== 层级深度分布 ===")
    for depth in sorted(depth_distribution.keys()):
        print(f"第{depth}层: {depth_distribution[depth]}个文档")

    print(f"\n文档树结构已保存到: {output_file}")
    print(f"文档信息已保存到: {docs_info_file}")
    print(f"可视化文档树已保存到: {visual_file}")
    print(f"路径解析结果已保存到: {paths_file}")

else:
    print("获取文档树失败，尝试使用SQL查询...")

    # 备用方案：使用DocumentManager的SQL查询获取文档列表
    sql_result = document_manager.get_notebook_docs_by_sql(notebook['id'])

    # 如果需要详细信息，可以使用原始SQL查询
    if not sql_result:
        sql_query = f"SELECT id, content, hpath FROM blocks WHERE box = '{notebook['id']}' AND type = 'd' ORDER BY created"
        sql_result = api_client.call_api("/api/query/sql", {"stmt": sql_query})

    if sql_result:
        print(f"通过SQL查询找到 {len(sql_result)} 个文档:")
        print("-" * 60)

        for doc in sql_result:
            print(f"📄 {doc.get('content', '无标题')}")
            print(f"   ID: {doc.get('id', '')}")
            print(f"   路径: {doc.get('hpath', '')}")
            print("-" * 40)

        # 保存SQL查询结果（使用FileManager）
        output_dir = Path("output")
        output_dir.mkdir(exist_ok=True)
        sql_output_file = output_dir / f"docs_sql_{notebook['name']}.json"
        FileManager.save_json_file(sql_result, str(sql_output_file))

        print(f"SQL查询结果已保存到: {sql_output_file}")
    else:
        print("SQL查询也失败了")
# Out:
# 2025-06-21 22:16:29,557 - INFO - 正在获取笔记本 20250614224007-27h8mrb 的文档树结构...
# 2025-06-21 22:16:29,591 - INFO - 获取到文档树，包含 7 个根节点
# 正在获取笔记本 'QuincyZou' 下的文档列表...
# 笔记本ID: 20250614224007-27h8mrb
# 最大层级深度: 3
# ------------------------------------------------------------
# 正在收集指定深度内的文档ID...
# 收集到 2649 个文档ID
# 正在批量获取文档路径...
# 2025-06-21 22:16:36,917 - INFO - 数据已保存到: output\doc_tree_QuincyZou.json
# 2025-06-21 22:16:36,950 - INFO - 数据已保存到: output\docs_info_QuincyZou.json
# 2025-06-21 22:16:36,966 - INFO - 数据已保存到: output\doc_paths_QuincyZou.json
# 成功获取 2649 个文档的路径
# 📁 我的草稿
#    📍 ID: 20250614231211-tibb8w3
#    📂 路径: /我的草稿
# ├── 📄 百度网盘视频素材转存进度
#        📍 ID: 20250614231211-9f9bx4c
#        📂 路径: /我的草稿/百度网盘视频素材转存进度
#
# ├── 📄 YouTube视频解析
#        📍 ID: 20250614231211-9g3qd2g
#        📂 路径: /我的草稿/YouTube视频解析
#
# ├── 📄 碎笔记20250608
#        📍 ID: 20250614231211-9mms44m
#        📂 路径: /我的草稿/碎笔记20250608
#
# ├── 📄 给开发者推荐6个必用的开源MCP服务器.md
#        📍 ID: 20250614231211-bz494qh
#        📂 路径: /我的草稿/给开发者推荐6个必用的开源MCP服务器.md
#
# ├── 📄 私人Prompt
#        📍 ID: 20250614231211-cg6d6qc
#        📂 路径: /我的草稿/私人Prompt
#
# ├── 📄 个人助理会是普通人的 AGI 吗？
#        📍 ID: 20250614231211-fu4mjn9
#        📂 路径: /我的草稿/个人助理会是普通人的 AGI 吗？
#
# ├── 📄 请按以下文章大纲
#        📍 ID: 20250614231211-jsd505c
#        📂 路径: /我的草稿/请按以下文章大纲
#
# ├── 📁 苹果的未来还可期吗？——从WWDC2024到WWDC2025
#        📍 ID: 20250614231211-kon2kr7
#        📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025
# │   ├── 📄 苹果AI“暴论”震动AI圈，DeepSeek、Claude等热门大模型只是死记的模式机器？
# │          📍 ID: 20250614231211-97m9dno
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/苹果AI“暴论”震动AI圈，DeepSeek、Claude等热门大模型只是死记的模式机器？
#
# │   ├── 📄 苹果公司创新机制深度分析_
# │          📍 ID: 20250615150514-3rhzhne
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/苹果公司创新机制深度分析_
#
# │   ├── 📄 iOS游戏发展与未来策略_
# │          📍 ID: 20250615150514-6rf1wqa
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/iOS游戏发展与未来策略_
#
# │   ├── 📄 对苹果公司“思维的幻象”论文中汉诺塔测试失败原因的分析：输出Token限制还是推理能力缺陷？
# │          📍 ID: 20250615150514-ae3rjac
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/对苹果公司“思维的幻象”论文中汉诺塔测试失败原因的分析：输出Token限制还是推理能力缺陷？
#
# │   ├── 📄 苹果Liquid_Glass设计分析_
# │          📍 ID: 20250615150514-cwq80q4
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/苹果Liquid_Glass设计分析_
#
# │   ├── 📄 苹果Siri发展历程与展望_
# │          📍 ID: 20250615150514-is0u4cl
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/苹果Siri发展历程与展望_
#
# │   ├── 📄 思维的幻象：解构苹果AI研究、争议及其对缓慢创新的启示
# │          📍 ID: 20250615150514-suwnkva
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/思维的幻象：解构苹果AI研究、争议及其对缓慢创新的启示
#
# │   ├── 📄 苹果AI特性：交付与展望_
# │          📍 ID: 20250615150514-x05b2zp
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/苹果AI特性：交付与展望_
#
# │   ├── 📄 实用主义与悖论：在技术变局中解析苹果的AI战略
# │          📍 ID: 20250615164756-bz7vti7
# │          📂 路径: /我的草稿/苹果的未来还可期吗？——从WWDC2024到WWDC2025/实用主义与悖论：在技术变局中解析苹果的AI战略
#
#
# ├── 📄 谈小微应用开发平台（包括Agent构建平台）【2024.8】.md
#        📍 ID: 20250614231211-n558kta
#        📂 路径: /我的草稿/谈小微应用开发平台（包括Agent构建平台）【2024.8】.md
#
# ├── 📄 《高手的黑箱》中的Prompt & Agent
#        📍 ID: 20250614231211-npa1qh9
#        📂 路径: /我的草稿/《高手的黑箱》中的Prompt & Agent
#
# ├── 📄 铁原，应该被叫做血原的 —— 永不该被遗忘的铁原阻击战（尾声）
#        📍 ID: 20250614231211-nslcr98
#        📂 路径: /我的草稿/铁原，应该被叫做血原的 —— 永不该被遗忘的铁原阻击战（尾声）
#
# ├── 📄 高手的黑箱（上） 01~20 —— AI时代学习、思考与创作.md
#        📍 ID: 20250614231211-oyq6v8g
#        📂 路径: /我的草稿/高手的黑箱（上） 01~20 —— AI时代学习、思考与创作.md
#
# ├── 📄 如何使用Bolt.new高效构建网站、Web 应用和移动应用
#        📍 ID: 20250614231211-qwe9a69
#        📂 路径: /我的草稿/如何使用Bolt.new高效构建网站、Web 应用和移动应用
#
# ├── 📄 Coreen士仪：我怎么看Circle成为首个在纽交所上市的稳定币企业？.md
#        📍 ID: 20250614231211-r9wl6e2
#        📂 路径: /我的草稿/Coreen士仪：我怎么看Circle成为首个在纽交所上市的稳定币企业？.md
#
# ├── 📄 百度网盘素材链接——已存
#        📍 ID: 20250614231211-rrk8z6f
#        📂 路径: /我的草稿/百度网盘素材链接——已存
#
# ├── 📄 AI编程产品功能对比分析_
#        📍 ID: 20250614231211-t0hdock
#        📂 路径: /我的草稿/AI编程产品功能对比分析_
#
# ├── 📁 碎想法：学习、实践、创作
#        📍 ID: 20250614231211-td8xjfy
#        📂 路径: /我的草稿/碎想法：学习、实践、创作
# │   ├── 📄 Pose Director“摄影师模式”介绍.md
# │          📍 ID: 20250614231211-3jfpgz5
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/Pose Director“摄影师模式”介绍.md
#
# │   ├── 📄 选择困难症？我掏出一个AI选择器
# │          📍 ID: 20250614231211-6jle95v
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/选择困难症？我掏出一个AI选择器
#
# │   ├── 📄 AI代码安全与优化审计SaaS服务
# │          📍 ID: 20250614231211-l6h7max
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/AI代码安全与优化审计SaaS服务
#
# │   ├── 📄 构建一个AI 简历与求职信生成SaaS服务
# │          📍 ID: 20250614231211-lb6true
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/构建一个AI 简历与求职信生成SaaS服务
#
# │   ├── 📄 AI_SaaS_案例分析与构想_.md
# │          📍 ID: 20250614231211-lyspljd
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/AI_SaaS_案例分析与构想_.md
#
# │   ├── 📄 超个性化冷启动外联内容生成器
# │          📍 ID: 20250614231211-o72ch90
# │          📂 路径: /我的草稿/碎想法：学习、实践、创作/超个性化冷启动外联内容生成器
#
#
# ├── 📄 Open Interpreter + LM Studio + Ilama3执行本地数据分析任务
#        📍 ID: 20250614231211-u4fyrbs
#        📂 路径: /我的草稿/Open Interpreter + LM Studio + Ilama3执行本地数据分析任务
#
# ├── 📄 高手的黑箱（下） 21~43 —— AI时代学习、思考与创作.md
#        📍 ID: 20250614231211-uqa72vo
#        📂 路径: /我的草稿/高手的黑箱（下） 21~43 —— AI时代学习、思考与创作.md
#
# ├── 📄 面向独立开发者的 30 个热门 AI SaaS 细分市场机遇（2025 年）.md
#        📍 ID: 20250614231211-y0ghinx
#        📂 路径: /我的草稿/面向独立开发者的 30 个热门 AI SaaS 细分市场机遇（2025 年）.md
#
# ├── 📄 一个苦命人 - 故事梗概
#        📍 ID: 20250614231211-zr2b2oo
#        📂 路径: /我的草稿/一个苦命人 - 故事梗概
#
# ├── 📄 一部饱受争议的邪书，却成为文学史上的不朽经典！
#        📍 ID: 20250615092218-99qe4ly
#        📂 路径: /我的草稿/一部饱受争议的邪书，却成为文学史上的不朽经典！
#
# ├── 📄 别了，为知笔记
#        📍 ID: 20250616215914-jytf1xx
#        📂 路径: /我的草稿/别了，为知笔记
#
#
# 📁 我的日记
#    📍 ID: 20250615121616-b8wqego
#    📂 路径: /我的日记
# ├── 📄 2022-03
#        📍 ID: 20250615121616-mz2igvd
#        📂 路径: /我的日记/2022-03
#
# ├── 📄 2022-01
#        📍 ID: 20250615121616-ow36p47
#        📂 路径: /我的日记/2022-01
#
# ├── 📄 2022-04
#        📍 ID: 20250615121616-th7ut1u
#        📂 路径: /我的日记/2022-04
#
# ├── 📄 2022-02
#        📍 ID: 20250615121616-yzvdijq
#        📂 路径: /我的日记/2022-02
#
# ├── 📄 2025-04.md
#        📍 ID: 20250615121617-0jhujoa
#        📂 路径: /我的日记/2025-04.md
#
# ├── 📄 2022-09
#        📍 ID: 20250615121617-0sx8q32
#        📂 路径: /我的日记/2022-09
#
# ├── 📄 童年回忆碎片
#        📍 ID: 20250615121617-2rcwzgn
#        📂 路径: /我的日记/童年回忆碎片
#
# ├── 📄 2024年10月日记.md
#        📍 ID: 20250615121617-4z57xns
#        📂 路径: /我的日记/2024年10月日记.md
#
# ├── 📄 2022-12
#        📍 ID: 20250615121617-64w4pl2
#        📂 路径: /我的日记/2022-12
#
# ├── 📄 2025-08.md
#        📍 ID: 20250615121617-7qoxw8w
#        📂 路径: /我的日记/2025-08.md
#
# ├── 📄 日记模板
#        📍 ID: 20250615121617-af4brlx
#        📂 路径: /我的日记/日记模板
#
# ├── 📄 2023-05.md
#        📍 ID: 20250615121617-anr7zos
#        📂 路径: /我的日记/2023-05.md
#
# ├── 📄 2023-10.md
#        📍 ID: 20250615121617-bhzpetn
#        📂 路径: /我的日记/2023-10.md
#
# ├── 📄 2024-07.md
#        📍 ID: 20250615121617-bzrw1zt
#        📂 路径: /我的日记/2024-07.md
#
# ├── 📄 2025-02.md
#        📍 ID: 20250615121617-c19vwgh
#        📂 路径: /我的日记/2025-02.md
#
# ├── 📄 2025-11.md
#        📍 ID: 20250615121617-c70v51c
#        📂 路径: /我的日记/2025-11.md
#
# ├── 📄 2023-11.md
#        📍 ID: 20250615121617-czlncfu
#        📂 路径: /我的日记/2023-11.md
#
# ├── 📄 2024-04.md
#        📍 ID: 20250615121617-etpnh79
#        📂 路径: /我的日记/2024-04.md
#
# ├── 📄 2024-02.md
#        📍 ID: 20250615121617-eyhl7fw
#        📂 路径: /我的日记/2024-02.md
#
# ├── 📄 2022-10
#        📍 ID: 20250615121617-flng5c0
#        📂 路径: /我的日记/2022-10
#
# ├── 📄 2025-07.md
#        📍 ID: 20250615121617-fobv6ee
#        📂 路径: /我的日记/2025-07.md
#
# ├── 📄 2024-11.md
#        📍 ID: 20250615121617-h2dd3m2
#        📂 路径: /我的日记/2024-11.md
#
# ├── 📄 2023-04.md
#        📍 ID: 20250615121617-hhqdvk2
#        📂 路径: /我的日记/2023-04.md
#
# ├── 📄 2022-06
#        📍 ID: 20250615121617-hkv7hzv
#        📂 路径: /我的日记/2022-06
#
# ├── 📄 2023-01.md
#        📍 ID: 20250615121617-ie59yos
#        📂 路径: /我的日记/2023-01.md
#
# ├── 📄 2025-05.md
#        📍 ID: 20250615121617-j18f3qu
#        📂 路径: /我的日记/2025-05.md
#
# ├── 📄 2023-02.md
#        📍 ID: 20250615121617-jxdt16z
#        📂 路径: /我的日记/2023-02.md
#
# ├── 📄 2025-03.md
#        📍 ID: 20250615121617-k4gfv9j
#        📂 路径: /我的日记/2025-03.md
#
# ├── 📄 2022-08
#        📍 ID: 20250615121617-kuvy937
#        📂 路径: /我的日记/2022-08
#
# ├── 📄 我的生活经历.md
#        📍 ID: 20250615121617-kyubq92
#        📂 路径: /我的日记/我的生活经历.md
#
# ├── 📄 2022-11
#        📍 ID: 20250615121617-l39sc6f
#        📂 路径: /我的日记/2022-11
#
# ├── 📄 2022-05
#        📍 ID: 20250615121617-m1jvdlo
#        📂 路径: /我的日记/2022-05
#
# ├── 📄 2024-05.md
#        📍 ID: 20250615121617-mkkwj10
#        📂 路径: /我的日记/2024-05.md
#
# ├── 📄 2024-03.md
#        📍 ID: 20250615121617-mn019y4
#        📂 路径: /我的日记/2024-03.md
#
# ├── 📄 2025-12.md
#        📍 ID: 20250615121617-mxscsx2
#        📂 路径: /我的日记/2025-12.md
#
# ├── 📄 2024-09.md
#        📍 ID: 20250615121617-pi7dg5n
#        📂 路径: /我的日记/2024-09.md
#
# ├── 📄 2023-08.md
#        📍 ID: 20250615121617-q17i5jj
#        📂 路径: /我的日记/2023-08.md
#
# ├── 📄 2023-03.md
#        📍 ID: 20250615121617-rgayffv
#        📂 路径: /我的日记/2023-03.md
#
# ├── 📄 2025-06.md
#        📍 ID: 20250615121617-rj5bypg
#        📂 路径: /我的日记/2025-06.md
#
# ├── 📄 2025-09.md
#        📍 ID: 20250615121617-rnncpnh
#        📂 路径: /我的日记/2025-09.md
#
# ├── 📄 2022-07
#        📍 ID: 20250615121617-slncaki
#        📂 路径: /我的日记/2022-07
#
# ├── 📄 2023-09.md
#        📍 ID: 20250615121617-th6i5ff
#        📂 路径: /我的日记/2023-09.md
#
# ├── 📄 2025-01.md
#        📍 ID: 20250615121617-trcqiz1
#        📂 路径: /我的日记/2025-01.md
#
# ├── 📄 2025-10.md
#        📍 ID: 20250615121617-uq3kgnc
#        📂 路径: /我的日记/2025-10.md
#
# ├── 📄 2023-06.md
#        📍 ID: 20250615121617-v3h07ev
#        📂 路径: /我的日记/2023-06.md
#
# ├── 📄 2024-06.md
#        📍 ID: 20250615121617-vwnnjjf
#        📂 路径: /我的日记/2024-06.md
#
# ├── 📄 2023-12.md
#        📍 ID: 20250615121617-w835sat
#        📂 路径: /我的日记/2023-12.md
#
# ├── 📄 2023-07.md
#        📍 ID: 20250615121617-w9du1jl
#        📂 路径: /我的日记/2023-07.md
#
# ├── 📄 2024-01.md
#        📍 ID: 20250615121617-xvi716n
#        📂 路径: /我的日记/2024-01.md
#
# ├── 📄 2024-12.md
#        📍 ID: 20250615121617-xzyo4s7
#        📂 路径: /我的日记/2024-12.md
#
# ├── 📄 2024-08.md
#        📍 ID: 20250615121617-ymbxoi1
#        📂 路径: /我的日记/2024-08.md
#
#
# 📁 我的邮件
#    📍 ID: 20250615183337-gsgibjl
#    📂 路径: /我的邮件
# ├── 📄 测完即梦新功能，直接睡不着了。。
#        📍 ID: 20250615183337-4yc4w6c
#        📂 路径: /我的邮件/测完即梦新功能，直接睡不着了。。
#
# ├── 📄 1个小团队，2个月，一部AI短剧火爆全网，它凭什么“干翻”传统剧组？
#        📍 ID: 20250615183337-5bzvlc1
#        📂 路径: /我的邮件/1个小团队，2个月，一部AI短剧火爆全网，它凭什么“干翻”传统剧组？
#
# ├── 📄 从0到1：AI时代，人人都能做“开发者”，堵住“漏风”的墙
#        📍 ID: 20250615183337-65fclhh
#        📂 路径: /我的邮件/从0到1：AI时代，人人都能做“开发者”，堵住“漏风”的墙
#
# ├── 📄 2个人不到1年做到月入百万，这个AI网文创业故事太疯狂了！
#        📍 ID: 20250615183337-f2ikyze
#        📂 路径: /我的邮件/2个人不到1年做到月入百万，这个AI网文创业故事太疯狂了！
#
# ├── 📄 Genspark 将上线 AI 浏览器丨创始人最新分享：我看到了 AGI
#        📍 ID: 20250615183337-fpze4jr
#        📂 路径: /我的邮件/Genspark 将上线 AI 浏览器丨创始人最新分享：我看到了 AGI
#
# ├── 📄 即梦3.0又炸了！一句话让LABUBU变藏海传，30秒做出爆款海报！
#        📍 ID: 20250615183337-g9v9iuq
#        📂 路径: /我的邮件/即梦3.0又炸了！一句话让LABUBU变藏海传，30秒做出爆款海报！
#
# ├── 📄 AI Image Editor - 免费、高性能的 AI 图像编辑工具，无需注册，效果媲美专业图像处理软件｜那些免费的砖
#        📍 ID: 20250615183337-kqo69hd
#        📂 路径: /我的邮件/AI Image Editor - 免费、高性能的 AI 图像编辑工具，无需注册，效果媲美专业图像处理软件｜那些免费的砖
#
# ├── 📄 40秒生成1080P视频，3.6元一条，字节这次又要掀桌子了？藏师傅Seedance  1.0 Pro实测
#        📍 ID: 20250615183337-nuxlxo2
#        📂 路径: /我的邮件/40秒生成1080P视频，3.6元一条，字节这次又要掀桌子了？藏师傅Seedance  1.0 Pro实测
#
# ├── 📄 即梦视频模型3.0Pro 登顶视频模型竞技场
#        📍 ID: 20250615183337-pgcwj3v
#        📂 路径: /我的邮件/即梦视频模型3.0Pro 登顶视频模型竞技场
#
# ├── 📄 扣子空间，再造垂直 Agent 宇宙
#        📍 ID: 20250615183337-pw930gw
#        📂 路径: /我的邮件/扣子空间，再造垂直 Agent 宇宙
#
# ├── 📄 Cursor迎来史诗级更新，关于Cursor 1.0.0版本，这里有你需要知道的一切！
#        📍 ID: 20250615183337-rg2n3wo
#        📂 路径: /我的邮件/Cursor迎来史诗级更新，关于Cursor 1.0.0版本，这里有你需要知道的一切！
#
# ├── 📄 我的AI工具箱：13款 AI 神器，多数每天在用。附实用教程
#        📍 ID: 20250615183337-s41b9he
#        📂 路径: /我的邮件/我的AI工具箱：13款 AI 神器，多数每天在用。附实用教程
#
# ├── 📄 AI时代的创作者：五种人生，一个信念
#        📍 ID: 20250615183337-wx2z3cy
#        📂 路径: /我的邮件/AI时代的创作者：五种人生，一个信念
#
# ├── 📄 Prompt三则（2）
#        📍 ID: 20250615183337-z1sxck4
#        📂 路径: /我的邮件/Prompt三则（2）
#
# ├── 📄 肝了30小时，Flux Kontext是我用过最稳、最能干活的AI图像模型！
#        📍 ID: 20250615183338-7d366w7
#        📂 路径: /我的邮件/肝了30小时，Flux Kontext是我用过最稳、最能干活的AI图像模型！
#
# ├── 📄 解决主体一致性了！FLUX.1 Kontext 深度测评+案例实操教程
#        📍 ID: 20250615183338-mixzm8b
#        📂 路径: /我的邮件/解决主体一致性了！FLUX.1 Kontext 深度测评+案例实操教程
#
# ├── 📄 跟两位顶尖AI产品大佬学设计经验（附原版视频） - 飞书云文档
#        📍 ID: 20250615183338-nwqxsz3
#        📂 路径: /我的邮件/跟两位顶尖AI产品大佬学设计经验（附原版视频） - 飞书云文档
#
# ├── 📄 苹果重磅论文翻车！被指测试方法有大问题……网友：Cook 该裁员了！
#        📍 ID: 20250615183338-p0zjwns
#        📂 路径: /我的邮件/苹果重磅论文翻车！被指测试方法有大问题……网友：Cook 该裁员了！
#
#
# 📁 我的任务
#    📍 ID: 20250615184730-tj5o5xc
#    📂 路径: /我的任务
# ├── 📄 锻炼肌肉群
#        📍 ID: 20250615184730-2ttfx5z
#        📂 路径: /我的任务/锻炼肌肉群
#
# ├── 📄 2022年Flag
#        📍 ID: 20250615184730-53o2qim
#        📂 路径: /我的任务/2022年Flag
#
# ├── 📄 走廊凹位：宽78，深25，高225；
#        📍 ID: 20250615184730-edo6jia
#        📂 路径: /我的任务/走廊凹位：宽78，深25，高225；
#
# ├── 📄 【惠城区税务局】尊敬的纳税人：您好
#        📍 ID: 20250615184730-gw1eo6k
#        📂 路径: /我的任务/【惠城区税务局】尊敬的纳税人：您好
#
# ├── 📄 正念冥想.md
#        📍 ID: 20250615184730-kv7qa8i
#        📂 路径: /我的任务/正念冥想.md
#
# ├── 📄 坚持练1个月平板支撑，你就知道自己有多厉害
#        📍 ID: 20250615184730-mei1x0u
#        📂 路径: /我的任务/坚持练1个月平板支撑，你就知道自己有多厉害
#
# ├── 📄 生活 Todo
#        📍 ID: 20250615184730-pb1d7ip
#        📂 路径: /我的任务/生活 Todo
#
# ├── 📄 为什么Chrome扩展是独立开发者的绝佳入场机会?
#        📍 ID: 20250615184730-pervd3j
#        📂 路径: /我的任务/为什么Chrome扩展是独立开发者的绝佳入场机会?
#
# ├── 📄 使用 Cursor 制作uTools插件教程​.md
#        📍 ID: 20250615184730-vszn7nd
#        📂 路径: /我的任务/使用 Cursor 制作uTools插件教程​.md
#
# ├── 📄 “我遇到的所有最酷的人，都是通过我写的东西找到我的”.md
#        📍 ID: 20250615184730-y2erdhf
#        📂 路径: /我的任务/“我遇到的所有最酷的人，都是通过我写的东西找到我的”.md
#
#
# 📁 个人信息
#    📍 ID: 20250615184928-7iccz2d
#    📂 路径: /个人信息
# ├── 📁 Personal Accounts - 账户
#        📍 ID: 20250615133537-ud1iefy
#        📂 路径: /个人信息/Personal Accounts - 账户
# │   ├── 📄 七牛云帐号信息
# │          📍 ID: 20250614224016-2dwxu7q
# │          📂 路径: /个人信息/Personal Accounts - 账户/七牛云帐号信息
#
#
# ├── 📄 【电子签约】华为劳动合同电子版（ 聘用期为_2021-09-01_日至_2025-08-31_日）
#        📍 ID: 20250615184928-1zqmsbc
#        📂 路径: /个人信息/【电子签约】华为劳动合同电子版（ 聘用期为_2021-09-01_日至_2025-08-31_日）
#
# ├── 📄 全家福照片
#        📍 ID: 20250615184928-2mhlyo5
#        📂 路径: /个人信息/全家福照片
#
# ├── 📄 体检报告2019
#        📍 ID: 20250615184928-44kkdyp
#        📂 路径: /个人信息/体检报告2019
#
# ├── 📄 HCIP考试结果报告复印件
#        📍 ID: 20250615184928-4xpvzgt
#        📂 路径: /个人信息/HCIP考试结果报告复印件
#
# ├── 📄 absolutely now!
#        📍 ID: 20250615184928-5dudyd6
#        📂 路径: /个人信息/absolutely now!
#
# ├── 📄 2016年湖北省成人学士学位外语考试准考证打印
#        📍 ID: 20250615184928-5zothuw
#        📂 路径: /个人信息/2016年湖北省成人学士学位外语考试准考证打印
#
# ├── 📄 体检报告2021
#        📍 ID: 20250615184928-60e5pef
#        📂 路径: /个人信息/体检报告2021
#
# ├── 📄 personal info old
#        📍 ID: 20250615184928-7xbbguq
#        📂 路径: /个人信息/personal info old
#
# ├── 📄 中学同学
#        📍 ID: 20250615184928-88z8yzc
#        📂 路径: /个人信息/中学同学
#
# ├── 📄 23魔方个人基因组检测 祖源分析 遗传健康风险 营养需求 药物反应 运动塑形 家族对比送礼【图片 价格 品牌 报价】-京东
#        📍 ID: 20250615184928-8voto28
#        📂 路径: /个人信息/23魔方个人基因组检测 祖源分析 遗传健康风险 营养需求 药物反应 运动塑形 家族对比送礼【图片 价格 品牌 报价】-京东
#
# ├── 📄 2020体检报告（港大医院）
#        📍 ID: 20250615184928-axqaawp
#        📂 路径: /个人信息/2020体检报告（港大医院）
#
# ├── 📄 2020年国庆假期（10.3~10.8）
#        📍 ID: 20250615184928-bsmaobt
#        📂 路径: /个人信息/2020年国庆假期（10.3~10.8）
#
# ├── 📄 mbti类型倾向为：infj
#        📍 ID: 20250615184928-du6xg3t
#        📂 路径: /个人信息/mbti类型倾向为：infj
#
# ├── 📄 2022年体检报告
#        📍 ID: 20250615184928-gss4g5j
#        📂 路径: /个人信息/2022年体检报告
#
# ├── 📄 FOMEPay美国信用卡
#        📍 ID: 20250615184928-i6roxyv
#        📂 路径: /个人信息/FOMEPay美国信用卡
#
# ├── 📄 WF - Export - 210808-191512.opml
#        📍 ID: 20250615184928-kwyjwbo
#        📂 路径: /个人信息/WF - Export - 210808-191512.opml
#
# ├── 📄 2017体检报告
#        📍 ID: 20250615184928-kxc7726
#        📂 路径: /个人信息/2017体检报告
#
# ├── 📄 2024年体检报告（港大医院）
#        📍 ID: 20250615184928-ojoy8xp
#        📂 路径: /个人信息/2024年体检报告（港大医院）
#
# ├── 📄 workflowy_bak20221022.rar
#        📍 ID: 20250615184928-s8htpb6
#        📂 路径: /个人信息/workflowy_bak20221022.rar
#
# ├── 📄 个人所得税 房贷利息专项扣除信息
#        📍 ID: 20250615184928-u1suosr
#        📂 路径: /个人信息/个人所得税 房贷利息专项扣除信息
#
# ├── 📄 2011网购总结
#        📍 ID: 20250615184928-whs99x1
#        📂 路径: /个人信息/2011网购总结
#
# ├── 📄 workflowy_bak_20231105
#        📍 ID: 20250615184928-y8jzz5k
#        📂 路径: /个人信息/workflowy_bak_20231105
#
# ├── 📄 Entry 门 door
#        📍 ID: 20250615184928-yn9f7sc
#        📂 路径: /个人信息/Entry 门 door
#
# ├── 📄 我的证件
#        📍 ID: 20250615184929-1mpw2mp
#        📂 路径: /个人信息/我的证件
#
# ├── 📄 出差Checklist
#        📍 ID: 20250615184929-27p4mw3
#        📂 路径: /个人信息/出差Checklist
#
# ├── 📄 支付宝年度电子账单 - 2011
#        📍 ID: 20250615184929-35d9oe8
#        📂 路径: /个人信息/支付宝年度电子账单 - 2011
#
# ├── 📄 我的照片
#        📍 ID: 20250615184929-3threrh
#        📂 路径: /个人信息/我的照片
#
# ├── 📁 新房装修
#        📍 ID: 20250615184929-4jg0d8l
#        📂 路径: /个人信息/新房装修
# │   ├── 📄 20180129-082919_焕色大师 -- 松湖朗苑添加项目详情.6YY89,135
# │          📍 ID: 20250615184929-1m0hv3h
# │          📂 路径: /个人信息/新房装修/20180129-082919_焕色大师 -- 松湖朗苑添加项目详情.6YY89,135
#
# │   ├── 📄 东莞松湖朗悦遗留事项，20180606
# │          📍 ID: 20250615184929-2ez0mis
# │          📂 路径: /个人信息/新房装修/东莞松湖朗悦遗留事项，20180606
#
# │   ├── 📄 墙漆颜色
# │          📍 ID: 20250615184929-3fk2bmg
# │          📂 路径: /个人信息/新房装修/墙漆颜色
#
# │   ├── 📄 威乐回水器热水循环系统家用燃气热水器：GT19Y大屏铜泵遥控水控200W
# │          📍 ID: 20250615184929-44wamsg
# │          📂 路径: /个人信息/新房装修/威乐回水器热水循环系统家用燃气热水器：GT19Y大屏铜泵遥控水控200W
#
# │   ├── 📄 投影幕布都有哪些，该如何选购？-智能电视&盒子讨论区-高清范
# │          📍 ID: 20250615184929-4b9ci1g
# │          📂 路径: /个人信息/新房装修/投影幕布都有哪些，该如何选购？-智能电视&盒子讨论区-高清范
#
# │   ├── 📄 【华为4G路由 2】价格_参数_图片_怎么样 - 华为商城 - Google Chrome
# │          📍 ID: 20250615184929-5sxcd8r
# │          📂 路径: /个人信息/新房装修/【华为4G路由 2】价格_参数_图片_怎么样 - 华为商城 - Google Chrome
#
# │   ├── 📄 20180605-084043_微信 -- 16备注,导向板尺寸25×240
# │          📍 ID: 20250615184929-68wlw4e
# │          📂 路径: /个人信息/新房装修/20180605-084043_微信 -- 16备注,导向板尺寸25×240
#
# │   ├── 📄 东莞松湖朗悦指纹锁K1使用指南
# │          📍 ID: 20250615184929-79f3yjp
# │          📂 路径: /个人信息/新房装修/东莞松湖朗悦指纹锁K1使用指南
#
# │   ├── 📄 141 全色系-五星文库 - Google Chrome
# │          📍 ID: 20250615184929-7c3z1qx
# │          📂 路径: /个人信息/新房装修/141 全色系-五星文库 - Google Chrome
#
# │   ├── 📄 房屋装修经验-深圳装友交流-装修论坛-搜房装修家居网 - Google Chrome
# │          📍 ID: 20250615184929-7ocecma
# │          📂 路径: /个人信息/新房装修/房屋装修经验-深圳装友交流-装修论坛-搜房装修家居网 - Google Chrome
#
# │   ├── 📄 厨房设计常被忽视的12个细节，比橱柜收纳重要100倍
# │          📍 ID: 20250615184929-93szyyb
# │          📂 路径: /个人信息/新房装修/厨房设计常被忽视的12个细节，比橱柜收纳重要100倍
#
# │   ├── 📄 【2010】海尔(haier) JSQ20-PR 10升 燃气热水器(天然气)
# │          📍 ID: 20250615184929-be9l7r1
# │          📂 路径: /个人信息/新房装修/【2010】海尔(haier) JSQ20-PR 10升 燃气热水器(天然气)
#
# │   ├── 📄 03GCC12 冷暖空调
# │          📍 ID: 20250615184929-bvn7c7a
# │          📂 路径: /个人信息/新房装修/【2010】海尔KFR-23GW/03GCC12 冷暖空调
#
# │   ├── 📄 20180129-122534_焕色大师 -- 所有色彩我的色彩色卡25YY81,177
# │          📍 ID: 20250615184929-dbe8kf0
# │          📂 路径: /个人信息/新房装修/20180129-122534_焕色大师 -- 所有色彩我的色彩色卡25YY81,177
#
# │   ├── 📄 十件装修以后很快后悔的事
# │          📍 ID: 20250615184929-ewaeow3
# │          📂 路径: /个人信息/新房装修/十件装修以后很快后悔的事
#
# │   ├── 📄 20171025-133018_酷家乐装修 -- 50%■我的预约设计豪华设计包已付款东莞
# │          📍 ID: 20250615184929-j6l7ke9
# │          📂 路径: /个人信息/新房装修/20171025-133018_酷家乐装修 -- 50%■我的预约设计豪华设计包已付款东莞
#
# │   ├── 📄 【明基W600+参数】BenQ W600+投影机参数_规格_性能_功能-ZOL中关村在线
# │          📍 ID: 20250615184929-jbzm5eo
# │          📂 路径: /个人信息/新房装修/【明基W600+参数】BenQ W600+投影机参数_规格_性能_功能-ZOL中关村在线
#
# │   ├── 📄 20180514-110528_手机淘宝 -- 98%匚订单详情卖家已发货还剩4天4时自
# │          📍 ID: 20250615184929-k7y0ad6
# │          📂 路径: /个人信息/新房装修/20180514-110528_手机淘宝 -- 98%匚订单详情卖家已发货还剩4天4时自
#
# │   ├── 📄 TCL立柜式空调
# │          📍 ID: 20250615184929-mr9mppp
# │          📂 路径: /个人信息/新房装修/TCL立柜式空调
#
# │   ├── 📄 东莞松湖朗苑装修公司 - 君悦装饰, 总价158,326元。
# │          📍 ID: 20250615184929-p2q5ws1
# │          📂 路径: /个人信息/新房装修/东莞松湖朗苑装修公司 - 君悦装饰, 总价158,326元。
#
# │   ├── 📄 20180424-143408_手机淘宝 -- ⊙84%□订单详情【东莞市】快件已到达东
# │          📍 ID: 20250615184929-r7m6cqf
# │          📂 路径: /个人信息/新房装修/20180424-143408_手机淘宝 -- ⊙84%□订单详情【东莞市】快件已到达东
#
# │   ├── 📄 入住半年余，说说装修经验与教训 （附美若天仙的户型图） - 家在深圳
# │          📍 ID: 20250615184929-uetntzp
# │          📂 路径: /个人信息/新房装修/入住半年余，说说装修经验与教训 （附美若天仙的户型图） - 家在深圳
#
# │   ├── 📄 【酷家乐】设计师回音设计工作室将为您服务
# │          📍 ID: 20250615184929-wedb34e
# │          📂 路径: /个人信息/新房装修/【酷家乐】设计师回音设计工作室将为您服务
#
# │   ├── 📄 松湖朗苑125㎡装修效果图
# │          📍 ID: 20250615184931-0o94iza
# │          📂 路径: /个人信息/新房装修/松湖朗苑125㎡装修效果图
#
# │   ├── 📄 松湖朗苑装修设计要求
# │          📍 ID: 20250615184931-4ysqrjz
# │          📂 路径: /个人信息/新房装修/松湖朗苑装修设计要求
#
# │   ├── 📄 澜园沙发尺寸
# │          📍 ID: 20250615184931-80g7135
# │          📂 路径: /个人信息/新房装修/澜园沙发尺寸
#
# │   ├── 📄 松湖朗悦 采购清单
# │          📍 ID: 20250615184931-9xtusbk
# │          📂 路径: /个人信息/新房装修/松湖朗悦 采购清单
#
# │   ├── 📄 智能马桶盖操作说明
# │          📍 ID: 20250615184931-atvjzo1
# │          📂 路径: /个人信息/新房装修/智能马桶盖操作说明
#
# │   ├── 📄 招商澜园2A12B装修信息
# │          📍 ID: 20250615184931-b50nv8k
# │          📂 路径: /个人信息/新房装修/招商澜园2A12B装修信息
#
# │   ├── 📄 涂料专题活动-京东 - Google Chrome
# │          📍 ID: 20250615184931-l15fkq0
# │          📂 路径: /个人信息/新房装修/涂料专题活动-京东 - Google Chrome
#
# │   ├── 📄 空调匹数_百度百科
# │          📍 ID: 20250615184931-o25io78
# │          📂 路径: /个人信息/新房装修/空调匹数_百度百科
#
# │   ├── 📄 招商澜园2A12B装修方案
# │          📍 ID: 20250615184931-ogg4lg2
# │          📂 路径: /个人信息/新房装修/招商澜园2A12B装修方案
#
# │   ├── 📄 招商澜园门锁尺寸
# │          📍 ID: 20250615184931-xk1sz33
# │          📂 路径: /个人信息/新房装修/招商澜园门锁尺寸
#
# │   ├── 📄 装修技巧，领悟了你就是装修专家！ - 家在深圳
# │          📍 ID: 20250615184931-yqsho0d
# │          📂 路径: /个人信息/新房装修/装修技巧，领悟了你就是装修专家！ - 家在深圳
#
#
# ├── 📄 叶殊凡：上海第二工业大学 财务管理专业
#        📍 ID: 20250615184929-6ppg3a3
#        📂 路径: /个人信息/叶殊凡：上海第二工业大学 财务管理专业
#
# ├── 📄 携号转网 2023年5月24日 周三
#        📍 ID: 20250615184929-9fqnq4b
#        📂 路径: /个人信息/携号转网 2023年5月24日 周三
#
# ├── 📄 我的基因检测201806
#        📍 ID: 20250615184929-fqndwjx
#        📂 路径: /个人信息/我的基因检测201806
#
# ├── 📄 华为配股2019年10月
#        📍 ID: 20250615184929-iid4128
#        📂 路径: /个人信息/华为配股2019年10月
#
# ├── 📄 医保信息
#        📍 ID: 20250615184929-mcqzrwe
#        📂 路径: /个人信息/我的社保/医保信息
#
# ├── 📄 建业大厦
#        📍 ID: 20250615184929-pfhej4q
#        📂 路径: /个人信息/建业大厦
#
# ├── 📄 华为20年奖牌
#        📍 ID: 20250615184929-pnaau6k
#        📂 路径: /个人信息/华为20年奖牌
#
# ├── 📄 手机通讯录
#        📍 ID: 20250615184929-pzjk8li
#        📂 路径: /个人信息/手机通讯录
#
# ├── 📄 换工号
#        📍 ID: 20250615184929-sjzrdxy
#        📂 路径: /个人信息/换工号
#
# ├── 📄 工资单-202409
#        📍 ID: 20250615184929-vbag0ef
#        📂 路径: /个人信息/工资单-202409
#
# ├── 📄 我的保险2017
#        📍 ID: 20250615184929-xuwi64s
#        📂 路径: /个人信息/我的保险2017
#
# ├── 📄 华为2021年分红出炉：预测每股可分1.58元 - 用户配置 1 - Microsoft​ Edge
#        📍 ID: 20250615184929-xzffr1u
#        📂 路径: /个人信息/华为2021年分红出炉：预测每股可分1.58元 - 用户配置 1 - Microsoft​ Edge
#
# ├── 📄 微信二维码名片 - famo
#        📍 ID: 20250615184929-yr0fbqf
#        📂 路径: /个人信息/微信二维码名片 - famo
#
# ├── 📄 增值税发票信息
#        📍 ID: 20250615184929-zlhduaf
#        📂 路径: /个人信息/增值税发票信息
#
# ├── 📄 我的标志主题：思维、学习、体谅、搜集、和谐
#        📍 ID: 20250615184929-zn9ipge
#        📂 路径: /个人信息/我的标志主题：思维、学习、体谅、搜集、和谐
#
# ├── 📄 邮箱客户端帐号、密码 mail_accounts
#        📍 ID: 20250615184931-0pcrx9f
#        📂 路径: /个人信息/邮箱客户端帐号、密码 mail_accounts
#
# ├── 📁 新生命
#        📍 ID: 20250615184931-18xkdc2
#        📂 路径: /个人信息/新生命
# │   ├── 📄 小一班幼儿成长档案（邹盈汐）
# │          📍 ID: 20250615184931-0dey676
# │          📂 路径: /个人信息/新生命/小一班幼儿成长档案（邹盈汐）
#
# │   ├── 📄 20180718_103814 -- 常住人口登记卡姓户主或与曾用名名邹沁心户
# │          📍 ID: 20250615184931-187kjw9
# │          📂 路径: /个人信息/新生命/20180718_103814 -- 常住人口登记卡姓户主或与曾用名名邹沁心户
#
# │   ├── 📄 20180628满月体检
# │          📍 ID: 20250615184931-av3hnvi
# │          📂 路径: /个人信息/新生命/20180628满月体检
#
# │   ├── 📄 安安作息 - Microsoft Word
# │          📍 ID: 20250615184931-fde70ne
# │          📂 路径: /个人信息/新生命/安安作息 - Microsoft Word
#
# │   ├── 📄 出生证明 -- 出生医学证明MEDICAL CERTIF
# │          📍 ID: 20250615184931-lnn0m47
# │          📂 路径: /个人信息/新生命/出生证明 -- 出生医学证明MEDICAL CERTIF
#
# │   ├── 📄 入学接种查验报告
# │          📍 ID: 20250615184931-lt5bypp
# │          📂 路径: /个人信息/新生命/入学接种查验报告
#
# │   ├── 📄 身份证（邹盈汐），440305201805270181
# │          📍 ID: 20250615184931-m6dz8ih
# │          📂 路径: /个人信息/新生命/身份证（邹盈汐），440305201805270181
#
# │   ├── 📄 诗词取名
# │          📍 ID: 20250615184931-nnodiq7
# │          📂 路径: /个人信息/新生命/诗词取名
#
# │   ├── 📄 安安的一寸照片
# │          📍 ID: 20250615184931-ut3eqhb
# │          📂 路径: /个人信息/新生命/安安的一寸照片
#
# │   ├── 📄 深圳市少儿医疗保险首次参保登记表
# │          📍 ID: 20250615184931-xh348y1
# │          📂 路径: /个人信息/新生命/深圳市少儿医疗保险首次参保登记表
#
# │   ├── 📄 十月怀胎，一朝分娩-黄丽芳
# │          📍 ID: 20250615184931-yz48k1k
# │          📂 路径: /个人信息/新生命/十月怀胎，一朝分娩-黄丽芳
#
#
# ├── 📁 资产
#        📍 ID: 20250615184931-2jas577
#        📂 路径: /个人信息/资产
# │   ├── 📄 历史理财记录
# │          📍 ID: 20250615184931-0y3m3kg
# │          📂 路径: /个人信息/资产/历史理财记录
#
# │   ├── 📄 惠州看房20200626
# │          📍 ID: 20250615184931-1kpgucx
# │          📂 路径: /个人信息/资产/惠州看房20200626
#
# │   ├── 📄 招商澜园相关证件（房产证等扫描件）
# │          📍 ID: 20250615184931-24hkemr
# │          📂 路径: /个人信息/资产/招商澜园相关证件（房产证等扫描件）
#
# │   ├── 📄 中意全球保障团体医疗保险（钻石版）20241015~20251014
# │          📍 ID: 20250615184931-53o2eax
# │          📂 路径: /个人信息/资产/中意全球保障团体医疗保险（钻石版）20241015~20251014
#
# │   ├── 📄 火球网 - 专业优质的网贷中介平台 - Google Chrome
# │          📍 ID: 20250615184931-6a4w6ap
# │          📂 路径: /个人信息/资产/火球网 - 专业优质的网贷中介平台 - Google Chrome
#
# │   ├── 📄 户口本
# │          📍 ID: 20250615184931-6pte6ts
# │          📂 路径: /个人信息/资产/户口本
#
# │   ├── 📄 上海警方：米袋计划等5平台涉非法吸收公众存款被立案侦查_凤凰资讯 - Google Chrome
# │          📍 ID: 20250615184931-7sv47wd
# │          📂 路径: /个人信息/资产/上海警方：米袋计划等5平台涉非法吸收公众存款被立案侦查_凤凰资讯 - Google Chrome
#
# │   ├── 📄 回复：Formax港美股出金 - QQ邮箱
# │          📍 ID: 20250615184931-8bnw8ei
# │          📂 路径: /个人信息/资产/回复：Formax港美股出金 - QQ邮箱
#
# │   ├── 📄 科苑花园36区旧改协议20210703
# │          📍 ID: 20250615184931-8h0bl7y
# │          📂 路径: /个人信息/资产/科苑花园36区旧改协议20210703
#
# │   ├── 📄 2022年个人所得税报税记录：补缴31733元
# │          📍 ID: 20250615184931-afs1apo
# │          📂 路径: /个人信息/资产/2022年个人所得税报税记录：补缴31733元
#
# │   ├── 📄 基金帐号：5124257550099903
# │          📍 ID: 20250615184931-bdulfo5
# │          📂 路径: /个人信息/资产/基金帐号：5124257550099903
#
# │   ├── 📄  银行账号信息
# │          📍 ID: 20250615184931-eezv47u
# │          📂 路径: /个人信息/资产/银行卡 / 银行账号信息
#
# │   ├── 📄 2019收入纳税明细
# │          📍 ID: 20250615184931-f3cuxku
# │          📂 路径: /个人信息/资产/2019收入纳税明细
#
# │   ├── 📄 惠州 - 中洲华昕府
# │          📍 ID: 20250615184931-g4kr1af
# │          📂 路径: /个人信息/资产/惠州 - 中洲华昕府
#
# │   ├── 📄 我的贷款
# │          📍 ID: 20250615184931-jbgynkv
# │          📂 路径: /个人信息/资产/我的贷款
#
# │   ├── 📄 资金202202
# │          📍 ID: 20250615184931-jkhfcwa
# │          📂 路径: /个人信息/资产/资产/资金202202
#
# │   ├── 📄 问界M5 增程混动车.md
# │          📍 ID: 20250615184931-jxpkqjy
# │          📂 路径: /个人信息/资产/问界M5 增程混动车.md
#
# │   ├── 📄 境外汇款_储蓄业务_招商银行 - Google Chrome
# │          📍 ID: 20250615184931-ki13szi
# │          📂 路径: /个人信息/资产/境外汇款_储蓄业务_招商银行 - Google Chrome
#
# │   ├── 📄 华富大厦房产证
# │          📍 ID: 20250615184931-l95f31v
# │          📂 路径: /个人信息/资产/华富大厦房产证
#
# │   ├── 📄  松湖朗悦  7-2303
# │          📍 ID: 20250615184931-nsnn96r
# │          📂 路径: /个人信息/资产/松湖朗苑 / 松湖朗悦  7-2303
#
# │   ├── 📄 我的股票账号
# │          📍 ID: 20250615184931-p1vb29a
# │          📂 路径: /个人信息/资产/我的股票账号
#
# │   ├── 📄 第4栋备案价格－惠民之家房产网
# │          📍 ID: 20250615184931-qwenjtr
# │          📂 路径: /个人信息/资产/第4栋备案价格－惠民之家房产网
#
# │   ├── 📄 惠州房产：旺岗路22号中洲华昕家园4栋2904房.md
# │          📍 ID: 20250615184931-r852bzs
# │          📂 路径: /个人信息/资产/惠州房产：旺岗路22号中洲华昕家园4栋2904房.md
#
# │   ├── 📄 Formax金融圈-我的账户 - 傲游云浏览器 4.4.3.4000
# │          📍 ID: 20250615184931-s3z6o9d
# │          📂 路径: /个人信息/资产/Formax金融圈-我的账户 - 傲游云浏览器 4.4.3.4000
#
# │   ├── 📄 安邦盛泰两全保险（万能型），2019年11月29日
# │          📍 ID: 20250615184931-vg0hp5i
# │          📂 路径: /个人信息/资产/安邦盛泰两全保险（万能型），2019年11月29日
#
# │   ├── 📄 租房合同(科苑花园36区)
# │          📍 ID: 20250615184931-vzkriau
# │          📂 路径: /个人信息/资产/租房合同(科苑花园36区)
#
# │   ├── 📄 我的交易单 - 京东金融 - 傲游云浏览器 4.4.5.1000
# │          📍 ID: 20250615184931-w04ise4
# │          📂 路径: /个人信息/资产/我的交易单 - 京东金融 - 傲游云浏览器 4.4.5.1000
#
# │   ├── 📄 科技园36区7栋701房产证（14栋701）-黄丽芳
# │          📍 ID: 20250615184931-y3sdy95
# │          📂 路径: /个人信息/资产/科技园36区7栋701房产证（14栋701）-黄丽芳
#
# │   ├── 📄 充电桩安装 3888+4900 = 8788
# │          📍 ID: 20250615184931-ziodwno
# │          📂 路径: /个人信息/资产/充电桩安装 3888+4900 = 8788
#
# │   ├── 📄 Formax Daily Confirmation - QQ邮箱
# │          📍 ID: 20250615184931-zlgp2on
# │          📂 路径: /个人信息/资产/Formax Daily Confirmation - QQ邮箱
#
#
# ├── 📄 龙游老家宽带设置
#        📍 ID: 20250615184931-4v07fkf
#        📂 路径: /个人信息/龙游老家宽带设置
#
# ├── 📄 黄丽芳的个人信息
#        📍 ID: 20250615184931-51iquxx
#        📂 路径: /个人信息/黄丽芳的个人信息
#
# ├── 📄 纪念日
#        📍 ID: 20250615184931-5iri682
#        📂 路径: /个人信息/家人/纪念日
#
# ├── 📄 衣服尺寸
#        📍 ID: 20250615184931-7zoo804
#        📂 路径: /个人信息/衣服尺寸
#
# ├── 📄 横突骨折记录.md
#        📍 ID: 20250615184931-a6dwxu8
#        📂 路径: /个人信息/横突骨折记录.md
#
# ├── 📄 转岗
#        📍 ID: 20250615184931-aqvkp5o
#        📂 路径: /个人信息/转岗
#
# ├── 📄 社保余额查询201905
#        📍 ID: 20250615184931-citzag6
#        📂 路径: /个人信息/社保余额查询201905
#
# ├── 📄 核酸码
#        📍 ID: 20250615184931-d8i0ffh
#        📂 路径: /个人信息/核酸码
#
# ├── 📄 高中同学
#        📍 ID: 20250615184931-dmm5wmm
#        📂 路径: /个人信息/高中同学
#
# ├── 📄 身份证
#        📍 ID: 20250615184931-efn0z8s
#        📂 路径: /个人信息/身份证
#
# ├── 📄 网络带宽测试
#        📍 ID: 20250615184931-ims7obe
#        📂 路径: /个人信息/中移动宽带配置 / 网速测试/网络带宽测试
#
# ├── 📄 邹沁心体检报告2023_香港大学深圳医院.pdf
#        📍 ID: 20250615184931-lb6u4d2
#        📂 路径: /个人信息/邹沁心体检报告2023_香港大学深圳医院.pdf
#
# ├── 📄 眼睛视力检测-验光数据
#        📍 ID: 20250615184931-miirtkb
#        📂 路径: /个人信息/眼睛视力检测-验光数据
#
# ├── 📄 脚长24.5cm
#        📍 ID: 20250615184931-nljrqfv
#        📂 路径: /个人信息/脚长24.5cm
#
# ├── 📄 水母头像
#        📍 ID: 20250615184931-u8hggvs
#        📂 路径: /个人信息/水母头像
#
# ├── 📄 洗车套餐
#        📍 ID: 20250615184931-won9q4k
#        📂 路径: /个人信息/洗车套餐
#
# ├── 📄 横突骨折是怎么回事
#        📍 ID: 20250615184931-zhd09w8
#        📂 路径: /个人信息/横突骨折是怎么回事
#
#
# 📁 我的笔记
#    📍 ID: 20250615202026-d786059
#    📂 路径: /我的笔记
# ├── 📁 吉光片羽
#        📍 ID: 20250615202026-5jz0ymi
#        📂 路径: /我的笔记/吉光片羽
# │   ├── 📄 好词
# │          📍 ID: 20250615202026-04jgjmu
# │          📂 路径: /我的笔记/吉光片羽/好词
#
# │   ├── 📄 其他
# │          📍 ID: 20250615202026-45ctfxr
# │          📂 路径: /我的笔记/吉光片羽/其他
#
# │   ├── 📄 关于现代社会
# │          📍 ID: 20250615202026-b2201dl
# │          📂 路径: /我的笔记/吉光片羽/关于现代社会
#
# │   ├── 📄 关于写作
# │          📍 ID: 20250615202026-cttq3k6
# │          📂 路径: /我的笔记/吉光片羽/关于写作
#
# │   ├── 📄 关于阅读
# │          📍 ID: 20250615202026-h56pfq5
# │          📂 路径: /我的笔记/吉光片羽/关于阅读
#
# │   ├── 📁 思维模型
# │          📍 ID: 20250615202026-i171crb
# │          📂 路径: /我的笔记/吉光片羽/思维模型
# │   │   ├── 📄 爱的哲学 | 献给所有恋人
# │   │          📍 ID: 20250615202026-4bium3i
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/爱的哲学 | 献给所有恋人
#
# │   │   ├── 📄 思维导图 | 查理芒格：让我受用一生的思维方式
# │   │          📍 ID: 20250615202026-5yug55o
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/思维导图 | 查理芒格：让我受用一生的思维方式
#
# │   │   ├── 📄 你必须读这本书的三个理由：《关于说话的一切》.md
# │   │          📍 ID: 20250615202026-6rgvpxm
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/你必须读这本书的三个理由：《关于说话的一切》.md
#
# │   │   ├── 📄 你缺乏的不是知识，而是思考！-今日头条
# │   │          📍 ID: 20250615202026-7tm1xr9
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/你缺乏的不是知识，而是思考！-今日头条
#
# │   │   ├── 📄 你不是不会思考，你只是缺少了一套思维模型
# │   │          📍 ID: 20250615202026-92pssxb
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/你不是不会思考，你只是缺少了一套思维模型
#
# │   │   ├── 📄 思维导图 | 李善友的3大思维模型
# │   │          📍 ID: 20250615202026-9ddhj1t
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/思维导图 | 李善友的3大思维模型
#
# │   │   ├── 📄 5本书告诉你，普通人和聪明人的思维方式到底有什么不一样？
# │   │          📍 ID: 20250615202026-9uqazts
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/5本书告诉你，普通人和聪明人的思维方式到底有什么不一样？
#
# │   │   ├── 📄 汤质：全错的王东岳，大错的万维钢
# │   │          📍 ID: 20250615202026-dgiqbgs
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/汤质：全错的王东岳，大错的万维钢
#
# │   │   ├── 📄 思维导图 | 查理•芒格生平最爱的2个思维模型
# │   │          📍 ID: 20250615202026-e5hfpr2
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/思维导图 | 查理•芒格生平最爱的2个思维模型
#
# │   │   ├── 📄 100个思维模型（图片）.md
# │   │          📍 ID: 20250615202026-fehv4ba
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/100个思维模型（图片）.md
#
# │   │   ├── 📄 查理·芒格的100 个思维模型研究（英文信息源）.md
# │   │          📍 ID: 20250615202026-fxz3xin
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/查理·芒格的100 个思维模型研究（英文信息源）.md
#
# │   │   ├── 📄 比尔·盖茨也在用的思维模型！避免情绪化决策，就看这一本！
# │   │          📍 ID: 20250615202026-iqht29b
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/比尔·盖茨也在用的思维模型！避免情绪化决策，就看这一本！
#
# │   │   ├── 📄 回归本质的思考：解读俞军产品方法论 15 条.md
# │   │          📍 ID: 20250615202026-jze7pu8
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/回归本质的思考：解读俞军产品方法论 15 条.md
#
# │   │   ├── 📄 沟通力思维模型
# │   │          📍 ID: 20250615202026-m8zfox3
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/沟通力思维模型
#
# │   │   ├── 📄 查理·芒格：如何提升自己的认知能力？
# │   │          📍 ID: 20250615202026-o4k5yrx
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/查理·芒格：如何提升自己的认知能力？
#
# │   │   ├── 📄 《穷查理宝典》查理列出25种经常误导人的心理倾向
# │   │          📍 ID: 20250615202026-pofaaad
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/《穷查理宝典》查理列出25种经常误导人的心理倾向
#
# │   │   ├── 📄 思维导图 | 查理•芒格生前最爱的2个思维模型
# │   │          📍 ID: 20250615202026-u5mli6d
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/思维导图 | 查理•芒格生前最爱的2个思维模型
#
# │   │   ├── 📄 我从牛人身上偷偷学到的12种思维方式
# │   │          📍 ID: 20250615202026-ubasmsy
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/我从牛人身上偷偷学到的12种思维方式
#
# │   │   ├── 📄 查理·芒格的100个思维模型研究（中文信息源）.md
# │   │          📍 ID: 20250615202026-vlnqmp9
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/查理·芒格的100个思维模型研究（中文信息源）.md
#
# │   │   ├── 📄 15种顶级分析思维模型。
# │   │          📍 ID: 20250615202026-w3wriam
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/15种顶级分析思维模型。
#
# │   │   ├── 📄 汤质丨我眼中最好的学习方法：认知负荷理论.md
# │   │          📍 ID: 20250615202026-wz25rgs
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/汤质丨我眼中最好的学习方法：认知负荷理论.md
#
# │   │   ├── 📄 性的哲思：宇宙最幽深的谜，是ta的面容与身体
# │   │          📍 ID: 20250615202026-xt0qmn4
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/性的哲思：宇宙最幽深的谜，是ta的面容与身体
#
# │   │   ├── 📄 模型思维介绍：因果推理模型
# │   │          📍 ID: 20250615202026-ztmcba7
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/模型思维介绍：因果推理模型
#
# │   │   ├── 📄 美团创始人王兴35条深度思考.md
# │   │          📍 ID: 20250615202027-3mfzphd
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/美团创始人王兴35条深度思考.md
#
# │   │   ├── 📄 给孩子的信：你将在两万多天后死去，在此之前…… | 死亡与游戏的哲思【文稿】
# │   │          📍 ID: 20250615202027-5ir7gz4
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/给孩子的信：你将在两万多天后死去，在此之前…… | 死亡与游戏的哲思【文稿】
#
# │   │   ├── 📄 致万维钢与卓老板们：放过哲学，救救科学
# │   │          📍 ID: 20250615202027-lm74fgy
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/致万维钢与卓老板们：放过哲学，救救科学
#
# │   │   ├── 📄 费曼学习法3.0：一个极其简单，但是让我受益无穷的学习方法
# │   │          📍 ID: 20250615202027-scvtg8p
# │   │          📂 路径: /我的笔记/吉光片羽/思维模型/费曼学习法3.0：一个极其简单，但是让我受益无穷的学习方法
#
#
# │   ├── 📄 Github项目
# │          📍 ID: 20250615202026-na3o89g
# │          📂 路径: /我的笔记/吉光片羽/Github项目
#
# │   ├── 📄  影单
# │          📍 ID: 20250615202026-pzixesa
# │          📂 路径: /我的笔记/吉光片羽/书单 / 影单
#
# │   ├── 📄 AI 技术 & 产品服务
# │          📍 ID: 20250615202026-y6yql39
# │          📂 路径: /我的笔记/吉光片羽/AI 技术 & 产品服务
#
# │   ├── 📄 Prompt
# │          📍 ID: 20250615202026-zf3yymy
# │          📂 路径: /我的笔记/吉光片羽/Prompt
#
# │   ├── 📁 案例素材
# │          📍 ID: 20250615202027-7fojwst
# │          📂 路径: /我的笔记/吉光片羽/案例素材
# │   │   ├── 📄 100岁齐邦媛去世：留下一本巨著，和一段旷世之恋
# │   │          📍 ID: 20250615202027-0xuu98r
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/100岁齐邦媛去世：留下一本巨著，和一段旷世之恋
#
# │   │   ├── 📄 155页PPT | 中国“新基建”发展研究报告
# │   │          📍 ID: 20250615202027-8e9bze7
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/155页PPT | 中国“新基建”发展研究报告
#
# │   │   ├── 📄 1、一切违背人性的技术和管理措施都一定会失效。 |方片
# │   │          📍 ID: 20250615202027-a4ya3db
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/1、一切违背人性的技术和管理措施都一定会失效。 |方片
#
# │   │   ├── 📄 2003：和赢家一起共事
# │   │          📍 ID: 20250615202027-a8c1jd9
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/2003：和赢家一起共事
#
# │   │   ├── 📄 2020断想
# │   │          📍 ID: 20250615202027-orj90be
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/2020断想
#
# │   │   ├── 📄 10张地图，带你回顾抗美援朝
# │   │          📍 ID: 20250615202027-p1bx30l
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/10张地图，带你回顾抗美援朝
#
# │   │   ├── 📄 1953年，梁漱溟因何事与毛主席争执被众人轰下台？最后结局如何？ 和另外 6 个页面 - 用户配置 1 - Microsoft​ Edge
# │   │          📍 ID: 20250615202027-x5xywmm
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/1953年，梁漱溟因何事与毛主席争执被众人轰下台？最后结局如何？ 和另外 6 个页面 - 用户配置 1 - Microsoft​ Edge
#
# │   │   ├── 📄 22亿富翁捡垃圾，擦马桶。挑战90天100块变100万，烂牌也成王炸！
# │   │          📍 ID: 20250615202027-zmy8ls6
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/22亿富翁捡垃圾，擦马桶。挑战90天100块变100万，烂牌也成王炸！
#
# │   │   ├── 📄 Kite 即将告别 Kite is saying farewell.md
# │   │          📍 ID: 20250615202028-1tc3yuy
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Kite 即将告别 Kite is saying farewell.md
#
# │   │   ├── 📄 5000万的教训！CODING创始人亲述：平台神话破灭
# │   │          📍 ID: 20250615202028-2jhf6hp
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/5000万的教训！CODING创始人亲述：平台神话破灭
#
# │   │   ├── 📄 Reddit问答版：你在什么时候意识到自己不再年轻了？.md
# │   │          📍 ID: 20250615202028-2o83d62
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Reddit问答版：你在什么时候意识到自己不再年轻了？.md
#
# │   │   ├── 📄 43岁日本学渣，一觉醒来拿了个诺贝尔奖，16年后，人生又逆袭了..
# │   │          📍 ID: 20250615202028-3ehzttl
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/43岁日本学渣，一觉醒来拿了个诺贝尔奖，16年后，人生又逆袭了..
#
# │   │   ├── 📄 Tumblr、Pinterest……一个个想创造新模式的应用都失败了，它们改变了什么又为何没落？ | 好奇心商业史
# │   │          📍 ID: 20250615202028-4ysrze2
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Tumblr、Pinterest……一个个想创造新模式的应用都失败了，它们改变了什么又为何没落？ | 好奇心商业史
#
# │   │   ├── 📄 ​我们该不该怀念2021？
# │   │          📍 ID: 20250615202028-73eil37
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/​我们该不该怀念2021？
#
# │   │   ├── 📄 UCloud案例故事
# │   │          📍 ID: 20250615202028-df3rht9
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/UCloud案例故事
#
# │   │   ├── 📄 45岁高龄加入华为，我活下来了！
# │   │          📍 ID: 20250615202028-f8rqx8i
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/45岁高龄加入华为，我活下来了！
#
# │   │   ├── 📄 5G带来的机会，集中在这里
# │   │          📍 ID: 20250615202028-g0gxs3g
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/5G带来的机会，集中在这里
#
# │   │   ├── 📄 Wework
# │   │          📍 ID: 20250615202028-klx6g1x
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Wework
#
# │   │   ├── 📄 Kicked Out of China, and Other Real-Life Costs of a Geopolitical Meltdown
# │   │          📍 ID: 20250615202028-oypguoe
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Kicked Out of China, and Other Real-Life Costs of a Geopolitical Meltdown
#
# │   │   ├── 📄 NFT火了，12岁男孩用 Python 写了一个「表情包」，赚了250万
# │   │          📍 ID: 20250615202028-rwr0hpi
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/NFT火了，12岁男孩用 Python 写了一个「表情包」，赚了250万
#
# │   │   ├── 📄 Temu、Shein遭到全球监管！这是雀巢100年前的经验！
# │   │          📍 ID: 20250615202028-st6809t
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Temu、Shein遭到全球监管！这是雀巢100年前的经验！
#
# │   │   ├── 📄 29年前《大话西游》留下的一个“大坑”，终于被周星驰自己填上了-今日头条
# │   │          📍 ID: 20250615202028-tv3q5bb
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/29年前《大话西游》留下的一个“大坑”，终于被周星驰自己填上了-今日头条
#
# │   │   ├── 📄 Coreen士仪：“美俄”沙特会谈.md
# │   │          📍 ID: 20250615202028-vvshmfx
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Coreen士仪：“美俄”沙特会谈.md
#
# │   │   ├── 📄 Opinion | Kicked Out of China, and Other Real-Life Costs of a Geopolitical Meltdown - The New York Times - Google Chrome
# │   │          📍 ID: 20250615202028-w8nmpek
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/Opinion | Kicked Out of China, and Other Real-Life Costs of a Geopolitical Meltdown - The New York Times - Google Chrome
#
# │   │   ├── 📄 28年追踪13个孩子，结果扎心了：如果不出意外，你的孩子终将平凡
# │   │          📍 ID: 20250615202028-wh3g9uy
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/28年追踪13个孩子，结果扎心了：如果不出意外，你的孩子终将平凡
#
# │   │   ├── 📄 OceanBase：蚂蚁爬上舞台
# │   │          📍 ID: 20250615202028-z96ge3a
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/OceanBase：蚂蚁爬上舞台
#
# │   │   ├── 📄 996到底是不是福报？
# │   │          📍 ID: 20250615202028-zzj6614
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/996到底是不是福报？
#
# │   │   ├── 📄 乐活--肯尼亚人的长跑优势
# │   │          📍 ID: 20250615202029-0nficj1
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/乐活--肯尼亚人的长跑优势
#
# │   │   ├── 📄 “大厦之巅的午餐”背后的谜团 - 纽约时报中文网
# │   │          📍 ID: 20250615202029-1pbmhuy
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/“大厦之巅的午餐”背后的谜团 - 纽约时报中文网
#
# │   │   ├── 📄 乐活--乡镇医院的精神科，快被中学生挤满了
# │   │          📍 ID: 20250615202029-1tifdvt
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/乐活--乡镇医院的精神科，快被中学生挤满了
#
# │   │   ├── 📄 【浮世汇860】俄罗斯的老百姓从没活得这么爽过 .md
# │   │          📍 ID: 20250615202029-257mc9x
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/【浮世汇860】俄罗斯的老百姓从没活得这么爽过 .md
#
# │   │   ├── 📄 他们又错了！特朗普大胜，但这个网站已经给出了准确预测！
# │   │          📍 ID: 20250615202029-2aagtdp
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/他们又错了！特朗普大胜，但这个网站已经给出了准确预测！
#
# │   │   ├── 📄 《原神》过的好是商业常识
# │   │          📍 ID: 20250615202029-3m1ija2
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/《原神》过的好是商业常识
#
# │   │   ├── 📄 亚马逊中国，不懂中国！
# │   │          📍 ID: 20250615202029-3m3bzyx
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/亚马逊中国，不懂中国！
#
# │   │   ├── 📄 以前的人想象的未来，和我们现在的真实有多大差距
# │   │          📍 ID: 20250615202029-3smvmdv
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/以前的人想象的未来，和我们现在的真实有多大差距
#
# │   │   ├── 📄 什么叫信达雅？来感受一下中文翻译的魅力吧！.md
# │   │          📍 ID: 20250615202029-4qufm50
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/什么叫信达雅？来感受一下中文翻译的魅力吧！.md
#
# │   │   ├── 📄 中国游戏是如何收割外国韭菜的
# │   │          📍 ID: 20250615202029-5atn9vm
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中国游戏是如何收割外国韭菜的
#
# │   │   ├── 📄 一个不太会写作的芯片工程师在今日头条三个月的写作之旅
# │   │          📍 ID: 20250615202029-5jgmbyr
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一个不太会写作的芯片工程师在今日头条三个月的写作之旅
#
# │   │   ├── 📄 一场秘密拍卖，扣动AI霸权之争的发令枪
# │   │          📍 ID: 20250615202029-5wavur5
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一场秘密拍卖，扣动AI霸权之争的发令枪
#
# │   │   ├── 📄 中国民营企业华为首次上榜世界500强到至今的销售收入 - Google Chrome
# │   │          📍 ID: 20250615202029-6kkwfp1
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中国民营企业华为首次上榜世界500强到至今的销售收入 - Google Chrome
#
# │   │   ├── 📄 乔布斯女儿回忆录：我的渣男爸爸乔布斯【1】--喷嚏网 dapenti.com
# │   │          📍 ID: 20250615202029-7qxjeb8
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/乔布斯女儿回忆录：我的渣男爸爸乔布斯【1】--喷嚏网 dapenti.com
#
# │   │   ├── 📄 「 生活太重要了，不能太过严肃 」：生命游戏之父、最神奇的数学家John Conway
# │   │          📍 ID: 20250615202029-9gsh9vp
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/「 生活太重要了，不能太过严肃 」：生命游戏之父、最神奇的数学家John Conway
#
# │   │   ├── 📄 京东物流上市：市值超2800亿港元 刘强东扛住了烧钱质疑 和另外 3 个页面 - 用户配置 1 - Microsoft​ Edge
# │   │          📍 ID: 20250615202029-9yn9k7k
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/京东物流上市：市值超2800亿港元 刘强东扛住了烧钱质疑 和另外 3 个页面 - 用户配置 1 - Microsoft​ Edge
#
# │   │   ├── 📄 中美大使在世贸组织总理事会上再次交锋--喷嚏网 dapenti.com
# │   │          📍 ID: 20250615202029-adrowz2
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中美大使在世贸组织总理事会上再次交锋--喷嚏网 dapenti.com
#
# │   │   ├── 📄 东北被非自然死亡了？在那个充满希望的春天，东北却坍塌了.md
# │   │          📍 ID: 20250615202029-blf6c8v
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/东北被非自然死亡了？在那个充满希望的春天，东北却坍塌了.md
#
# │   │   ├── 📄 一次模拟相亲，揭开婚恋市场残酷的一面：门当户对才是幸福关键？
# │   │          📍 ID: 20250615202029-cek6bl1
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一次模拟相亲，揭开婚恋市场残酷的一面：门当户对才是幸福关键？
#
# │   │   ├── 📄 产品思考：为什么微信语音消息播放不加进度条？
# │   │          📍 ID: 20250615202029-e657ng1
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/产品思考：为什么微信语音消息播放不加进度条？
#
# │   │   ├── 📄 中国军工“看一眼就怀孕”的历史，就要一去不复返了吗？ 和另外 1 个页面 - 用户配置 1 - Microsoft​ Edge
# │   │          📍 ID: 20250615202029-g2zjmtm
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中国军工“看一眼就怀孕”的历史，就要一去不复返了吗？ 和另外 1 个页面 - 用户配置 1 - Microsoft​ Edge
#
# │   │   ├── 📄 《关于需求是什么》－－销售小说《输赢》里面一个关于需求的小故事
# │   │          📍 ID: 20250615202029-hj73q92
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/《关于需求是什么》－－销售小说《输赢》里面一个关于需求的小故事
#
# │   │   ├── 📄 《水门桥》拍的很热血，但大部分剧情都是导演编的
# │   │          📍 ID: 20250615202029-m1kjt1x
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/《水门桥》拍的很热血，但大部分剧情都是导演编的
#
# │   │   ├── 📄 一个创新方法论，解芯片行业的千愁
# │   │          📍 ID: 20250615202029-mkr0t57
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一个创新方法论，解芯片行业的千愁
#
# │   │   ├── 📄 上线5天捞金13亿！没听过《幻兽帕鲁》就OUT了！却被批用了AI！
# │   │          📍 ID: 20250615202029-n581y4c
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/上线5天捞金13亿！没听过《幻兽帕鲁》就OUT了！却被批用了AI！
#
# │   │   ├── 📄 从产业集群现象谈初级赛道
# │   │          📍 ID: 20250615202029-n7b53vj
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/从产业集群现象谈初级赛道
#
# │   │   ├── 📄 乐活--青蒿素改变了非洲人的基因，然后出现了抗药性
# │   │          📍 ID: 20250615202029-noe8nun
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/乐活--青蒿素改变了非洲人的基因，然后出现了抗药性
#
# │   │   ├── 📄 《老滚5》的AI系统有多牛？
# │   │          📍 ID: 20250615202029-nwxi3lm
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/《老滚5》的AI系统有多牛？
#
# │   │   ├── 📄 中奖者们的“悲惨结局”定律？盘点海外8大最愚蠢的中奖者 - Google Chrome
# │   │          📍 ID: 20250615202029-ojpowte
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中奖者们的“悲惨结局”定律？盘点海外8大最愚蠢的中奖者 - Google Chrome
#
# │   │   ├── 📄 一年涨了7700亿！马斯克为啥是2023最能赚钱的人？
# │   │          📍 ID: 20250615202029-peb53lj
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一年涨了7700亿！马斯克为啥是2023最能赚钱的人？
#
# │   │   ├── 📄 【浮世汇24】苍蝇不叮无缝的蛋，学点男德保平安--喷嚏网 dapenti.com
# │   │          📍 ID: 20250615202029-qwikqud
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/【浮世汇24】苍蝇不叮无缝的蛋，学点男德保平安--喷嚏网 dapenti.com
#
# │   │   ├── 📄 一场疫情，改变了买卖方式，更改变了赚钱逻辑！
# │   │          📍 ID: 20250615202029-skmgy6z
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/一场疫情，改变了买卖方式，更改变了赚钱逻辑！
#
# │   │   ├── 📄 中国三十年来第一次在台问题上，赢取战略主动
# │   │          📍 ID: 20250615202029-szrx2vc
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中国三十年来第一次在台问题上，赢取战略主动
#
# │   │   ├── 📄 “毒妻”翟欣欣已认罪，或将获刑10年以上！
# │   │          📍 ID: 20250615202029-u8zrjub
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/“毒妻”翟欣欣已认罪，或将获刑10年以上！
#
# │   │   ├── 📄 亲鉴历史
# │   │          📍 ID: 20250615202029-xnq6a8u
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/亲鉴历史
#
# │   │   ├── 📄 什么情况下，可以用华为铁三角营销模式？
# │   │          📍 ID: 20250615202029-xr1t67i
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/什么情况下，可以用华为铁三角营销模式？
#
# │   │   ├── 📄 中国为什么要抗美援朝？——抗美援朝历史回顾（讲座）
# │   │          📍 ID: 20250615202029-xr98029
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/中国为什么要抗美援朝？——抗美援朝历史回顾（讲座）
#
# │   │   ├── 📄 为什么我们吃不到地沟油了？这就是创新的力量.md
# │   │          📍 ID: 20250615202029-ye47pjk
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/为什么我们吃不到地沟油了？这就是创新的力量.md
#
# │   │   ├── 📄 《财富》世界500强发布：华为排名44，互联网7强中国占4席
# │   │          📍 ID: 20250615202029-zfffsfp
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/《财富》世界500强发布：华为排名44，互联网7强中国占4席
#
# │   │   ├── 📄 从自我放逐到被驱逐：陈冠希的困兽之斗
# │   │          📍 ID: 20250615202029-zvdtx1d
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/从自我放逐到被驱逐：陈冠希的困兽之斗
#
# │   │   ├── 📄 定投改变命运（第三版连载）5
# │   │          📍 ID: 20250615202030-0mfvvnr
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/定投改变命运（第三版连载）5
#
# │   │   ├── 📄 华为决策原则之三——以客户为中心
# │   │          📍 ID: 20250615202030-2ju5i16
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/华为决策原则之三——以客户为中心
#
# │   │   ├── 📄 多邻国居然早上市了？！靠AI还创下股价新高！
# │   │          📍 ID: 20250615202030-2qpq9pj
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/多邻国居然早上市了？！靠AI还创下股价新高！
#
# │   │   ├── 📄 司美格鲁肽为啥是减肥神药？首席科学家透露幕后故事（万字长文）
# │   │          📍 ID: 20250615202030-3tuvah3
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/司美格鲁肽为啥是减肥神药？首席科学家透露幕后故事（万字长文）
#
# │   │   ├── 📄 华为对Google的禁用有何策略？
# │   │          📍 ID: 20250615202030-4o3d2ld
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/华为对Google的禁用有何策略？
#
# │   │   ├── 📄 作为一个中产阶级，我对国家有哪些不满意
# │   │          📍 ID: 20250615202030-4tyi7ce
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/作为一个中产阶级，我对国家有哪些不满意
#
# │   │   ├── 📄 商业快评 - “叫好不叫座”的飞书开始裁员.md
# │   │          📍 ID: 20250615202030-594t1r4
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/商业快评 - “叫好不叫座”的飞书开始裁员.md
#
# │   │   ├── 📄 卢虹贝：木心文学创作中的“文本再生”现象研究.md
# │   │          📍 ID: 20250615202030-5w8ly4w
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/卢虹贝：木心文学创作中的“文本再生”现象研究.md
#
# │   │   ├── 📄 加拿大宣布对香港禁运军事物资，一看金额，尴尬了
# │   │          📍 ID: 20250615202030-7t46c8u
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/加拿大宣布对香港禁运军事物资，一看金额，尴尬了
#
# │   │   ├── 📄 在崩塌的地缘政治中，我被迫离开中国 - 纽约时报中文网 - Google Chrome
# │   │          📍 ID: 20250615202030-7w7b00a
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/在崩塌的地缘政治中，我被迫离开中国 - 纽约时报中文网 - Google Chrome
#
# │   │   ├── 📄 困扰数学家50年的问题，竟被博士小姐姐用一周业余时间解决了
# │   │          📍 ID: 20250615202030-8e192e8
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/困扰数学家50年的问题，竟被博士小姐姐用一周业余时间解决了
#
# │   │   ├── 📄 俄罗斯外长：她看似说了一大堆话，但是其实什么也没说。
# │   │          📍 ID: 20250615202030-9lmti51
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/俄罗斯外长：她看似说了一大堆话，但是其实什么也没说。
#
# │   │   ├── 📄 华为做出了全世界体积最小的存储卡！为中国又解除了一个紧箍咒
# │   │          📍 ID: 20250615202030-9twlti0
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/华为做出了全世界体积最小的存储卡！为中国又解除了一个紧箍咒
#
# │   │   ├── 📄 刘润：教培行业，可能只是个开始 ……
# │   │          📍 ID: 20250615202030-a5utos2
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/刘润：教培行业，可能只是个开始 ……
#
# │   │   ├── 📄 平成废物：快乐教育的后果，日本替我们试过了
# │   │          📍 ID: 20250615202030-aa46fwp
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/平成废物：快乐教育的后果，日本替我们试过了
#
# │   │   ├── 📄 定投改变命运（第三版连载）1
# │   │          📍 ID: 20250615202030-amsuxil
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/定投改变命运（第三版连载）1
#
# │   │   ├── 📄 巴黎日记：第三阶段舆论战，西方已提前开打
# │   │          📍 ID: 20250615202030-b05ttz8
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/巴黎日记：第三阶段舆论战，西方已提前开打
#
# │   │   ├── 📄 全世界都错了！只有美联储看见了“真正”的魔鬼！
# │   │          📍 ID: 20250615202030-c5vn356
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/全世界都错了！只有美联储看见了“真正”的魔鬼！
#
# │   │   ├── 📄 后制造时代的经济增长
# │   │          📍 ID: 20250615202030-c67504p
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/后制造时代的经济增长
#
# │   │   ├── 📄 关于“四行仓库”，你想知道的基本都在这里
# │   │          📍 ID: 20250615202030-cqce53t
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/关于“四行仓库”，你想知道的基本都在这里
#
# │   │   ├── 📄 字节跳动的命运由己还是由天？| 施展札记24
# │   │          📍 ID: 20250615202030-djk4gz7
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/字节跳动的命运由己还是由天？| 施展札记24
#
# │   │   ├── 📄 因女朋友的一个建议，这位程序员创立仅 551 天公司就被 10 亿美元收购了
# │   │          📍 ID: 20250615202030-frrjr82
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/因女朋友的一个建议，这位程序员创立仅 551 天公司就被 10 亿美元收购了
#
# │   │   ├── 📄 孙正义20年投资神话背后的独特思维是什么？
# │   │          📍 ID: 20250615202030-gh5alcx
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/孙正义20年投资神话背后的独特思维是什么？
#
# │   │   ├── 📄 十分钟，三亿欧元，灰飞烟灭！都没错，那是谁的错？
# │   │          📍 ID: 20250615202030-gi5u0rf
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/十分钟，三亿欧元，灰飞烟灭！都没错，那是谁的错？
#
# │   │   ├── 📄 如何应对甩锅，索赔，泼脏水？
# │   │          📍 ID: 20250615202030-i09h33u
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/如何应对甩锅，索赔，泼脏水？
#
# │   │   ├── 📄 小企业怎样学华为？
# │   │          📍 ID: 20250615202030-icrfsq2
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/小企业怎样学华为？
#
# │   │   ├── 📄 巴西人民是怎么把国家带进坑里？从摇篮到坟墓，坟墓未到国家已衰
# │   │          📍 ID: 20250615202030-iutqucb
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/巴西人民是怎么把国家带进坑里？从摇篮到坟墓，坟墓未到国家已衰
#
# │   │   ├── 📄 刚刚美国送出“大礼包”，我们的国运又来了！.md
# │   │          📍 ID: 20250615202030-j3hrjac
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/刚刚美国送出“大礼包”，我们的国运又来了！.md
#
# │   │   ├── 📄 冯骥发长文表示两年前就写好了《黑神话》TGA获奖感言.md
# │   │          📍 ID: 20250615202030-jg1iamc
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/冯骥发长文表示两年前就写好了《黑神话》TGA获奖感言.md
#
# │   │   ├── 📄 在约会软件寻找爱情的深圳人：​我一认真，对方马上就跑了
# │   │          📍 ID: 20250615202030-k9txnz9
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/在约会软件寻找爱情的深圳人：​我一认真，对方马上就跑了
#
# │   │   ├── 📄 孟晚舟任华为轮值董事长
# │   │          📍 ID: 20250615202030-m83ya1x
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/孟晚舟任华为轮值董事长
#
# │   │   ├── 📄 如何看待张大飞的恋爱观？.md
# │   │          📍 ID: 20250615202030-mzz36px
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/如何看待张大飞的恋爱观？.md
#
# │   │   ├── 📄 复盘，美国制裁华为，如何实质性反制？
# │   │          📍 ID: 20250615202030-n9oiz76
# │   │          📂 路径: /我的笔记/吉光片羽/案例素材/复盘，美国制裁华为，如何实质性反制？
#
# ...
# 2146.       豆瓣读书记录_已读515_2022-04-01.md
# 2147.       豆瓣读书记录_在读111_2022-04-01.md
# 2148.       用200本书构建知识体系Part3——脑神经科学、遗传学、进化生物学、心理学、行为经济学.md
# 2149.       豆瓣2024年度读书榜单.md
# 2150.       用200本书构建知识体系.md
# 2151.       政治学、社会学、宏观经济学.md
# 2152.       我得了松鼠症，晚期那种，还有救吗？
# 2153.       时间裂开的碎片 —— 2024 我的私人阅读十佳
# 2154.       豆瓣读书记录_想读344_2022-04-01.md
# 2155.     为知笔记使用技巧
# 2156.     为知笔记互链测试
# 2157.     为知笔记标签分组设置
# 2158.     卡片笔记
# 2159.     在路上
# 2160.       Snote功能测试
# 2161.        Exhibitions - Museo di Roma
# 2162.       一休(日本著名奇僧)—搜狗百科
# 2163.       一个普通人的阅读生涯
# 2164.       中学时候
# 2165.       《京都漫步》.md
# 2166.       亲爱的小芳：
# 2167.       北京
# 2168.       惠州照片202311
# 2169.       十一游日本记录201910
# 2170.       人工智能
# 2171.       KM
# 2172.       2024年终盘点-2024年度10大个人热帖-黄大年茶思屋
# 2173.        Exhibitions - Musei Capitolini
# 2174.       华为云找到了一种智能化跑腿服务
# 2175.       工作相关2014
# 2176.       2020年春节.md
# 2177.       双十一你买了什么好东西？
# 2178.       2025蛇年春节祝福
# 2179.       19
# 2180.       2020年五一节（0502~0504）
# 2181.       当你成为父亲，才能理解父亲——父亲节，2024.6.16
# 2182.       心情画记2012
# 2183.       为什么我对老婆有怨气？
# 2184.       2022国庆行程（计划）
# 2185.       微信转账记录2015~2024 to 黄丽芳
# 2186.       小咪的问题
# 2187.       云水谣.md
# 2188.       生日祝福
# 2189.       纪要（杂）
# 2190.       记事2014
# 2191.       深圳图书馆.北。一些关于书的书的照片。
# 2192.       那么多经过的地方，我没有去过
# 2193.       父母的记忆
# 2194.       金阁寺.md
# 2195.       这是一条好消息：2024年度茶思屋之星获奖名单公布啦！热烈祝贺获奖团队和个人-黄大年茶思屋
# 2196.       欧洲游201403
# 2197.       香港迪士尼
# 2198.       短暂与永恒——艺术与科学的关系@深圳美术馆
# 2199.       清水寺.md
# 2200.       随想2014
# 2201.       随想
# 2202.       贺卡
# 2203.       走走看看
# 2204.       读书笔记2014
# 2205.       日本七日游路线图 - Microsoft Word
# 2206.       放在心里没有对老婆说的话，但有时候真的想一吐为快
# 2207.       手绘明信片 - life of Pi
# 2208.       记事
# 2209.       星海横流，蹀躞万里 | 茶思屋2024年终盘点
# 2210.       我的知识地图 20140329
# 2211.       涂鸦2014
# 2212.       想你
# 2213.       生日祝福 2023年8月19日 周六 12:19
# 2214.       读书笔记
# 2215.       致词
# 2216.     读后感
# 2217.       《生活三部曲：生活的样子》.md
# 2218.       情绪的隐秘力量——《人类的荣耀：是什么让我们独一无二》读后感
# 2219.       代入法解方程，破解时间谜题——《无证之罪》读后感.md
# 2220.       2：好故事可以收服人心
# 2221.       为了不能忘却的苦难——《秋园》读后感
# 2222.       工作伦理的变迁——《 工作、消费主义和新穷人》读后感
# 2223.       当世界尚未陈旧，一切都还是新的——《宝宝也是哲学家》读后感
# 2224.       为什么你需要学习阅读和写作？——《阅读与写作讲义》读后感
# 2225.       《AIGC：智能创作时代》读后感***
# 2226.       《幽冥仙途》读后感.md
# 2227.       《文明之光（第三册）》读后感***
# 2228.       《雨》读后感.md
# 2229.       日常琐事皆是修行——《禅与摩托车维修艺术》读后感.md
# 2230.       读书是可以随身携带的避难所——我的2021年度读书报告.md
# 2231.       双重人生——《哥谭重案组1：分内之事》读后感
# 2232.       《蓝莓上尉》读后感.md
# 2233.       《海狼》读后感.md
# 2234.       最终极的占有——《色戒》观后感
# 2235.       《Head First HTML与CSS（第2版）》读后感
# 2236.       有些人，盖棺也无法定论——《法国往事（下）》读后感.md
# 2237.       《为什么读经典》读后感
# 2238.       《相约星期二》读后感
# 2239.       《一本小小的红色写作书》读后感
# 2240.       时间、成长及缺憾——《给大壮的信》读后感
# 2241.       《许仙志3》读后感.md
# 2242.       古老的智慧——《黑猩猩的政治》读后感
# 2243.       《平如美棠》读后感
# 2244.       《逻辑的引擎》读后感***
# 2245.       《Modern Generative AI with ChatGPT and OpenAI Models（双语版）》读后感**
# 2246.       在大数据中披沙拣金——《信号与噪声》读后感
# 2247.       《以图代言》读后感.md
# 2248.       《跟菲力大叔学手绘——创意速写》读后感.md
# 2249.       一个普通劳动者的精神漂流——《我在北京送快递》读后感
# 2250.       《怪诞行为学2 - 非理性的积极力量》读后感
# 2251.       《高兴死了》读后感
# 2252.       从“唯一真理”到“多元对话”——《走出唯一真理观》读后感
# 2253.       家不是讲理的地方——《爱的博弈》读后感
# 2254.       人类的终极命运——读《奇点临近》有感.md
# 2255.       《边城》读后感.md
# 2256.       《星际特工2》读后感.md
# 2257.       乡下人的悲歌——《秧歌》读后感*****
# 2258.       伟大的达尔文演化论——《盲眼钟表匠》读后感
# 2259.       世界的本来面貌——《复杂·性》读后感
# 2260.       《白话统计》读后感.md
# 2261.       信息技术的前世今生——《信息简史》读后感
# 2262.       用想象力超越俗世生活——《夜晚的潜水艇》读后感
# 2263.       《月球陨落》观后感
# 2264.       为什么我们需要文学评论？——《许子东现代文学课》读后感
# 2265.       《Python快速入门》读后感.md
# 2266.       在局部中窥见全貌——《局部1：陌生的经验》读后感***
# 2267.       现实中的林奕含就像房思琪一样没有了——《 房思琪的初恋乐园》读后感
# 2268.       《读库1804》读后感.md
# 2269.       时代与人的永恒话题——2022年3月读书小记.md
# 2270.       艰难浮沉的生活——《流俗地》读后感
# 2271.       豆瓣读书记录_在读95_2021-07-24.md
# 2272.       《从一到无穷大》读后感
# 2273.       《数据分析实战》读后感.md
# 2274.       一场对生活的反抗——《一个人的朝圣》读后感.md
# 2275.       《杨戬》观后感*****
# 2276.       AI 助你实现作家梦——《Three Story Method_ Cowriting with ChatGPT》读后感
# 2277.       《枕刀歌之尘世行》观后感****
# 2278.       是什么阻碍了我们好好休息？——10大最受欢迎的深度休息方式.md
# 2279.       《星际特工3》读后感.md
# 2280.       《鬼刀》读后感
# 2281.       《身边的江湖》读后感
# 2282.       《ChatGPT使用指南》读后感**
# 2283.       《黄金案（大唐狄公案·第一辑）》读后感
# 2284.       《Python数据分析：活用Pandas库》读后感
# 2285.       《简明Python教程》读后感.md
# 2286.       《Python学习手册（第4版）》读后感.md
# 2287.       外星乌托邦和温柔的异星来客——《星之继承者II——温柔的伽星巨人》读后感
# 2288.       《惊爆点》读后感.md
# 2289.       小说中的自成世界——读《星之继承者I》有感.md
# 2290.       《Python数据处理》读后感.md
# 2291.       《蒸汽火车头》读后感
# 2292.       数据可视化之道：美感和内容的平衡——《不只是美——信息图表设计原理与经典案例》读后感.md
# 2293.       《以鸟兽之名》读后感***
# 2294.       《夸克与美洲豹》读后感**.md
# 2295.       写作是一门需要训练的技艺——《蔡骏24堂写作课》读后感
# 2296.       一种对人类未来的乐观主义——《无穷的开始：世界进步的本源》读后感
# 2297.       最深的爱恋终抵不过时间——《七夜雪》读后感
# 2298.       《我本芬芳》读后感***
# 2299.       《SQL基础教程（第2版）》读后感
# 2300.       孤独与寻找的百年轮回 ——《一句顶一万句》读后感.md
# 2301.       《642件可写的事》读后感
# 2302.       对多数人来说，幽默是一种技能而不是天赋——《有梗》读后感
# 2303.       人工智能时代的哲学思考——《生命 3.0》读后感
# 2304.       《小顾聊绘画－贰》读后感
# 2305.       你相信吗，学习编程让我戒了游戏瘾——《Python编程快速上手 _ 让繁琐工作自动化》读后感
# 2306.       寻获额外的乐趣——《如何阅读一本文学书》读后寻获感.md
# 2307.       《Python编程：从入门到实践》读后感.md
# 2308.       当个良善之辈就能促成合作吗？——《超级合作者》读后感
# 2309.       《封闭式车库》读后感.md
# 2310.       《Getting Started with Processing.py》读后感
# 2311.       日常琐事皆是修行——2022年1月读书小记.md
# 2312.       《疾速追杀4》观后感
# 2313.       《大明乌纱》读后感
# 2314.       我觉得中国人还是太在意外国人
# 2315.       《昆仑3》读后感
# 2316.       自洽一体的奇异世界——《平面国：多维空间传奇往事》读后感
# 2317.       晨间日记让人更接近梦想？——《晨间日记的奇迹》读后感
# 2318.       学习究竟是什么？——元学习（学习如何学习）指南.md
# 2319.       在19世纪的法国如何快速传播谣言？——趣读《基督山伯爵》中的冷知识.md
# 2320.       一个老外的中国生活启示录——《我用中文做了场梦》读后感****
# 2321.       一只画眉鸟引发的奇案——《喻世明言》读后感
# 2322.       读书不觉秋风至——2021年3季度读书小结.md
# 2323.       《三岔口》读后感
# 2324.       《我书架上的神明》读后感***
# 2325.       《逝》读后感.md
# 2326.       技术对艺术的冲击——《摄影小史》读后感
# 2327.       《LEARN PYTHON VISUALLY》读后感
# 2328.       了不起的盖茨比 - 笔记汇总
# 2329.       《Pandas数据处理与分析》读后感****
# 2330.       以古鉴今，中国对美国高科技的挑战能否成功？——《芯片战争》读后感
# 2331.       《我大概是只废汪了》读后感
# 2332.       从“祥瑞”到“灾异”：王莽的悲剧与儒家的困局——《祥瑞》读后感.md
# 2333.       科幻不止冷冰冰的机甲，还有温暖的想象力——《转生接口》读后感
# 2334.       《解忧杂货店》人物关系 @famo
# 2335.       志愿军战士永垂不朽！——电影《志愿军：雄兵出击》讲述的是历史真相还是文学创作？
# 2336.       《AIGC+：100倍速生产爆款内容的底层逻辑》读后感*
# 2337.       《元宇宙时代的虚拟现实》读后感
# 2338.       何以为人？——2022年12月读书小记
# 2339.       短暂的爱情，漫长的生活——读《霍乱时期的爱情》.md
# 2340.       希腊神话故事里最精巧的爱情故事——《希腊罗马神话》读后感
# 2341.       《蒋勋说宋词》读后感
# 2342.       《决战中途岛》观后感.md
# 2343.       《Python网络数据采集》读后感.md
# 2344.       我们什么时候连说话都要别人教了？——《如何向GPT提问》读后感**.md
# 2345.       《名画之谜：希腊神话篇-中野京子》读后感
# 2346.       《我们仨》读后感.md
# 2347.       百年未有之大变局——《梦游者：1914年，欧洲如何走向一战》读后感
# 2348.       《名画之谜：历史故事篇》读后感
# 2349.       以战止戈 —— 永不该被遗忘的铁原阻击战（下）
# 2350.       《图解物联网》读后感.md
# 2351.       【私人十佳】——邹沁心的2021年度读书报告.md
# 2352.       当我们谈论思考时，我们在谈论什么——2022年5月读书小记.md
# 2353.       爱的明信片
# 2354.       《数据之美》读后感.md
# 2355.       《诉讼可视化》读后感
# 2356.       《算法神探》读后感.md
# 2357.       《阿拉蕾 No. 1》读后感*****
# 2358.       《惊天营救》观后感.md
# 2359.       《法国往事（上）》读后感.md
# 2360.       《创新者》读后感.md
# 2361.       一面向思考者的AI指南——生造的中文书名《AI 3.0》 *****
# 2362.       《非平面》读后感.md
# 2363.       《银翼夜枭 - 01暗夜女巫》读后感.md
# 2364.       智慧无法传授，只能亲身体验——《悉达多》读后感
# 2365.       《回答不了》读后感
# 2366.       《图灵的大教堂》读后感
# 2367.       《成为数据分析师》读后感
# 2368.       人生的残酷，回忆也冲淡不了——《在细雨中呼喊》读后感.md
# 2369.       《叫魂： 1768年中国妖术大恐慌》读后感
# 2370.       大篇幅的命题作文——《清单革命》读后感
# 2371.       世界史、科技史、个人史——2022年6月读书小记.md
# 2372.       如何跨越裂谷？—— 从阅读记录到思考输出 ——《卡片笔记写作法》读后感
# 2373.       《半小时漫画唐诗》读后感.md
# 2374.       我的2020年读书小结 - 漫画篇.md
# 2375.       不要破坏我的童年滤镜——《刀背藏身》读后感
# 2376.       囤积是一种病
# 2377.       军人最大的奉献不是牺牲，而是胜利！—— 永不该被遗忘的铁原阻击战（中）
# 2378.       《剑来1》读后感.md
# 2379.       《孟买酒店》观后感
# 2380.       《怦然心动》观后感.md
# 2381.       我的2020年读书小结 -- Python篇.md
# 2382.       朋友圈是个虚拟的小世界
# 2383.       2021年度书影音报告
# 2384.       《重说中国近代史》读后感
# 2385.       《许仙志1》读后感.md
# 2386.       活在当下，静心生活——《十分钟冥想》读后感*****.md
# 2387.       军人最大的奉献不是牺牲，而是胜利！——《铁在烧》读后感
# 2388.       《SAW X》观后感
# 2389.       开书店的梦想又破灭了一回——《书店》读后感
# 2390.       少年人轰轰烈烈的爱情——《少年维特的烦恼》读后感
# 2391.       报复是维持社会秩序的强大力量
# 2392.       《许仙志6》读后感.md
# 2393.       《杜撰集》读后感
# 2394.       读书的共鸣——《读书毁了我》读后感
# 2395.       《 Python游戏编程快速上手(第4版)》读后感.md
# 2396.       直接的答案无法解决困境——《单读17：人的困境》读后感
# 2397.       《从零开始学Python数据分析》读后感.md
# 2398.       经典名著为什么经典？——《12堂文学阅读课》读后感
# 2399.       人类语言与思维结构的映射——《思想本质：语言是洞察人类天性之窗 》读后感.md
# 2400.       支离破碎的意象，一言难尽的故事——《光年》读后感.md
# 2401.       《皮囊》读后感
# 2402.       人类文明的高度有赖于集体协作的力量——《流浪地球2》观后感
# 2403.       燕去燕来——《遍地枭雄》读后感.md
# 2404.       《银河铁道之夜》读后感.md
# 2405.       制约生命、城市、公司规模化发展的隐秘法则——《规模》读后感
# 2406.       数说我的2021年度读书报告.md
# 2407.       《草间居游》读后感.md
# 2408.       《文森特与凡·高：星空中的月亮》读后感.md
# 2409.       你是否属于那2%的人？——《智能时代》读后感
# 2410.       人的头脑，最大的谜团——《黑镜 第三季》观后感.md
# 2411.       仍在酝酿，已闻酒香——《阳光猛烈，万物显形》读后感.md
# 2412.       《小说课（壹）》读后感.md
# 2413.       《雪中悍刀行 1》读后感
# 2414.       如何输出高质量ChatGPT提示词？掌握这两个关键点就够了！——《Mastering ChatGPT_ 21 Prompts Templates for Effortless Writing 21个提示模板辅助轻松写作》读后感
# 2415.       半年来读了15本Python编程入门书，我给这5本打五星！.md
# 2416.       时代与人的永恒话题——《单读. 十周年特辑》读后感
# 2417.       《元宇宙大投资》读后感***
# 2418.       “他说，我说”，按对话模式来写作——《高效写作的秘密》读后感
# 2419.       《Python基础教程(第3版)》读后感***
# 2420.       我的2020年读书小结 - 杂篇.md
# 2421.       《漫画统计学》读后感.md
# 2422.       《对比Excel，轻松学习Python数据分析》读后感.md
# 2423.       命中注定 or 人定胜天？——《六小时后你会死》读后感***
# 2424.       2 No.22》读后感
# 2425.       荒野生存，永恒的故事——《生火》读后感
# 2426.       《如何学习》读后感
# 2427.       《ChatGPT：AI革命》读后感*
# 2428.       时代的野火——《野火集——三十周年纪念版》读后感.md
# 2429.       《阿凡达2：水之道》观后感
# 2430.       《乐见数据》读后感
# 2431.       歌词创作可有一定之规？——《流行歌词写作教程》读后感
# 2432.       最深的爱恋终抵不过时间——2022年2月读书小记.md
# 2433.       在暴风雨中放声歌唱——《一只鸟接着一只鸟》读后感
# 2434.       《子弹笔记》读后感**
# 2435.       《大卫·戈尔的一生》观后感
# 2436.       哲学、科学、常识，各归其位——《哲学-科学-常识》读后感.md
# 2437.       沉默的大多数
# 2438.       从手中有剑到心中无剑——《从零开始创意写作》读后感
# 2439.       《Python从入门到项目实践》读后感.md
# 2440.       悲壮的旅程——《老人与海》读后感*****
# 2441.       统计革命——《女士品茶》读后感***
# 2442.       少女奇遇记——《买下我》观后感
# 2443.       《万物：创世》读后感.md
# 2444.       《你今天真好看》读后感
# 2445.       《超级快速阅读》读后感.md
# 2446.       《元宇宙：下一代互联网的新形态  》读后感
# 2447.       上帝的语言——《微积分的力量》读后感
# 2448.       欲望、孤独与救赎——《沉沦》读后感
# 2449.       《深海》观后感
# 2450.       无远弗届的想象——2022年8月读书小记.md
# 2451.       幸福与爱的秘密——2022年10月读书小记.md
# 2452.       《我决定活得有趣》读后感.md
# 2453.       《西西弗神话》读后感
# 2454.       《你好，李焕英》观后感
# 2455.       《小鸟睡在我身旁》读后感.md
# 2456.       《小顾聊绘画－文艺复兴》读后感
# 2457.       理想的生活，永远在别处——《革命之路》观后感
# 2458.       理想主义者的幻灭——《了不起的盖茨比》读后感
# 2459.       《终结者：黑暗命运》观后感.md
# 2460.       《白话机器学习算法》读后感.md
# 2461.       《正见》读后感***
# 2462.       《微晕的树林》读后感**
# 2463.       《这就是搜索引擎》读后感
# 2464.       《小人物》观后感**
# 2465.       《AIGC商业宝典》读后感**.md
# 2466.       《花束般的恋爱》观后感
# 2467.       理解生而为人的自己，掌握获得幸福的方法——《 象与骑象人：幸福的假设》读后感.md
# 2468.       《利刃出鞘 Knives Out (2019)》观后感.md
# 2469.       是什么，遮蔽了我们的双眼？——2022年9月读书小记.md
# 2470.       一部小说怎么才能成为经典？——《白夜行》读后感.md
# 2471.       一个侦探坏了一个好局——《漫长的告别》读后感.md
# 2472.       国家富裕或贫穷的逻辑 --《国富国穷》★★★★★
# 2473.       《生命最后的读书会》读后感
# 2474.       《再一次》读后感.md
# 2475.       《极简人工智能》读后感
# 2476.       《师从天才》读后感
# 2477.       《解忧杂货店》-东野圭吾，读后感
# 2478.       《长安的荔枝》读后感****
# 2479.       暮色中的星光——《无暇他顾：勒古恩 81-85 岁博客文章集锦》读后感.md
# 2480.       《猫之眼1》读后感
# 2481.       《从Python开始学编程》读后感.md
# 2482.       《局外人》读后感.md
# 2483.       《Python数据可视化之Matplotlib精进》读后感.md
# 2484.       你自以为很懂的进化论其实只是一知半解——《熊猫的拇指》读后感
# 2485.       《Python数据可视化之matplotlib实践》读后感.md
# 2486.       《Python数据科学入门》读后感.md
# 2487.       一本老派写作指导，对我们还有帮助吗？——《写作这门手艺：普林斯顿大学写作课》读后感***
# 2488.       《新宋·十字1》读后感.md
# 2489.       人生苦，何以解？——从佛学到科学的答案——《洞见：为什么佛学是真的》读后感.md
# 2490.       即将消失的放牧生活——《冬牧场》读后感
# 2491.       《拆弹专家2》观后感.md
# 2492.       谁能保证，生活中的哪一种选择会导向幸福？——《鹿川有许多粪》读后感*****
# 2493.       揭秘科学家的学术生活——《双螺旋》读后感**
# 2494.       《Python3网络爬虫数据采集》读后感***
# 2495.       《绅士们》观后感.md
# 2496.       好故事与坏故事——《 说部之乱》读后感.md
# 2497.       《困在时间里的父亲》观后感
# 2498.       初读卡佛——《当我们谈论爱情时我们在谈论什么》★★★.md
# 2499.       由一方墓志唤醒的宫闱秘史——《漫长的余生》读后感
# 2500.       《Python数据分析基础》读后感
# 2501.       理解自由才能自由选择——《自由选择》读后感
# 2502.       读书不觉冬夜长——2021年4季度读书小结.md
# 2503.       《Python GUI设计：tkinter菜鸟编程》读后感.md
# 2504.       2020年度书影音报告
# 2505.       《氯的滋味》读后感.md
# 2506.       游戏人生——《游戏开发之旅》读后感.md
# 2507.       信息爆炸时代的心智争夺战——《定位》读后感
# 2508.       《漫画半小时中国科技史》读后感*
# 2509.       读书不觉春已暮——2021年上半年读书小结.md
# 2510.       《自学是门手艺》读后感.md
# 2511.       I want to know how it is gonna  end after sunrise
# 2512.       《飞行家》读后感.md
# 2513.       《美得令人心醉的宋词》读后感
# 2514.       《一本书读懂ChatGPT》读后感**
# 2515.       《星之继承者III——巨人之星》读后感****
# 2516.       《献给阿尔吉侬的花束》读后感****
# 2517.       《拉戈·云奇2：O.P.A.& 商业蓝调》读后感.md
# 2518.       理想的生活，永远在别处——2022年4月读书小记.md
# 2519.       《了不起的Markdown》读后感
# 2520.       关于书的书，关于阅读的阅读——《阅读的故事》读后感.md
# 2521.       《冥想5分钟，等于熟睡1小时》读后感
# 2522.       自在写文，意趣横生——《文章自在》读后感
# 2523.       《孩子们的诗》读后感.md
# 2524.       什么是好“文笔”？——《大师们的写作课：好文笔是读出来的》读后感
# 2525.       《成功与运气：好运与精英社会的神话》读后感**
# 2526.       《京都漫步》读后感.md
# 2527.       《小说的骨架》读后感.md
# 2528.       《树莓派Python编程入门与实战(第2版)》读后感.md
# 2529.       《小狗钱钱》读后感
# 2530.       打破"理性人"的神话——《助推：如何做出有关健康、财富与幸福的最佳决策》读后感.md
# 2531.       一个普通人的读书与写作——我的2022年读书报告.md
# 2532.       在历史的伤痕中寻找自我——《少年凯歌》读后感
# 2533.       《像计算机科学家一样思考Python (第2版)》读后感.md
# 2534.       《方向》读后感.md
# 2535.       没什么不可变更的诫条——《动物农场》读后感
# 2536.       《3秒》读后感.md
# 2537.       未尽的历史：西方的兴起？——《西方的兴起：人类共同体史》读后感
# 2538.       《笨办法学Python 3》读后感.md
# 2539.       《逻辑思维》读后感
# 2540.       《癌症传》读后感.md
# 2541.       《七十二堂写作课》读后感
# 2542.       权力社会里人们对性与爱的曲折追求——《情色朝鲜》读后感
# 2543.       大模型是否举足轻重到给我们的时代命名？——《大模型时代》读后感****
# 2544.       困境与解法——2022年7月读书小记.md
# 2545.       在不太平的岁月，打出一个世界强国——《亲历抗美援朝战争》★★★.md
# 2546.       志愿军存亡之战 —— 永不该被遗忘的铁原阻击战（上）
# 2547.       《创新者的窘境》读后感
# 2548.       《画的秘密》读后感.md
# 2549.       《世界历史很有趣：袁腾飞讲日本史》读后感.md
# 2550.       《秘密特工》观后感****
# 2551.       《东大爸爸写给我的日本史》读后感.md
# 2552.       《短篇小说写作指南》读后感***
# 2553.       《剑来2》读后感.md
# 2554.       《查令十字街84号》读后感
# 2555.       《费曼学习法：用输出倒逼输入》读后感
# 2556.       《Python数据可视化编程实战(第2版)》.md
# 2557.       时代与年轻人，永远的话题——《单向街001：最愚蠢的一代》读后感.md
# 2558.       《番茄工作法图解》读后感
# 2559.       《拉戈·云奇1：继承者&W集团》读后感.md
# 2560.       《文学课：如何轻松理解伟大作品》读后感.md
# 2561.       2019年度书影音报告 - 我的豆瓣
# 2562.       《利用Python进行数据分析（原书第2版）》读后感
# 2563.       《病毒星球》读后感
# 2564.       《小顾聊神话》读后感.md
# 2565.       博大精深的Python可视化，你值得拥有！——五星书籍《Python数据可视化之美》推荐
# 2566.       不是所有的爱情，都有一个美好的结局--《伤心咖啡馆之歌》读后感.md
# 2567.       《仙症》读后感****
# 2568.       散文不错，访谈和小说不行——《东京一年》读后感***
# 2569.       大学毕业20年后重新学习编程，从Python开始——《Python编程 _ 从入门到实践》读后感
# 2570.       如果跳出父女亲情的框框.md
# 2571.       《机器学习精讲》读后感***
# 2572.       驱动我们行为的隐秘力量——《怪诞行为学——可预测的非理性》读后感.md
# 2573.       费马最终定理，易懂难精
# 2574.       跨越时空的共鸣——《最美唐诗》读后感
# 2575.       那些精妙的词句——好书推荐：《包法利夫人》*****.md
# 2576.       食色男女——《废都》读后感.md
# 2577.       豆瓣读书记录_想读207_2021-07-24.md
# 2578.       透过迷雾，挖掘真相——2022年11月读书小记.md
# 2579.       身居高位的决策者们也是人啊——《镜厅》读后感
# 2580.       逼真详实的旅行记录——《旅行与读书》读后感
# 2581.       降低期望、缓解焦虑，找到读书的乐趣——《快速阅读术》读后感.md
# 2582.       遗忘之地和被遗忘的记忆——《失落的卫星 _ 深入中亚大陆的旅程》读后感
# 2583.       非常系统的系统理论——《系统之美》读后感
# 2584.       黑白战争——《生吞》读后感
# 2585.       音乐与文学的交响——《音乐影响了我的写作》读后感
# 2586.       金句的巨大能量——《通往奴役之路》读后感
# 2587.       重读古龙派武侠小说《武林外史》
# 2588.       配色设计入门——《写给大家看的色彩书1：设计配色基础》读后感.md
# 2589.       《阿拉蕾 No.3》
# 2590.       乱马
# 2591.     我的头条荣誉
# 2592.     女儿成长小记
# 2593.       一个好凶的雷
# 2594.       你要是想我了，就看看这幅画
# 2595.       “好是好，但是想不起来了。”
# 2596.       女儿幼儿园中班期末寄语
# 2597.       安安趣事
# 2598.       爸爸
# 2599.       让你吃油腻的东西
# 2600.       我要永远爱你又多一天
# 2601.       生命的片段 20200503.md
# 2602.       打屁股
# 2603.       我现在长大了
# 2604.       我的名字为什么叫“安安”？
# 2605.       女儿成长小记2019~2020.md
# 2606.       雨下大了
# 2607.       我给你唱首歌吧 20241208
# 2608.       我的臭臭探出头来了，然后扑通掉到
# 2609.       情商
# 2610.       相信自己
# 2611.       口头禅：“不要！” 20191007(1周岁4个月零13天).md
# 2612.       采访小学生
# 2613.       面从嘴巴里逃走了
# 2614.       算术
# 2615.       母女日常互怼
# 2616.       小小播报员
# 2617.       给你的狗粮
# 2618.       生日邀请函_安安
# 2619.       女儿成长小记2019~2020_bak.md
# 2620.       猛吃苹果
# 2621.       小安安 2024年6月22日 周六 17:02
# 2622.       开花啦
# 2623.       抓知了20230528
# 2624.     永不该被遗忘的铁原阻击战
# 2625.     记忆编码
# 2626.     好物
# 2627.     微信朋友圈
# 2628.       身体影响心情
# 2629.       你的微信朋友圈几天可见？
# 2630.       华为危机公关能力值得赞一个
# 2631.       归舟
# 2632.       2024 龙年拜年文案.md
# 2633.       每个人都在看，少数人看见
# 2634.       朋友圈
# 2635.       我的3月书影音记录
# 2636.       心有猛虎，细嗅蔷薇。
# 2637.       4月份读书观影记录：6本书，3部电影
# 2638.       2023私人阅读记录 - 朋友圈.md
# 2639.       我的人设
# 2640.       过年2023
# 2641.       重开微信朋友圈
# 2642.       从前的日色变得慢
# 2643.       溪流背坡村
# 2644. 测试思源API
# 2645.   原生笔记，无自定义属性
# 2646.   自定义属性，无url
# 2647.   自定义属性，含url
# 2648.     自定义属性，含url (子文档)
# 2649.   原生笔记，无自定义属性，web剪藏
#
# === 路径解析统计 ===
# 总文档数: 2649
# 成功获取路径的文档数: 2649
# 未获取到路径的文档数: 0
#
# === 层级深度分布 ===
# 第0层: 7个文档
# 第1层: 172个文档
# 第2层: 130个文档
# 第3层: 2340个文档
#
# 文档树结构已保存到: output\doc_tree_QuincyZou.json
# 文档信息已保存到: output\docs_info_QuincyZou.json
# 可视化文档树已保存到: output\visual_tree_QuincyZou.txt
# 路径解析结果已保存到: output\doc_paths_QuincyZou.json

# %% [markdown]
# ## 获取文档的属性以及包含的块及内容

# %%
# 获取文档的属性以及包含的块及内容（使用functions.py模块）

def get_document_blocks(doc_id):
    """
    获取指定文档的所有块内容（使用functions.py模块）

    :param doc_id: 文档ID
    :return: 块列表
    """
    print(f"正在获取文档 {doc_id} 的所有块...")

    # 使用API客户端进行SQL查询
    sql_query = f"""
    SELECT id, type, subtype, content, markdown, parent_id, sort, created, updated
    FROM blocks
    WHERE root_id = '{doc_id}'
    ORDER BY sort
    """

    data = api_client.call_api("/api/query/sql", {"stmt": sql_query})

    if data and len(data) > 0:
        print(f"找到 {len(data)} 个块")
        return data
    else:
        print("未找到任何块")
        return []

def display_blocks(blocks):
    """
    格式化显示块内容

    :param blocks: 块列表
    """
    if not blocks:
        print("没有块可显示")
        return

    print("=" * 80)
    print(f"文档块结构 (共 {len(blocks)} 个块)")
    print("=" * 80)

    for i, block in enumerate(blocks, 1):
        block_type = block.get('type', 'unknown')
        subtype = block.get('subtype', '')
        content = block.get('content', '').strip()
        markdown = block.get('markdown', '').strip()
        parent_id = block.get('parent_id', '')
        block_id = block.get('id', '')
        created = block.get('created', '')
        updated = block.get('updated', '')

        # 根据块类型显示不同的图标
        type_icons = {
            'd': '📄',  # 文档
            'p': '📝',  # 段落
            'h': '📑',  # 标题
            'l': '📋',  # 列表
            'i': '🖼️',  # 列表项
            'b': '📦',  # 引用块
            'c': '💾',  # 代码块
            's': '🔄',  # 超级块
            't': '📊',  # 表格
            'm': '🔢',  # 数学公式
            'html': '🌐',  # HTML块
            'widget': '🔧',  # 挂件
            'iframe': '🖼️',  # iframe
            'video': '🎥',  # 视频
            'audio': '🔊',  # 音频
        }

        icon = type_icons.get(block_type, '📄')
        type_desc = f"{block_type}" + (f"/{subtype}" if subtype else "")

        print(f"\n{i:3d}. {icon} 块类型: {type_desc}")
        print(f"     📍 ID: {block_id}")
        print(f"     👆 父块: {parent_id}")
        print(f"     📅 创建: {created}")
        print(f"     🔄 更新: {updated}")

        if content:
            # 限制显示长度，避免输出过长
            display_content = content if len(content) <= 200 else content[:200] + "..."
            print(f"     💬 内容: {display_content}")

        if markdown and markdown != content:
            display_markdown = markdown if len(markdown) <= 200 else markdown[:200] + "..."
            print(f"     📝 Markdown: {display_markdown}")

        print("-" * 60)


def save_blocks_to_file(blocks, doc_id, output_dir="output"):
    """
    保存块信息到文件（使用FileManager）

    :param blocks: 块列表
    :param doc_id: 文档ID
    :param output_dir: 输出目录
    """
    output_path = Path(output_dir)
    output_path.mkdir(exist_ok=True)

    # 保存完整的块信息到JSON文件（使用FileManager）
    json_file = output_path / f"blocks_{doc_id}.json"
    FileManager.save_json_file(blocks, str(json_file))

    # 保存可读格式到文本文件
    txt_file = output_path / f"blocks_{doc_id}.txt"
    with txt_file.open('w', encoding='utf-8') as f:
        f.write(f"文档 {doc_id} 的块结构\n")
        f.write("=" * 60 + "\n\n")

        for i, block in enumerate(blocks, 1):
            f.write(f"{i:3d}. 块类型: {block.get('type', 'unknown')}\n")
            f.write(f"     ID: {block.get('id', '')}\n")
            f.write(f"     父块: {block.get('parent_id', '')}\n")
            f.write(f"     内容: {block.get('content', '').strip()}\n")
            if block.get('markdown'):
                f.write(f"     Markdown: {block.get('markdown', '').strip()}\n")
            f.write("-" * 40 + "\n")

    print(f"\n文件已保存:")
    print(f"  JSON格式: {json_file}")
    print(f"  文本格式: {txt_file}")

# 示例：指定要获取的文档ID
# 您可以修改这个ID为您想要查看的文档ID
DOC_ID = "20250618232924-ed8wf0w"  # 示例文档ID，请根据需要修改

print(f"开始获取文档 {DOC_ID} 的所有块内容...")
print()

# 获取块内容
blocks = get_document_blocks(DOC_ID)

if blocks:
    # 显示块内容
    display_blocks(blocks)

    attributes = block_manager.get_block_attributes(DOC_ID)
    print(attributes)
    # 保存到文件
    save_blocks_to_file(blocks, DOC_ID)

    # 统计信息
    type_counts = {}
    for block in blocks:
        block_type = block.get('type', 'unknown')
        type_counts[block_type] = type_counts.get(block_type, 0) + 1

    print(f"\n📊 块类型统计:")
    for block_type, count in sorted(type_counts.items()):
        print(f"  {block_type}: {count} 个")
else:
    print("未能获取到块内容")
# Out:
# 2025-06-21 22:20:26,610 - INFO - 数据已保存到: output\blocks_20250618232924-ed8wf0w.json
# 开始获取文档 20250618232924-ed8wf0w 的所有块内容...
#
# 正在获取文档 20250618232924-ed8wf0w 的所有块...
# 找到 45 个块
# ================================================================================
# 文档块结构 (共 45 个块)
# ================================================================================
#
#   1. 📄 块类型: d
#      📍 ID: 20250618232924-ed8wf0w
#      👆 父块:
#      📅 创建: 20250618232924
#      🔄 更新: 20250618232924
#      💬 内容: 这个大模型，真的治好了我的论文阅读障碍
# ------------------------------------------------------------
#
#   2. 🌐 块类型: html
#      📍 ID: 20250618232925-ksxmn77
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# <!DOCTYPE html>
# </div>
# ------------------------------------------------------------
#
#   3. 🌐 块类型: html
#      📍 ID: 20250618232925-lcpavs3
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# <html>
# <head>
#     <meta charset="utf-8">
#     <title>这个大模型，真的治好了我的论文阅读障碍</title>
# </head>
# <body>
# <!doctype html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <head></head>
#   </head>
#   <body>
#    ...
# ------------------------------------------------------------
#
#   4. 📝 块类型: p
#      📍 ID: 20250618232925-qyikp5f
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 在腾讯「元宝」的最近一次更新中，我们看到了这些问题的解决方案。他们新推出的「深度阅读模式」支持长文精读，能够输出模块化的、图文并茂的解析，非常适合用来读论文。
#      📝 Markdown: 在腾讯「**元宝**」的最近一次更新中，我们看到了这些问题的解决方案。他们新推出的「**深度阅读模式**」支持**长文精读**，**能够输出模块化的、图文并茂的解析**，非常适合用来读论文。
# ------------------------------------------------------------
#
#   5. 📝 块类型: p
#      📍 ID: 20250618232925-j0qgthv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 为了验证这一新功能的效果，机器之心进行了一手实测。
# ------------------------------------------------------------
#
#   6. 📝 块类型: p
#      📍 ID: 20250618232925-ndzts7w
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 论文「精读」，精在哪儿？
#      📝 Markdown: **论文「精读」，精在哪儿？**
# ------------------------------------------------------------
#
#   7. 📝 块类型: p
#      📍 ID: 20250618232925-9qbt9en
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 用 AI 读论文是一种怎样的体验？很多时候是：你丢给它一个 PDF，它返回一段总结 + 若干条概述（有时候可能高达 10 条）。这些信息确实有帮助，但有时候，你很难分清哪些是亮点，以及论文解决了什么、没解决什么，有哪些核心问题值得细看。
# ------------------------------------------------------------
#
#   8. 📝 块类型: p
#      📍 ID: 20250618232925-e5tqd5e
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 我们实测发现，「元宝」是通过提供一系列模块化、结构化信息来解决这些问题的。
# ------------------------------------------------------------
#
#   9. 📝 块类型: p
#      📍 ID: 20250618232925-lp4mnwq
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 以我们测试的一篇 SIGGRAPH 论文为例。如果你直接把论文丢进去，它返回的总结和其他 AI 区别不大。不过，只要你耐心往下拉，就会看到一个「深度阅读该文档」的按钮，这才是「一键直达」论文精读的开关。
# ------------------------------------------------------------
#
#  10. 📝 块类型: p
#      📍 ID: 20250618232925-mezbn47
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_2-20250618232924-g1t0tnn.png
#      📝 Markdown: ![image](assets/640_2-20250618232924-g1t0tnn.png)
# ------------------------------------------------------------
#
#  11. 📝 块类型: p
#      📍 ID: 20250618232925-la4rqmw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 与之前总结论文的界面不同，精读页面会把论文拆解得非常有层次，研究背景、研究方法、实验设计、结果分析、总体结论各自被组织成一个模块，很像机器之心平时介绍论文的布局。所有这些都可以通过左边的大纲迅速跳转。
#      📝 Markdown: 与之前总结论文的界面不同，**精读页面会把论文拆解得非常有层次**，研究背景、研究方法、实验设计、结果分析、总体结论各自被组织成一个模块，很像机器之心平时介绍论文的布局。所有这些都可以通过左边的大纲迅速跳转。
# ------------------------------------------------------------
#
#  12. 📝 块类型: p
#      📍 ID: 20250618232925-q2c08rv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_3-20250618232924-7uq17ds.png
#      📝 Markdown: ![image](assets/640_3-20250618232924-7uq17ds.png)
# ------------------------------------------------------------
#
#  13. 📝 块类型: p
#      📍 ID: 20250618232925-qwi6458
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 别看每个模块字不多，其实这些字是非常有信息量的。比如在研究背景这个模块，「研究难点」段落仅用三个短句就描述了四个难点，「相关工作」更是对第二章「related work」的高度浓缩，一段话就把该领域的主要技术路线介绍清楚了。所以，在读完这个模块之后，我们能基本搞清楚论文研究的是一个什么问题，面临的是怎样一个研究现状。
# ------------------------------------------------------------
#
#  14. 📝 块类型: p
#      📍 ID: 20250618232925-bg1c6fb
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了这些常规的结构化信息，元宝的精读还有一个令人眼前一亮的设计 —— 它会把论文的优点与不足列出来，方便研究者迅速了解自己能从这篇论文中学到什么，还有什么问题值得继续研究。
#      📝 Markdown: 除了这些常规的结构化信息，元宝的精读还有一个令人眼前一亮的设计 —— **它会把论文的优点与不足列出来**，方便研究者迅速了解自己能从这篇论文中学到什么，还有什么问题值得继续研究。
# ------------------------------------------------------------
#
#  15. 📝 块类型: p
#      📍 ID: 20250618232925-i5rojyg
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_4-20250618232924-7wcgqv5.png
#      📝 Markdown: ![image](assets/640_4-20250618232924-7wcgqv5.png)
# ------------------------------------------------------------
#
#  16. 📝 块类型: p
#      📍 ID: 20250618232925-x7ooiaw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_5-20250618232924-zm8iiwz.png
#      📝 Markdown: ![image](assets/640_5-20250618232924-zm8iiwz.png)
# ------------------------------------------------------------
#
#  17. 📝 块类型: p
#      📍 ID: 20250618232925-d8xh6s1
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 为什么这个功能如此重要？中国台湾清华大学教授彭明辉在关于论文阅读的一篇文章中曾经写道，论文和课本不同，课本会提供别人整理、组织好的系统性知识，而论文要求读者自己从无组织的知识中检索、筛选、组织知识。其中，分析既有研究优缺点的能力尤其重要，这是批判性思维的关键部分，也是学术研究中自我提升的重要途径。元宝通过快速分析和总结论文的优缺点，可以帮助研究者节省大量筛选和初步理解的时间，使他们能够更快地聚焦于...
#      📝 Markdown: 为什么这个功能如此重要？中国台湾清华大学教授彭明辉在关于论文阅读的一篇文章中曾经写道，论文和课本不同，课本会提供别人整理、组织好的系统性知识，而论文要求读者自己从无组织的知识中检索、筛选、组织知识。其中，**分析既有研究优缺点的能力尤其重要，这是批判性思维的关键部分，也是学术研究中自我提升的重要途径**。元宝通过快速分析和总结论文的优缺点，可以帮助研究者节省大量筛选和初步理解的时间，使他们能够更快...
# ------------------------------------------------------------
#
#  18. 📝 块类型: p
#      📍 ID: 20250618232925-udiynou
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 不过，如果你觉得前面这些信息太繁琐，你也可以直接跳转到最后的「关键问题与解答」模块。这里会列出几个最关键的问题，让你快速了解到论文的价值，进而判断是否值得花时间去读原文。当然，之前的很多 AI 助手也会在答案末尾呈现一些关键问题，点一下就能得到答案，但如果你是一名初学者或者跨学科背景的读者，你可能不太容易判断哪些问题比较关键。元宝这种直接呈现的方式感觉更加直观。
#      📝 Markdown: 不过，如果你觉得前面这些信息太繁琐，你也可以直接跳转到最后的 **「关键问题与解答」模块**。这里会列出几个最关键的问题，让你快速了解到论文的价值，进而判断是否值得花时间去读原文。当然，之前的很多 AI 助手也会在答案末尾呈现一些关键问题，点一下就能得到答案，但如果你是一名初学者或者跨学科背景的读者，你可能不太容易判断哪些问题比较关键。元宝这种直接呈现的方式感觉更加直观。
# ------------------------------------------------------------
#
#  19. 📝 块类型: p
#      📍 ID: 20250618232925-mwmhayr
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_6-20250618232924-0sgh1t9.png
#      📝 Markdown: ![image](assets/640_6-20250618232924-0sgh1t9.png)
# ------------------------------------------------------------
#
#  20. 📝 块类型: p
#      📍 ID: 20250618232925-h9srjs7
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 原图原数，谁说 AI 读论文不能配图？
#      📝 Markdown: **原图原数，谁说 AI 读论文不能配图？**
# ------------------------------------------------------------
#
#  21. 📝 块类型: p
#      📍 ID: 20250618232925-ki4dswk
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 在读论文时，很多人都有一个习惯，一边看图，一边看论文描述。这样理解起来更快、更容易。但是，现在市面上大部分 AI 应用返回的都是文字结果，想看图的话需要自己去原文里找。
# ------------------------------------------------------------
#
#  22. 📝 块类型: p
#      📍 ID: 20250618232925-xwgzq18
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 我们在测试中发现，元宝是为数不多的直接把论文图截出来并放到段落对应位置的 AI。比如，如果在某个模块讲架构，那它会把对应的架构图放上：
#      📝 Markdown: 我们在测试中发现，**元宝是为数不多的直接把论文图截出来并放到段落对应位置的 AI**。比如，如果在某个模块讲架构，那它会把对应的架构图放上：
# ------------------------------------------------------------
#
#  23. 📝 块类型: p
#      📍 ID: 20250618232925-0m3pxz4
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_7-20250618232924-9d0ho0e.png
#      📝 Markdown: ![image](assets/640_7-20250618232924-9d0ho0e.png)
# ------------------------------------------------------------
#
#  24. 📝 块类型: p
#      📍 ID: 20250618232925-tuzna5p
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_8-20250618232924-3ec9sxb.png
#      📝 Markdown: ![image](assets/640_8-20250618232924-3ec9sxb.png)
# ------------------------------------------------------------
#
#  25. 📝 块类型: p
#      📍 ID: 20250618232925-c8fb1fw
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 如果在某个模块讲实验结果，那它会把对应的图表放上：
# ------------------------------------------------------------
#
#  26. 📝 块类型: p
#      📍 ID: 20250618232925-sld5b8i
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_9-20250618232924-8xtz03t.png
#      📝 Markdown: ![image](assets/640_9-20250618232924-8xtz03t.png)
# ------------------------------------------------------------
#
#  27. 📝 块类型: p
#      📍 ID: 20250618232925-wbcvbo7
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_10-20250618232924-hrqfbcx.png
#      📝 Markdown: ![image](assets/640_10-20250618232924-hrqfbcx.png)
# ------------------------------------------------------------
#
#  28. 📝 块类型: p
#      📍 ID: 20250618232925-a40iuay
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 众所周知，大模型的幻觉问题现在还没有办法完全解决。因此，这种原图原数的呈现其实是一种更加可靠的输出方式，方便读者随时验证模型的答案，在用作参考时更加保险。
# ------------------------------------------------------------
#
#  29. 📝 块类型: p
#      📍 ID: 20250618232925-8qe5pb3
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 此外，我们还发现，如果你有写博客等对外输出的需求，元宝还可以帮你绘制图表，而且你不需要告诉它数据去哪里找，它能自己定位到论文中的相关表格，并将数据提取出来进行绘制。这一功能可以通过精读页面右侧的「提问」按钮来唤起。
# ------------------------------------------------------------
#
#  30. 📝 块类型: p
#      📍 ID: 20250618232925-bdpd5im
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_11-20250618232924-lhj4egm.png
#      📝 Markdown: ![image](assets/640_11-20250618232924-lhj4egm.png)
# ------------------------------------------------------------
#
#  31. 📝 块类型: p
#      📍 ID: 20250618232925-9sigu5g
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 随时随地想读就读，谁说读论文障碍重重？
#      📝 Markdown: **随时随地想读就读，谁说读论文障碍重重？**
# ------------------------------------------------------------
#
#  32. 📝 块类型: p
#      📍 ID: 20250618232925-wh5fo5w
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了结构化的信息和图文并茂的输出，我们在测试中还发现，元宝其实有一些非常实用的小功能，能让读论文这件事变得更加方便。
# ------------------------------------------------------------
#
#  33. 📝 块类型: p
#      📍 ID: 20250618232925-qqdg1tt
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 首先是划词翻译和搜索，这是「原文」阅读界面的两个实用小功能。划词翻译可以帮助英语不好的读者随时随地扫清语言障碍，划词搜索则更进一步，像是把元宝的搜索功能做成了一个插件，可以随时搜相关信息。而且，元宝给出的解释不只是简短的总结，还有模块化的展开，真是把「结构化」、「有信息量」做到每一个细节里了。
#      📝 Markdown: 首先是**划词翻译和搜索**，这是「原文」阅读界面的两个实用小功能。划词翻译可以帮助英语不好的读者随时随地扫清语言障碍，划词搜索则更进一步，像是把元宝的搜索功能做成了一个插件，可以随时搜相关信息。而且，元宝给出的解释不只是简短的总结，还有模块化的展开，真是把「结构化」、「有信息量」做到每一个细节里了。
# ------------------------------------------------------------
#
#  34. 📝 块类型: p
#      📍 ID: 20250618232925-kwwat0a
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_12-20250618232924-9tq4oc6.gif
#      📝 Markdown: ![image](assets/640_12-20250618232924-9tq4oc6.gif)
# ------------------------------------------------------------
#
#  35. 📝 块类型: p
#      📍 ID: 20250618232925-ua7u619
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_13-20250618232925-712fycw.gif
#      📝 Markdown: ![image](assets/640_13-20250618232925-712fycw.gif)
# ------------------------------------------------------------
#
#  36. 📝 块类型: p
#      📍 ID: 20250618232925-xocemfy
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 其次是「离线阅读」。这个功能的实用之处在于：它可以让你在「飞行模式」下回看精读内容及原文，不浪费一点碎片时间。这让航空公司在与高铁的竞争中扳回一局。说不定，研究者们的下一个灵感就是在飞机上回看精读时产生的呢。
#      📝 Markdown: 其次是「**离线阅读**」。这个功能的实用之处在于：它可以让你在「飞行模式」下回看精读内容及原文，不浪费一点碎片时间。这让航空公司在与高铁的竞争中扳回一局。说不定，研究者们的下一个灵感就是在飞机上回看精读时产生的呢。
# ------------------------------------------------------------
#
#  37. 📝 块类型: p
#      📍 ID: 20250618232925-r9boa3s
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_14-20250618232925-3pps49b.jpg
#      📝 Markdown: ![image](assets/640_14-20250618232925-3pps49b.jpg)
# ------------------------------------------------------------
#
#  38. 📝 块类型: p
#      📍 ID: 20250618232925-9isicnb
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 最后一个小功能是「计算器」。前段时间，AI 因为分不清 9.9 和 9.11 哪个大而引发了很多讨论。在元宝中，我们发现它集成了计算器功能，能够确保根据准确的计算结果来生成答案。这种功能在我们阅读实验数据时非常有用。
#      📝 Markdown: 最后一个小功能是「**计算器**」。前段时间，AI 因为分不清 9.9 和 9.11 哪个大而引发了很多讨论。在元宝中，我们发现它集成了计算器功能，能够确保根据准确的计算结果来生成答案。这种功能在我们阅读实验数据时非常有用。
# ------------------------------------------------------------
#
#  39. 📝 块类型: p
#      📍 ID: 20250618232925-3e59xx9
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 长文精读的背后：原来有专家指导
#      📝 Markdown: **长文精读的背后：原来有专家指导**
# ------------------------------------------------------------
#
#  40. 📝 块类型: p
#      📍 ID: 20250618232925-04scg83
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 根据官方信息，腾讯元宝的这次升级主打「长文精读」，可原生支持最长近 50 万字的输入。我们在测试中用到的论文远远没有达到这个长度，日常所接触的论文大多也达不到。所以用元宝来精读论文，大部分情况下上下文窗口都是够用的。它的模块化、图文并茂输出以及划词搜索、翻译等小功能也让读论文这件事真正变得方便、高效，向着「实用性」又迈近了一步。
# ------------------------------------------------------------
#
#  41. 📝 块类型: p
#      📍 ID: 20250618232925-u1h5qrh
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 这种进化离不开其背后模型 —— 腾讯混元大模型的升级。据悉，为了在专业领域中提升模型的专业性和实用性，腾讯混元团队专门邀请领域专家概括各专业领域的核心技能，并制定了专业问题的回答标准，使得模型能够作为真正的领域专家来提供服务。所以我们用下来就感觉，元宝是知道论文读者需要什么信息以及信息应该如何呈现的。
#      📝 Markdown: 这种进化离不开其背后模型 —— 腾讯混元大模型的升级。据悉，为了在专业领域中提升模型的专业性和实用性，腾讯混元团队**专门邀请领域专家概括各专业领域的核心技能，并制定了专业问题的回答标准**，使得模型能够作为真正的领域专家来提供服务。所以我们用下来就感觉，元宝是知道论文读者需要什么信息以及信息应该如何呈现的。
# ------------------------------------------------------------
#
#  42. 📝 块类型: p
#      📍 ID: 20250618232925-zgmh29e
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 除了论文，这个新功能还可以用来精读财报、研报等长文本。在这些场景中，它可以从多个维度梳理信息，根据报告内容生成杜邦分析图等专业图表，让不懂这些文件的人也能看懂企业的财务状况等信息。
#      📝 Markdown: 除了论文，这个新功能还可以用来精读**财报、研报**等长文本。在这些场景中，它可以从多个维度梳理信息，根据报告内容生成杜邦分析图等专业图表，让不懂这些文件的人也能看懂企业的财务状况等信息。
# ------------------------------------------------------------
#
#  43. 📝 块类型: p
#      📍 ID: 20250618232925-onh1mn2
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: image assets/640_15-20250618232925-fa0beu6.gif
#      📝 Markdown: ![image](assets/640_15-20250618232925-fa0beu6.gif)
# ------------------------------------------------------------
#
#  44. 📝 块类型: p
#      📍 ID: 20250618232925-4hdadlv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: 不过，就读论文这个场景来说，元宝依然存在一些改进空间，比如在阅读原文界面缺乏完整的原文 - 译文对照，对公式的识别有时不够准确等。我们也希望元宝能在未来的更新中改进这些问题。</pre>
# ------------------------------------------------------------
#
#  45. 🌐 块类型: html
#      📍 ID: 20250618232925-a0qnofv
#      👆 父块: 20250618232924-ed8wf0w
#      📅 创建: 20250618232925
#      🔄 更新: 20250618232925
#      💬 内容: <div>
# </body>
# </html>
# </body>
# </html>
# </div>
# ------------------------------------------------------------
# {'custom-abstract': '<nil>', 'custom-accessed': '2024-09-03 22:36:43 +0000 UTC', 'custom-attachmentCount': '0', 'custom-author': '<nil>', 'custom-category': '/兴趣爱好/AIGC/', 'custom-created': '2024-08-18 09:02:36 +0000 UTC', 'custom-docGuid': '7986491f-fba2-4d29-a20f-4c587692ad73', 'custom-keywords': '<nil>', 'custom-modified': '<nil>', 'custom-readCount': '0', 'custom-resources': '[]', 'custom-url': 'https://mp.weixin.qq.com/s/mC1N8qdHwli6bufPLX_LWg', 'custom-version': '153404', 'id': '20250618232924-ed8wf0w', 'tags': '已读', 'title': '这个大模型，真的治好了我的论文阅读障碍', 'type': 'doc', 'updated': '20250618232924'}
#
# 文件已保存:
#   JSON格式: output\blocks_20250618232924-ed8wf0w.json
#   文本格式: output\blocks_20250618232924-ed8wf0w.txt
#
# 📊 块类型统计:
#   d: 1 个
#   html: 3 个
#   p: 41 个

# %%
# 获取文档块的kramdown源码（使用functions.py模块）
doc_id = "20250621081403-hx0zl8u"
data = api_client.call_api("/api/block/getBlockKramdown", {"id": doc_id})

def print_dict_structure(data, indent=0):
    """递归打印字典结构，每一层都有适当的缩进"""
    if isinstance(data, dict):
        for key, value in data.items():
            print("  " * indent + f"{key}:")
            if isinstance(value, (dict, list)):
                print_dict_structure(value, indent + 1)
            else:
                print("  " * (indent + 1) + str(value))
    elif isinstance(data, list):
        for i, item in enumerate(data):
            print("  " * indent + f"[{i}]:")
            if isinstance(item, (dict, list)):
                print_dict_structure(item, indent + 1)
            else:
                print("  " * (indent + 1) + str(item))
    else:
        print("  " * indent + str(data))

print_dict_structure(data)
# Out:
# id:
#   20250621081403-hx0zl8u
# kramdown:
#   > 为知笔记迁移文档自定义属性：
# > abstract: <nil>
# > url: [https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848](https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848)
# > created: 2025-06-09 23:04:19 +0000 UTC
# > accessed: 2025-06-12 12:31:36 +0000 UTC
# > modified: <nil>
# > {: id="20250621140548-jaos5p3" updated="20250621140548"}
# >
# {: id="20250621140548-b92fkyy" updated="20250621140548"}
#
# # 苹果重磅论文翻车！被指测试方法有大问题……网友：Cook 该裁员了！
# {: id="20250621081403-clxqrix" updated="20250621105403"}
#
# 2025-06-09 17:43·[人工智能学家](https://www.toutiao.com/c/user/token/MS4wLjABAAAAopm85qB5EHed92CocYuWSjILG4hacNLOMeKOxKXTHGk/?source=tuwen_detail)
# {: id="20250621081403-8gvt7q6" updated="20250615183338"}
#
# 来源：AGI Hunt
# {: id="20250621081403-tgzjxng" updated="20250615183338"}
#
# **苹果的AI 研究团队这次真的翻车了！**
# {: id="20250621081403-ghxk2dy" updated="20250615183338"}
#
# 他们最近发布的一篇论文引发了AI 圈的集体吐槽，原因竟然是**测试方法出了大问题**。
# {: id="20250621081403-gba3sqo" updated="20250615183338"}
#
# ![image](assets/5e3c075bb3b21ecc3bae51e4b8a175df-20250615183338-vocbet6.jpg)
# {: id="20250621081403-d3xebaz" updated="20250615183338"}
#
# 见前文：苹果宣判推理模型死刑！Google CEO：忘了AGI吧，先用好AJI
# {: id="20250621081403-xy9amr8" updated="20250615183338"}
#
# 研究者Lisan al Gaib在复现苹果论文中的汉诺塔（Tower of Hanoi）测试后发现了一个惊人的事实：**模型根本不是因为推理能力不行而失败，而是因为输出token限制！**
# {: id="20250621081403-7p1if9k" updated="20250615183338"}
#
# ![image](assets/60ef00128e5cf80619d90503519d1757-20250615183338-oktw4wi.jpg)
# {: id="20250621081403-cyyfl0e" updated="20250615183338"}
#
# 要知道，汉诺塔问题需要**至少2^N - 1步**才能解决，而输出格式需要每步10个token外加一些固定内容。
# {: id="20250621081403-159tyw2" updated="20250615183338"}
#
# 这意味着什么？
# {: id="20250621081403-utt76ju" updated="20250615183338"}
#
# {: custom-abstract="&lt;nil&gt;" custom-accessed="2025-06-12 12:31:36 +0000 UTC" custom-attachmentCount="0" custom-author="&lt;nil&gt;" custom-category="/My Emails/" custom-created="2025-06-09 23:04:19 +0000 UTC" custom-docGuid="38002001-6d85-41c2-a1ec-a75f9ed33571" custom-keywords="&lt;nil&gt;" custom-modified="&lt;nil&gt;" custom-readCount="0" custom-resources="[]" custom-url="https://www.toutiao.com/article/7517174713618104851/?log_from=396a8c9db2481_1750471891848" custom-version="179271" id="20250621081403-hx0zl8u" title="自定义属性，含url" type="doc" updated="20250621140548"}

# %%
# 使用重构后的functions.py模块的简单示例
print("=== 使用functions.py模块的简单示例 ===\n")

# 1. 快速获取笔记本信息
print("1. 获取笔记本列表:")
notebooks = notebook_manager.list_notebooks()
for i, notebook in enumerate(notebooks[:3], 1):  # 只显示前3个
    print(f"   {i}. {notebook['name']} ({notebook['id'][:8]}...)")

# 2. 根据名称查找笔记本
print("\n2. 根据名称查找笔记本:")
if notebooks:
    notebook_name = notebooks[0]['name']
    found_id = notebook_manager.get_notebook_id_by_name(notebook_name)
    print(f"   笔记本 '{notebook_name}' 的ID: {found_id}")

# 3. 快速获取文档数量
print("\n3. 获取文档数量:")
if notebooks:
    nb_id = notebooks[0]['id']
    doc_ids = document_manager.get_notebook_docs_by_sql(nb_id)
    print(f"   笔记本中共有 {len(doc_ids)} 个文档")

# 4. 使用TreeProcessor计算文档数量
print("\n4. 使用TreeProcessor功能:")
sample_tree = {
    "folder1": {
        "doc1": "Document 1",
        "doc2": "Document 2"
    },
    "doc3": "Document 3"
}
doc_count = TreeProcessor.count_documents(sample_tree)
print(f"   示例树结构包含 {doc_count} 个文档")
# Out:
# 2025-06-21 22:23:54,561 - INFO - 正在获取笔记本列表...
# 2025-06-21 22:23:54,565 - INFO - 找到 3 个笔记本
# 2025-06-21 22:23:54,566 - INFO - 正在获取笔记本 '思源笔记用户指南' 的ID...
# 2025-06-21 22:23:54,566 - INFO - 正在获取笔记本列表...
# 2025-06-21 22:23:54,569 - INFO - 找到 3 个笔记本
# 2025-06-21 22:23:54,569 - INFO - 找到笔记本 '思源笔记用户指南' 的ID: 20210808180117-czj9bvb
# 2025-06-21 22:23:54,570 - INFO - 正在通过SQL查询获取笔记本 20210808180117-czj9bvb 下的文档...
# 2025-06-21 22:23:54,570 - INFO - 执行SQL: SELECT id, content FROM blocks WHERE box = '20210808180117-czj9bvb' AND type = 'd' ORDER BY created
# === 使用functions.py模块的简单示例 ===
#
# 1. 获取笔记本列表:
#    1. 思源笔记用户指南 (20210808...)
#    2. QuincyZou (20250614...)
#    3. 剪藏笔记本 (20250618...)
#
# 2. 根据名称查找笔记本:
#    笔记本 '思源笔记用户指南' 的ID: 20210808180117-czj9bvb
#
# 3. 获取文档数量:
# 2025-06-21 22:23:55,215 - INFO - 通过SQL查询找到 64 个文档
#    笔记本中共有 64 个文档
#
# 4. 使用TreeProcessor功能:
#    示例树结构包含 3 个文档
#
# === 重构完成！现在可以更高效地使用思源笔记API ===
# 💡 提示：所有功能都可以通过相应的管理器类来访问，代码更简洁、更易维护！
